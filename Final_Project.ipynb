# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns
import re
# %matplotlib inline

# %%
elon_musk = pd.read_csv('ElonTweets(Sentiment) 10-28-22.csv')
elon_musk
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                   Datetime  \
# 0                 0             0           0  2022-10-28 03:49:11+00:00
# 1                 1             1           1  2022-10-28 01:50:49+00:00
# 2                 2             2           2  2022-10-27 21:45:47+00:00
# 3                 3             3           3  2022-10-27 16:17:39+00:00
# 4                 4             4           4  2022-10-27 13:19:25+00:00
# ...             ...           ...         ...                        ...
# 17440         17440         17440       17440  2011-12-03 08:22:07+00:00
# 17441         17441         17441       17441  2011-12-03 08:20:28+00:00
# 17442         17442         17442       17442  2011-12-01 10:29:04+00:00
# 17443         17443         17443       17443  2011-12-01 09:55:11+00:00
# 17444         17444         17444       17444  2010-06-04 18:31:57+00:00
#
#                   Tweet Id                                               Text  \
# 0      1585841080431321088                                  the bird is freed
# 1      1585811291851018241  Falcon rockets to orbit as seen from LA https:...
# 2      1585749627365515266                                @Gfilche @Twitter 🤣
# 3      1585667048020901888                              @PeterSchiff 🤣 thanks
# 4      1585622194696044544                              @ZubyMusic Absolutely
# ...                    ...                                                ...
# 17440   142881284019060736                  That was a total non sequitur btw
# 17441   142880871391838208  Great Voltaire quote, arguably better than Twa...
# 17442   142188458125963264  I made the volume on the Model S http://t.co/w...
# 17443   142179928203460608  Went to Iceland on Sat to ride bumper cars on ...
# 17444          15434727182  Please ignore prior tweets, as that was someon...
#
#        Username    location  reply count  retweet count  like count language  \
# 0      elonmusk  Twitter HQ        57663         128631      730472       en
# 1      elonmusk  Twitter HQ         6857          16499      189436       en
# 2      elonmusk  Twitter HQ          632            246        7052      und
# 3      elonmusk  Twitter HQ          670            420       17577       en
# 4      elonmusk  Twitter HQ         1281           1152       42896       en
# ...         ...         ...          ...            ...         ...      ...
# 17440  elonmusk  Twitter HQ           27              9          51       en
# 17441  elonmusk  Twitter HQ           23             29          53       en
# 17442  elonmusk  Twitter HQ           29             13          75       en
# 17443  elonmusk  Twitter HQ           33             22         188       en
# 17444  elonmusk  Twitter HQ          988            558        6023       en
#
#       Twitter Access Point  Follower Count   Friends Count  verified  \
# 0       Twitter for iPhone       110553384             122      True
# 1       Twitter for iPhone       110553384             122      True
# 2       Twitter for iPhone       110553384             122      True
# 3       Twitter for iPhone       110553384             122      True
# 4       Twitter for iPhone       110553384             122      True
# ...                    ...             ...             ...       ...
# 17440   Twitter for iPhone       110555351             122      True
# 17441   Twitter for iPhone       110555351             122      True
# 17442   Twitter Web Client       110555351             122      True
# 17443   Twitter Web Client       110555351             122      True
# 17444   Twitter Web Client       110555351             122      True
#
#              Date         mentions                 sentiment
# 0      2022-10-28                _  ['positive', 0.70848316]
# 1      2022-10-28                _   ['neutral', 0.90077394]
# 2      2022-10-27  Gfilche,Twitter    ['neutral', 0.5714027]
# 3      2022-10-27      PeterSchiff  ['positive', 0.78971434]
# 4      2022-10-27        ZubyMusic    ['neutral', 0.5287457]
# ...           ...              ...                       ...
# 17440  2011-12-03                _   ['negative', 0.5067324]
# 17441  2011-12-03                _  ['positive', 0.55860823]
# 17442  2011-12-01                _    ['neutral', 0.6384011]
# 17443  2011-12-01                _   ['positive', 0.9733198]
# 17444  2010-06-04                _    ['neutral', 0.5472165]
#
# [17445 rows x 19 columns]

# %%
elon_musk['Date']= elon_musk['Datetime'].str.extract('(^\d*)')
elon_musk['Date'] = pd.to_datetime(elon_musk['Date'], format='%Y%m%d')
elon_musk
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:510, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509 try:
# --> 510     values, tz = conversion.datetime_to_datetime64(arg)
#     511     dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 elon_musk['Date']= elon_musk['Datetime'].str.extract('(^\d*)')
# ----> 2 elon_musk['Date'] = pd.to_datetime(elon_musk['Date'], format='%Y%m%d')
#       3 elon_musk
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1047, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1045             result = arg.tz_localize(tz)
#    1046 elif isinstance(arg, ABCSeries):
# -> 1047     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1048     if not cache_array.empty:
#    1049         result = arg.map(cache_array)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:197, in _maybe_cache(arg, format, cache, convert_listlike)
#     195 unique_dates = unique(arg)
#     196 if len(unique_dates) < len(arg):
# --> 197     cache_dates = convert_listlike(unique_dates, format)
#     198     cache_array = Series(cache_dates, index=unique_dates)
#     199     # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:394, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     391         format = None
#     393 if format is not None:
# --> 394     res = _to_datetime_with_format(
#     395         arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     396     )
#     397     if res is not None:
#     398         return res
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:514, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     512     return DatetimeIndex._simple_new(dta, name=name)
#     513 except (ValueError, TypeError):
# --> 514     raise err
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:501, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     498             return _box_as_indexlike(result, utc=utc, name=name)
#     500     # fallback
# --> 501     res = _array_strptime_with_fallback(
#     502         arg, name, tz, fmt, exact, errors, infer_datetime_format
#     503     )
#     504     return res
#     506 except ValueError as err:
#     507     # Fallback to try to convert datetime objects if timezone-aware
#     508     #  datetime objects are found without passing `utc=True`
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:437, in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     434 utc = tz == "utc"
#     436 try:
# --> 437     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     438     if "%Z" in fmt or "%z" in fmt:
#     439         return _return_parsed_timezone_results(result, timezones, tz, name)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/strptime.pyx:150, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '2022' does not match format '%Y%m%d' (match)

# %%
elon_musk['year'] = pd.DatetimeIndex(elon_musk['Datetime']).year

# %%
elon_musk
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                   Datetime  \
# 0                 0             0           0  2022-10-28 03:49:11+00:00
# 1                 1             1           1  2022-10-28 01:50:49+00:00
# 2                 2             2           2  2022-10-27 21:45:47+00:00
# 3                 3             3           3  2022-10-27 16:17:39+00:00
# 4                 4             4           4  2022-10-27 13:19:25+00:00
# ...             ...           ...         ...                        ...
# 17440         17440         17440       17440  2011-12-03 08:22:07+00:00
# 17441         17441         17441       17441  2011-12-03 08:20:28+00:00
# 17442         17442         17442       17442  2011-12-01 10:29:04+00:00
# 17443         17443         17443       17443  2011-12-01 09:55:11+00:00
# 17444         17444         17444       17444  2010-06-04 18:31:57+00:00
#
#                   Tweet Id                                               Text  \
# 0      1585841080431321088                                  the bird is freed
# 1      1585811291851018241  Falcon rockets to orbit as seen from LA https:...
# 2      1585749627365515266                                @Gfilche @Twitter 🤣
# 3      1585667048020901888                              @PeterSchiff 🤣 thanks
# 4      1585622194696044544                              @ZubyMusic Absolutely
# ...                    ...                                                ...
# 17440   142881284019060736                  That was a total non sequitur btw
# 17441   142880871391838208  Great Voltaire quote, arguably better than Twa...
# 17442   142188458125963264  I made the volume on the Model S http://t.co/w...
# 17443   142179928203460608  Went to Iceland on Sat to ride bumper cars on ...
# 17444          15434727182  Please ignore prior tweets, as that was someon...
#
#        Username    location  reply count  retweet count  like count language  \
# 0      elonmusk  Twitter HQ        57663         128631      730472       en
# 1      elonmusk  Twitter HQ         6857          16499      189436       en
# 2      elonmusk  Twitter HQ          632            246        7052      und
# 3      elonmusk  Twitter HQ          670            420       17577       en
# 4      elonmusk  Twitter HQ         1281           1152       42896       en
# ...         ...         ...          ...            ...         ...      ...
# 17440  elonmusk  Twitter HQ           27              9          51       en
# 17441  elonmusk  Twitter HQ           23             29          53       en
# 17442  elonmusk  Twitter HQ           29             13          75       en
# 17443  elonmusk  Twitter HQ           33             22         188       en
# 17444  elonmusk  Twitter HQ          988            558        6023       en
#
#       Twitter Access Point  Follower Count   Friends Count  verified  Date  \
# 0       Twitter for iPhone       110553384             122      True  2022
# 1       Twitter for iPhone       110553384             122      True  2022
# 2       Twitter for iPhone       110553384             122      True  2022
# 3       Twitter for iPhone       110553384             122      True  2022
# 4       Twitter for iPhone       110553384             122      True  2022
# ...                    ...             ...             ...       ...   ...
# 17440   Twitter for iPhone       110555351             122      True  2011
# 17441   Twitter for iPhone       110555351             122      True  2011
# 17442   Twitter Web Client       110555351             122      True  2011
# 17443   Twitter Web Client       110555351             122      True  2011
# 17444   Twitter Web Client       110555351             122      True  2010
#
#               mentions                 sentiment  year
# 0                    _  ['positive', 0.70848316]  2022
# 1                    _   ['neutral', 0.90077394]  2022
# 2      Gfilche,Twitter    ['neutral', 0.5714027]  2022
# 3          PeterSchiff  ['positive', 0.78971434]  2022
# 4            ZubyMusic    ['neutral', 0.5287457]  2022
# ...                ...                       ...   ...
# 17440                _   ['negative', 0.5067324]  2011
# 17441                _  ['positive', 0.55860823]  2011
# 17442                _    ['neutral', 0.6384011]  2011
# 17443                _   ['positive', 0.9733198]  2011
# 17444                _    ['neutral', 0.5472165]  2010
#
# [17445 rows x 20 columns]

# %%
elon_musk_2021 = elon_musk[elon_musk['year'] == 2021]

# %%
elon_musk_2021
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                   Datetime  \
# 3135          3135          3135        3135  2021-12-31 02:23:58+00:00
# 3136          3136          3136        3136  2021-12-30 21:11:23+00:00
# 3137          3137          3137        3137  2021-12-30 20:47:53+00:00
# 3138          3138          3138        3138  2021-12-30 20:28:51+00:00
# 3139          3139          3139        3139  2021-12-30 18:23:14+00:00
# ...            ...           ...         ...                        ...
# 6132          6132          6132        6132  2021-01-02 14:59:09+00:00
# 6133          6133          6133        6133  2021-01-02 14:51:49+00:00
# 6134          6134          6134        6134  2021-01-02 12:23:28+00:00
# 6135          6135          6135        6135  2021-01-02 03:20:48+00:00
# 6136          6136          6136        6136  2021-01-01 00:58:30+00:00
#
#                  Tweet Id                                               Text  \
# 3135  1476740887543791617                                   @TheBabylonBee 🤣
# 3136  1476662222617251846                                  @roshanpateI 🤣 $7
# 3137  1476656306610216960             @tesla_raj Many UI improvements coming
# 3138  1476651519986614281  @CSmithson80 @heydave7 @BLKMDL3 @mims This cha...
# 3139  1476619907076923398  @BLKMDL3 @mims Predicting macroeconomics is ch...
# ...                   ...                                                ...
# 6132  1345384139969552389  @flcnhvy Tesla is responsible for 2/3 of all t...
# 6133  1345382294966571008  So proud of the Tesla team for achieving this ...
# 6134  1345344958710992897  @newscientist Um, we have giant fusion reactor...
# 6135  1345208391958888448  @comma_ai Tesla Full Self-Driving will work at...
# 6136  1344810193952014336  @PPathole Dojo isn’t needed, but will make sel...
#
#       Username    location  reply count  retweet count  like count language  \
# 3135  elonmusk  Twitter HQ          987            687       21062      und
# 3136  elonmusk  Twitter HQ          756            340       12985      und
# 3137  elonmusk  Twitter HQ          972            418       11841       ca
# 3138  elonmusk  Twitter HQ          238            136        2450       en
# 3139  elonmusk  Twitter HQ          730           1605        6610       en
# ...        ...         ...          ...            ...         ...      ...
# 6132  elonmusk  Twitter HQ          618            643       12589       en
# 6133  elonmusk  Twitter HQ         3944           5820      104724       en
# 6134  elonmusk  Twitter HQ         1811           2210       50314       en
# 6135  elonmusk  Twitter HQ          635            869       19773       en
# 6136  elonmusk  Twitter HQ          213            207        3461       en
#
#      Twitter Access Point  Follower Count   Friends Count  verified  Date  \
# 3135   Twitter for iPhone       110553725             122      True  2021
# 3136   Twitter for iPhone       110553725             122      True  2021
# 3137   Twitter for iPhone       110553725             122      True  2021
# 3138   Twitter for iPhone       110553725             122      True  2021
# 3139   Twitter for iPhone       110553725             122      True  2021
# ...                   ...             ...             ...       ...   ...
# 6132   Twitter for iPhone       110554098             122      True  2021
# 6133   Twitter for iPhone       110554098             122      True  2021
# 6134   Twitter for iPhone       110554098             122      True  2021
# 6135   Twitter for iPhone       110554098             122      True  2021
# 6136   Twitter for iPhone       110554098             122      True  2021
#
#                                mentions                 sentiment  year
# 3135                      TheBabylonBee   ['neutral', 0.52986854]  2021
# 3136                        roshanpateI   ['neutral', 0.69755554]  2021
# 3137                          tesla_raj    ['positive', 0.797664]  2021
# 3138  CSmithson80,heydave7,BLKMDL3,mims  ['positive', 0.79169226]  2021
# 3139                       BLKMDL3,mims   ['neutral', 0.54506123]  2021
# ...                                 ...                       ...   ...
# 6132                            flcnhvy   ['neutral', 0.43212065]  2021
# 6133                                  _  ['positive', 0.98368937]  2021
# 6134                       newscientist     ['positive', 0.59646]  2021
# 6135                           comma_ai  ['positive', 0.81392205]  2021
# 6136                           PPathole     ['neutral', 0.479866]  2021
#
# [3002 rows x 20 columns]

# %%
elon_musk_2021.shape
# Out:
# (3002, 20)

# %%
musk_tweets_2021 = pd.DataFrame(elon_musk_2021['Text'])

# %%
musk_tweets_2021
# Out:
#                                                    Text
# 3135                                   @TheBabylonBee 🤣
# 3136                                  @roshanpateI 🤣 $7
# 3137             @tesla_raj Many UI improvements coming
# 3138  @CSmithson80 @heydave7 @BLKMDL3 @mims This cha...
# 3139  @BLKMDL3 @mims Predicting macroeconomics is ch...
# ...                                                 ...
# 6132  @flcnhvy Tesla is responsible for 2/3 of all t...
# 6133  So proud of the Tesla team for achieving this ...
# 6134  @newscientist Um, we have giant fusion reactor...
# 6135  @comma_ai Tesla Full Self-Driving will work at...
# 6136  @PPathole Dojo isn’t needed, but will make sel...
#
# [3002 rows x 1 columns]

# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-4.12.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 3.2 MB/s ta 0:00:01
# Collecting oauthlib<4,>=3.2.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 7.2 MB/s eta 0:00:01
# Collecting requests-oauthlib<2,>=1.2.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: requests<3,>=2.27.0 in /Users/saori/opt/anaconda3/lib/python3.9/site-packages (from tweepy) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/saori/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/saori/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/saori/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/saori/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.2.2 requests-oauthlib-1.3.1 tweepy-4.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy
import file with credentials ("twt.py")
import twt

# %%
# import file with credentials ("twt.py")
#import twt
#import tweepy

#api_key = twt.API_key
#api_secret = twt.API_secret_key
#access_token = twt.access_token
#access_secret = twt.access_token_secret

# Authenticate to Twitter
#auth = tweepy.OAuth1UserHandler(api_key,api_secret,access_token,access_secret)

#api = tweepy.API(auth)
 
#try:
  #  api.verify_credentials()
  #  print('Successful Authentication')
#except:
   # print('Failed authentication')

# %%
api_key = 'vcCmOETCASdUd0CpAdCtAT1H7'

api_secret = '8KEdeRxbIiQdRzC5oQFpJreC6b87I3LN2Sq6cwLXlkBB1aEGTw'

bearer_token = 'AAAAAAAAAAAAAAAAAAAAAKnFRAEAAAAA0WTW5LZ0FZm0YaTCHQpjYW2BzmI%3DAis5txxF8CKfT5UfsbcG9UznM61bmjCuN6FqlZwqJIjycjw9Hl'

access_token = '1410231389220376584-B2PrnZFEXKU6coWb3AEWGPODV4YJ9F'

access_token_secret = 'PPwZ8sh80xzCPochgHytGCzk3USP2RQkmUeRPqq2LqiHR'

auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
import tweepy

client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAKnFRAEAAAAA0WTW5LZ0FZm0YaTCHQpjYW2BzmI%3DAis5txxF8CKfT5UfsbcG9UznM61bmjCuN6FqlZwqJIjycjw9Hl')

# Replace with your own search query
query = 'from:suhemparack -is:retweet'

# Replace with time period of your choice
start_time = '2022-01-01T00:00:00Z'

# Replace with time period of your choice
end_time = '2022-11-30T00:00:00Z'

tweets = client.search_all_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
                                  start_time=start_time,
                                  end_time=end_time, max_results=100)

for tweet in tweets.data:
    print(tweet.text)
    print(tweet.created_at)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Input In [24], in <cell line: 14>()
#      11 # Replace with time period of your choice
#      12 end_time = '2022-11-30T00:00:00Z'
# ---> 14 tweets = client.search_all_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
#      15                                   start_time=start_time,
#      16                                   end_time=end_time, max_results=100)
#      18 for tweet in tweets.data:
#      19     print(tweet.text)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/client.py:1163, in Client.search_all_tweets(self, query, **params)
#    1071 """search_all_tweets( \
#    1072     query, *, end_time=None, expansions=None, max_results=None, \
#    1073     media_fields=None, next_token=None, place_fields=None, \
#    (...)
#    1160 .. _pagination: https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/paginate
#    1161 """
#    1162 params["query"] = query
# -> 1163 return self._make_request(
#    1164     "GET", "/2/tweets/search/all", params=params,
#    1165     endpoint_parameters=(
#    1166         "end_time", "expansions", "max_results", "media.fields",
#    1167         "next_token", "place.fields", "poll.fields", "query",
#    1168         "since_id", "sort_order", "start_time", "tweet.fields",
#    1169         "until_id", "user.fields"
#    1170     ), data_type=Tweet
#    1171 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/client.py:129, in BaseClient._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     123 def _make_request(
#     124     self, method, route, params={}, endpoint_parameters=(), json=None,
#     125     data_type=None, user_auth=False
#     126 ):
#     127     request_params = self._process_params(params, endpoint_parameters)
# --> 129     response = self.request(method, route, params=request_params,
#     130                             json=json, user_auth=user_auth)
#     132     if self.return_type is requests.Response:
#     133         return response
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/client.py:100, in BaseClient.request(self, method, route, params, json, user_auth)
#      98     raise Unauthorized(response)
#      99 if response.status_code == 403:
# --> 100     raise Forbidden(response)
#     101 if response.status_code == 404:
#     102     raise NotFound(response)
#
# Forbidden: 403 Forbidden
# When authenticating requests to the Twitter API v2 endpoints, you must use keys and tokens from a Twitter developer App that is attached to a Project. You can create a project via the developer portal.

# %%
cursor = tweepy.Cursor(api.user_timeline, id='paulkrugman', tweet_mode='extendet')

for i in cursor:
    print(dir(i))
    
cursor = tweepy.Cursor(api.user_timeline, id='paulkrugman', tweet_mode='extendet').items(10)

for i in cursor:
    print(i.text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 3>()
#       1 cursor = tweepy.Cursor(api.user_timeline, id='paulkrugman', tweet_mode='extendet')
# ----> 3 for i in cursor:
#       4     print(dir(i))
#       6 cursor = tweepy.Cursor(api.user_timeline, id='paulkrugman', tweet_mode='extendet').items(10)
#
# TypeError: 'Cursor' object is not iterable

# %%
import tweepy

#Put your Bearer Token in the parenthesis below
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAKnFRAEAAAAA0WTW5LZ0FZm0YaTCHQpjYW2BzmI%3DAis5txxF8CKfT5UfsbcG9UznM61bmjCuN6FqlZwqJIjycjw9Hl')

"""
If you don't understand search queries, there is an excellent introduction to it here: 
https://github.com/twitterdev/getting-started-with-the-twitter-api-v2-for-academic-research/blob/main/modules/5-how-to-write-search-queries.md
"""

# Get tweets that contain the hashtag #petday
# -is:retweet means I don't want retweets
# lang:en is asking for the tweets to be in english
query = '#petday -is:retweet lang:en'
tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)

"""
What context_annotations are: 
https://developer.twitter.com/en/docs/twitter-api/annotations/overview
"""
for tweet in tweets.data:
    print(tweet.text)
    if len(tweet.context_annotations) > 0:
        print(tweet.context_annotations)
# Out:
# When it comes to taking care of your pet we know best! Checkout the site for the best products!
#  #stylish #dogs #petday #pet #comfy #dogcare #pups #doghype https://t.co/0G4pKJ9qt1
# [{'domain': {'id': '45', 'name': 'Brand Vertical', 'description': 'Top level entities that describe a Brands industry'}, 'entity': {'id': '781974596811493377', 'name': 'Pet Care - CPG'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697078762958848', 'name': 'Pet Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Pets such as pet food, toys, cleaning'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '852262932607926273', 'name': 'Pets', 'description': 'Pets'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '853980498816679937', 'name': 'Dogs', 'description': 'Dogs'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '781974596811493377', 'name': 'Pet Care - CPG'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '839543325212319744', 'name': 'Animals'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '852262932607926273', 'name': 'Pets', 'description': 'Pets'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '853980498816679937', 'name': 'Dogs', 'description': 'Dogs'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '845326060757512192', 'name': 'Fashion Novelty', 'description': 'Fashion Novelty'}}, {'domain': {'id': '67', 'name': 'Interests and Hobbies', 'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'}, 'entity': {'id': '845327283774640128', 'name': 'Fashion Tags', 'description': 'Fashion Blogging'}}]
# The holidays are here be sure to checkout the site for the best products and ideas for your dog or cat!
#  #comfy #stylish #pups #dogs #petday #dogcare #dogseason #pet https://t.co/0pgkMLaq33
# [{'domain': {'id': '45', 'name': 'Brand Vertical', 'description': 'Top level entities that describe a Brands industry'}, 'entity': {'id': '781974596811493377', 'name': 'Pet Care - CPG'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697078762958848', 'name': 'Pet Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Pets such as pet food, toys, cleaning'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '781974596811493377', 'name': 'Pet Care - CPG'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '852262932607926273', 'name': 'Pets', 'description': 'Pets'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '845326060757512192', 'name': 'Fashion Novelty', 'description': 'Fashion Novelty'}}, {'domain': {'id': '67', 'name': 'Interests and Hobbies', 'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'}, 'entity': {'id': '845327283774640128', 'name': 'Fashion Tags', 'description': 'Fashion Blogging'}}]
# Checkout these 4 piece protection antiskid puppy boots that we have for sale on our site for a low price! They would be perfect for your keeping your pups paws warm this winter!
#
# https://t.co/Gjgpe5BPAF
#
#  #stylish #pet #comfy #dogseason #pups #dogs #petday #dogcare https://t.co/5oiFabd2td
# [{'domain': {'id': '45', 'name': 'Brand Vertical', 'description': 'Top level entities that describe a Brands industry'}, 'entity': {'id': '781974596811493377', 'name': 'Pet Care - CPG'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697078762958848', 'name': 'Pet Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Pets such as pet food, toys, cleaning'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '852262932607926273', 'name': 'Pets', 'description': 'Pets'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '853980498816679937', 'name': 'Dogs', 'description': 'Dogs'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '781974596811493377', 'name': 'Pet Care - CPG'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '839543325212319744', 'name': 'Animals'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '852262932607926273', 'name': 'Pets', 'description': 'Pets'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '853980498816679937', 'name': 'Dogs', 'description': 'Dogs'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '908752469164826625', 'name': 'Puppies', 'description': 'Puppies'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '908779324391571456', 'name': 'Baby animals', 'description': 'Baby Animals'}}, {'domain': {'id': '167', 'name': 'Animals', 'description': ', for animals and types of animals, e.g., cats, birds, marine life, Labrador Retriever'}, 'entity': {'id': '908752469164826625', 'name': 'Puppies', 'description': 'Puppies'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '845326060757512192', 'name': 'Fashion Novelty', 'description': 'Fashion Novelty'}}, {'domain': {'id': '67', 'name': 'Interests and Hobbies', 'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'}, 'entity': {'id': '845327283774640128', 'name': 'Fashion Tags', 'description': 'Fashion Blogging'}}]
# #Affirmation I love petting my EGO when i MATURELY rufflect... on compLIMEnts from OTHERS that i surely collect. #PetDay #Pet $WOOF #Health #Lime #Energy #Longevity #PerpetualYouthDay #PerPETualYOUth
# It’s official announcement. My couch wolf didn’t participate in breaking my hand.
# #petday https://t.co/djQsII9t4C

# %%
import tweepy

#Put your Bearer Token in the parenthesis below
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAKnFRAEAAAAA0WTW5LZ0FZm0YaTCHQpjYW2BzmI%3DAis5txxF8CKfT5UfsbcG9UznM61bmjCuN6FqlZwqJIjycjw9Hl')

"""
If you don't understand search queries, there is an excellent introduction to it here: 
https://github.com/twitterdev/getting-started-with-the-twitter-api-v2-for-academic-research/blob/main/modules/5-how-to-write-search-queries.md
"""

# Get tweets that contain the hashtag #petday
# -is:retweet means I don't wantretweets
# lang:en is asking for the tweets to be in english
query = ' -is:retweet lang:en'
tweets = tweepy.Paginator(client.search_recent_tweets, query=query,
                              tweet_fields=['context_annotations', 'created_at'], max_results=100).flatten(limit=1000)

for tweet in tweets:
    print(tweet.text)
    if len(tweet.context_annotations) > 0:
        print(tweet.context_annotations)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Input In [31], in <cell line: 18>()
#      14 query = ' -is:retweet lang:en'
#      15 tweets = tweepy.Paginator(client.search_recent_tweets, query=query,
#      16                               tweet_fields=['context_annotations', 'created_at'], max_results=100).flatten(limit=1000)
# ---> 18 for tweet in tweets:
#      19     print(tweet.text)
#      20     if len(tweet.context_annotations) > 0:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/pagination.py:67, in Paginator.flatten(self, limit)
#      64     return
#      66 count = 0
# ---> 67 for response in PaginationIterator(
#      68     self.method, *self.args, **self.kwargs
#      69 ):
#      70     if isinstance(response, Response):
#      71         response_data = response.data or []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/pagination.py:126, in PaginationIterator.__next__(self)
#     123 else:
#     124     self.kwargs["pagination_token"] = pagination_token
# --> 126 response = self.method(*self.args, **self.kwargs)
#     128 if isinstance(response, Response):
#     129     meta = response.meta
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/client.py:1266, in Client.search_recent_tweets(self, query, user_auth, **params)
#    1174 """search_recent_tweets( \
#    1175     query, *, end_time=None, expansions=None, max_results=None, \
#    1176     media_fields=None, next_token=None, place_fields=None, \
#    (...)
#    1263 .. _Academic Research Project: https://developer.twitter.com/en/docs/projects
#    1264 """
#    1265 params["query"] = query
# -> 1266 return self._make_request(
#    1267     "GET", "/2/tweets/search/recent", params=params,
#    1268     endpoint_parameters=(
#    1269         "end_time", "expansions", "max_results", "media.fields",
#    1270         "next_token", "place.fields", "poll.fields", "query",
#    1271         "since_id", "sort_order", "start_time", "tweet.fields",
#    1272         "until_id", "user.fields"
#    1273     ), data_type=Tweet, user_auth=user_auth
#    1274 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/client.py:129, in BaseClient._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     123 def _make_request(
#     124     self, method, route, params={}, endpoint_parameters=(), json=None,
#     125     data_type=None, user_auth=False
#     126 ):
#     127     request_params = self._process_params(params, endpoint_parameters)
# --> 129     response = self.request(method, route, params=request_params,
#     130                             json=json, user_auth=user_auth)
#     132     if self.return_type is requests.Response:
#     133         return response
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/client.py:96, in BaseClient.request(self, method, route, params, json, user_auth)
#      88 log.debug(
#      89     "Received API response: "
#      90     f"{response.status_code} {response.reason}\n"
#      91     f"Headers: {response.headers}\n"
#      92     f"Content: {response.content}"
#      93 )
#      95 if response.status_code == 400:
# ---> 96     raise BadRequest(response)
#      97 if response.status_code == 401:
#      98     raise Unauthorized(response)
#
# BadRequest: 400 Bad Request
# There were errors processing your request: is/has/lang cannot be used as a standalone operator (at position 2)
