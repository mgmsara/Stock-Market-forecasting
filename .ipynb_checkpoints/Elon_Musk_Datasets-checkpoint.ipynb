# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns
import re
# %matplotlib inline
from datetime import datetime, timezone

# %%
elon_musk = pd.read_csv('ElonTweets(Sentiment) 10-28-22.csv')
elon_musk
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                   Datetime  \
# 0                 0             0           0  2022-10-28 03:49:11+00:00
# 1                 1             1           1  2022-10-28 01:50:49+00:00
# 2                 2             2           2  2022-10-27 21:45:47+00:00
# 3                 3             3           3  2022-10-27 16:17:39+00:00
# 4                 4             4           4  2022-10-27 13:19:25+00:00
# ...             ...           ...         ...                        ...
# 17440         17440         17440       17440  2011-12-03 08:22:07+00:00
# 17441         17441         17441       17441  2011-12-03 08:20:28+00:00
# 17442         17442         17442       17442  2011-12-01 10:29:04+00:00
# 17443         17443         17443       17443  2011-12-01 09:55:11+00:00
# 17444         17444         17444       17444  2010-06-04 18:31:57+00:00
#
#                   Tweet Id                                               Text  \
# 0      1585841080431321088                                  the bird is freed
# 1      1585811291851018241  Falcon rockets to orbit as seen from LA https:...
# 2      1585749627365515266                                @Gfilche @Twitter 🤣
# 3      1585667048020901888                              @PeterSchiff 🤣 thanks
# 4      1585622194696044544                              @ZubyMusic Absolutely
# ...                    ...                                                ...
# 17440   142881284019060736                  That was a total non sequitur btw
# 17441   142880871391838208  Great Voltaire quote, arguably better than Twa...
# 17442   142188458125963264  I made the volume on the Model S http://t.co/w...
# 17443   142179928203460608  Went to Iceland on Sat to ride bumper cars on ...
# 17444          15434727182  Please ignore prior tweets, as that was someon...
#
#        Username    location  reply count  retweet count  like count language  \
# 0      elonmusk  Twitter HQ        57663         128631      730472       en
# 1      elonmusk  Twitter HQ         6857          16499      189436       en
# 2      elonmusk  Twitter HQ          632            246        7052      und
# 3      elonmusk  Twitter HQ          670            420       17577       en
# 4      elonmusk  Twitter HQ         1281           1152       42896       en
# ...         ...         ...          ...            ...         ...      ...
# 17440  elonmusk  Twitter HQ           27              9          51       en
# 17441  elonmusk  Twitter HQ           23             29          53       en
# 17442  elonmusk  Twitter HQ           29             13          75       en
# 17443  elonmusk  Twitter HQ           33             22         188       en
# 17444  elonmusk  Twitter HQ          988            558        6023       en
#
#       Twitter Access Point  Follower Count   Friends Count  verified  \
# 0       Twitter for iPhone       110553384             122      True
# 1       Twitter for iPhone       110553384             122      True
# 2       Twitter for iPhone       110553384             122      True
# 3       Twitter for iPhone       110553384             122      True
# 4       Twitter for iPhone       110553384             122      True
# ...                    ...             ...             ...       ...
# 17440   Twitter for iPhone       110555351             122      True
# 17441   Twitter for iPhone       110555351             122      True
# 17442   Twitter Web Client       110555351             122      True
# 17443   Twitter Web Client       110555351             122      True
# 17444   Twitter Web Client       110555351             122      True
#
#              Date         mentions                 sentiment
# 0      2022-10-28                _  ['positive', 0.70848316]
# 1      2022-10-28                _   ['neutral', 0.90077394]
# 2      2022-10-27  Gfilche,Twitter    ['neutral', 0.5714027]
# 3      2022-10-27      PeterSchiff  ['positive', 0.78971434]
# 4      2022-10-27        ZubyMusic    ['neutral', 0.5287457]
# ...           ...              ...                       ...
# 17440  2011-12-03                _   ['negative', 0.5067324]
# 17441  2011-12-03                _  ['positive', 0.55860823]
# 17442  2011-12-01                _    ['neutral', 0.6384011]
# 17443  2011-12-01                _   ['positive', 0.9733198]
# 17444  2010-06-04                _    ['neutral', 0.5472165]
#
# [17445 rows x 19 columns]

# %%
elon_musk['Date']= elon_musk['Datetime'].str.extract('(^\d*)')
elon_musk['Date'] = pd.to_datetime(elon_musk['Datetime'], format='%Y%m%d')
elon_musk
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:510, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509 try:
# --> 510     values, tz = conversion.datetime_to_datetime64(arg)
#     511     dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 elon_musk['Date']= elon_musk['Datetime'].str.extract('(^\d*)')
# ----> 2 elon_musk['Date'] = pd.to_datetime(elon_musk['Datetime'], format='%Y%m%d')
#       3 elon_musk
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1051, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1049         result = arg.map(cache_array)
#    1050     else:
# -> 1051         values = convert_listlike(arg._values, format)
#    1052         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:394, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     391         format = None
#     393 if format is not None:
# --> 394     res = _to_datetime_with_format(
#     395         arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     396     )
#     397     if res is not None:
#     398         return res
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:514, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     512     return DatetimeIndex._simple_new(dta, name=name)
#     513 except (ValueError, TypeError):
# --> 514     raise err
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:501, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     498             return _box_as_indexlike(result, utc=utc, name=name)
#     500     # fallback
# --> 501     res = _array_strptime_with_fallback(
#     502         arg, name, tz, fmt, exact, errors, infer_datetime_format
#     503     )
#     504     return res
#     506 except ValueError as err:
#     507     # Fallback to try to convert datetime objects if timezone-aware
#     508     #  datetime objects are found without passing `utc=True`
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:437, in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     434 utc = tz == "utc"
#     436 try:
# --> 437     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     438     if "%Z" in fmt or "%z" in fmt:
#     439         return _return_parsed_timezone_results(result, timezones, tz, name)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/strptime.pyx:150, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '2022-10-28 03:49:11+00:00' does not match format '%Y%m%d' (match)

# %%
elon_musk['year'] = pd.DatetimeIndex(elon_musk['Datetime']).year

# %%
elon_musk
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                   Datetime  \
# 0                 0             0           0  2022-10-28 03:49:11+00:00
# 1                 1             1           1  2022-10-28 01:50:49+00:00
# 2                 2             2           2  2022-10-27 21:45:47+00:00
# 3                 3             3           3  2022-10-27 16:17:39+00:00
# 4                 4             4           4  2022-10-27 13:19:25+00:00
# ...             ...           ...         ...                        ...
# 17440         17440         17440       17440  2011-12-03 08:22:07+00:00
# 17441         17441         17441       17441  2011-12-03 08:20:28+00:00
# 17442         17442         17442       17442  2011-12-01 10:29:04+00:00
# 17443         17443         17443       17443  2011-12-01 09:55:11+00:00
# 17444         17444         17444       17444  2010-06-04 18:31:57+00:00
#
#                   Tweet Id                                               Text  \
# 0      1585841080431321088                                  the bird is freed
# 1      1585811291851018241  Falcon rockets to orbit as seen from LA https:...
# 2      1585749627365515266                                @Gfilche @Twitter 🤣
# 3      1585667048020901888                              @PeterSchiff 🤣 thanks
# 4      1585622194696044544                              @ZubyMusic Absolutely
# ...                    ...                                                ...
# 17440   142881284019060736                  That was a total non sequitur btw
# 17441   142880871391838208  Great Voltaire quote, arguably better than Twa...
# 17442   142188458125963264  I made the volume on the Model S http://t.co/w...
# 17443   142179928203460608  Went to Iceland on Sat to ride bumper cars on ...
# 17444          15434727182  Please ignore prior tweets, as that was someon...
#
#        Username    location  reply count  retweet count  like count language  \
# 0      elonmusk  Twitter HQ        57663         128631      730472       en
# 1      elonmusk  Twitter HQ         6857          16499      189436       en
# 2      elonmusk  Twitter HQ          632            246        7052      und
# 3      elonmusk  Twitter HQ          670            420       17577       en
# 4      elonmusk  Twitter HQ         1281           1152       42896       en
# ...         ...         ...          ...            ...         ...      ...
# 17440  elonmusk  Twitter HQ           27              9          51       en
# 17441  elonmusk  Twitter HQ           23             29          53       en
# 17442  elonmusk  Twitter HQ           29             13          75       en
# 17443  elonmusk  Twitter HQ           33             22         188       en
# 17444  elonmusk  Twitter HQ          988            558        6023       en
#
#       Twitter Access Point  Follower Count   Friends Count  verified  Date  \
# 0       Twitter for iPhone       110553384             122      True  2022
# 1       Twitter for iPhone       110553384             122      True  2022
# 2       Twitter for iPhone       110553384             122      True  2022
# 3       Twitter for iPhone       110553384             122      True  2022
# 4       Twitter for iPhone       110553384             122      True  2022
# ...                    ...             ...             ...       ...   ...
# 17440   Twitter for iPhone       110555351             122      True  2011
# 17441   Twitter for iPhone       110555351             122      True  2011
# 17442   Twitter Web Client       110555351             122      True  2011
# 17443   Twitter Web Client       110555351             122      True  2011
# 17444   Twitter Web Client       110555351             122      True  2010
#
#               mentions                 sentiment  year
# 0                    _  ['positive', 0.70848316]  2022
# 1                    _   ['neutral', 0.90077394]  2022
# 2      Gfilche,Twitter    ['neutral', 0.5714027]  2022
# 3          PeterSchiff  ['positive', 0.78971434]  2022
# 4            ZubyMusic    ['neutral', 0.5287457]  2022
# ...                ...                       ...   ...
# 17440                _   ['negative', 0.5067324]  2011
# 17441                _  ['positive', 0.55860823]  2011
# 17442                _    ['neutral', 0.6384011]  2011
# 17443                _   ['positive', 0.9733198]  2011
# 17444                _    ['neutral', 0.5472165]  2010
#
# [17445 rows x 20 columns]

# %%
elon_musk_2022 = elon_musk[elon_musk['year'] == 2022]

# %%
elon_musk_2022
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                   Datetime  \
# 0                0             0           0  2022-10-28 03:49:11+00:00
# 1                1             1           1  2022-10-28 01:50:49+00:00
# 2                2             2           2  2022-10-27 21:45:47+00:00
# 3                3             3           3  2022-10-27 16:17:39+00:00
# 4                4             4           4  2022-10-27 13:19:25+00:00
# ...            ...           ...         ...                        ...
# 3130          3130          3130        3130  2022-01-02 22:56:00+00:00
# 3131          3131          3131        3131  2022-01-02 18:19:33+00:00
# 3132          3132          3132        3132  2022-01-02 17:56:50+00:00
# 3133          3133          3133        3133  2022-01-01 01:58:52+00:00
# 3134          3134          3134        3134  2022-01-01 00:53:13+00:00
#
#                  Tweet Id                                               Text  \
# 0     1585841080431321088                                  the bird is freed
# 1     1585811291851018241  Falcon rockets to orbit as seen from LA https:...
# 2     1585749627365515266                                @Gfilche @Twitter 🤣
# 3     1585667048020901888                              @PeterSchiff 🤣 thanks
# 4     1585622194696044544                              @ZubyMusic Absolutely
# ...                   ...                                                ...
# 3130  1477775713172402176                            https://t.co/LA9hPzVlGx
# 3131  1477706142461706248                Let’s make the roaring 20’s happen!
# 3132  1477700424933253123  Great work by Tesla team worldwide! https://t....
# 3133  1477096955658579974                                  @BLKMDL3 @Tesla 🔥
# 3134  1477080438049058818                  @MiFSDBetaTester @WholeMarsBlog 🤣
#
#       Username    location  reply count  retweet count  like count language  \
# 0     elonmusk  Twitter HQ        57663         128631      730472       en
# 1     elonmusk  Twitter HQ         6857          16499      189436       en
# 2     elonmusk  Twitter HQ          632            246        7052      und
# 3     elonmusk  Twitter HQ          670            420       17577       en
# 4     elonmusk  Twitter HQ         1281           1152       42896       en
# ...        ...         ...          ...            ...         ...      ...
# 3130  elonmusk  Twitter HQ        24741          48592      459498      zxx
# 3131  elonmusk  Twitter HQ        21602          25257      309430       en
# 3132  elonmusk  Twitter HQ         5474           4253       64534       en
# 3133  elonmusk  Twitter HQ         1029            447       43276      und
# 3134  elonmusk  Twitter HQ          306            143        3941      und
#
#      Twitter Access Point  Follower Count   Friends Count  verified  Date  \
# 0      Twitter for iPhone       110553384             122      True  2022
# 1      Twitter for iPhone       110553384             122      True  2022
# 2      Twitter for iPhone       110553384             122      True  2022
# 3      Twitter for iPhone       110553384             122      True  2022
# 4      Twitter for iPhone       110553384             122      True  2022
# ...                   ...             ...             ...       ...   ...
# 3130   Twitter for iPhone       110553725             122      True  2022
# 3131   Twitter for iPhone       110553725             122      True  2022
# 3132   Twitter for iPhone       110553725             122      True  2022
# 3133   Twitter for iPhone       110553725             122      True  2022
# 3134   Twitter for iPhone       110553725             122      True  2022
#
#                            mentions                 sentiment  year
# 0                                 _  ['positive', 0.70848316]  2022
# 1                                 _   ['neutral', 0.90077394]  2022
# 2                   Gfilche,Twitter    ['neutral', 0.5714027]  2022
# 3                       PeterSchiff  ['positive', 0.78971434]  2022
# 4                         ZubyMusic    ['neutral', 0.5287457]  2022
# ...                             ...                       ...   ...
# 3130                              _   ['neutral', 0.47640553]  2022
# 3131                              _   ['positive', 0.7544188]  2022
# 3132                              _  ['positive', 0.98015714]  2022
# 3133                  BLKMDL3,Tesla   ['positive', 0.5772162]  2022
# 3134  MiFSDBetaTester,WholeMarsBlog    ['neutral', 0.5714027]  2022
#
# [3135 rows x 20 columns]

# %%
elon_musk_2022.shape
# Out:
# (3135, 20)

# %% [markdown]
# ### CLEANING DATE ON ELON MUSK DF

# %%
df_musk_2022 = pd.DataFrame(elon_musk_2022[['Text', 'Datetime']])

# %%
df_musk_2022
# Out:
#                                                    Text  \
# 0                                     the bird is freed
# 1     Falcon rockets to orbit as seen from LA https:...
# 2                                   @Gfilche @Twitter 🤣
# 3                                 @PeterSchiff 🤣 thanks
# 4                                 @ZubyMusic Absolutely
# ...                                                 ...
# 3130                            https://t.co/LA9hPzVlGx
# 3131                Let’s make the roaring 20’s happen!
# 3132  Great work by Tesla team worldwide! https://t....
# 3133                                  @BLKMDL3 @Tesla 🔥
# 3134                  @MiFSDBetaTester @WholeMarsBlog 🤣
#
#                        Datetime
# 0     2022-10-28 03:49:11+00:00
# 1     2022-10-28 01:50:49+00:00
# 2     2022-10-27 21:45:47+00:00
# 3     2022-10-27 16:17:39+00:00
# 4     2022-10-27 13:19:25+00:00
# ...                         ...
# 3130  2022-01-02 22:56:00+00:00
# 3131  2022-01-02 18:19:33+00:00
# 3132  2022-01-02 17:56:50+00:00
# 3133  2022-01-01 01:58:52+00:00
# 3134  2022-01-01 00:53:13+00:00
#
# [3135 rows x 2 columns]

# %%
df_musk_2022['Datetime'] = pd.to_datetime(df_musk_2022['Datetime'])

# %%
df_musk_2022['Date_New'] = df_musk_2022['Datetime'].dt.date
# display the dataframe
print(df_musk_2022)
# Out:
#                                                    Text  \
# 0                                     the bird is freed
# 1     Falcon rockets to orbit as seen from LA https:...
# 2                                   @Gfilche @Twitter 🤣
# 3                                 @PeterSchiff 🤣 thanks
# 4                                 @ZubyMusic Absolutely
# ...                                                 ...
# 3130                            https://t.co/LA9hPzVlGx
# 3131                Let’s make the roaring 20’s happen!
# 3132  Great work by Tesla team worldwide! https://t....
# 3133                                  @BLKMDL3 @Tesla 🔥
# 3134                  @MiFSDBetaTester @WholeMarsBlog 🤣
#
#                       Datetime    Date_New
# 0    2022-10-28 03:49:11+00:00  2022-10-28
# 1    2022-10-28 01:50:49+00:00  2022-10-28
# 2    2022-10-27 21:45:47+00:00  2022-10-27
# 3    2022-10-27 16:17:39+00:00  2022-10-27
# 4    2022-10-27 13:19:25+00:00  2022-10-27
# ...                        ...         ...
# 3130 2022-01-02 22:56:00+00:00  2022-01-02
# 3131 2022-01-02 18:19:33+00:00  2022-01-02
# 3132 2022-01-02 17:56:50+00:00  2022-01-02
# 3133 2022-01-01 01:58:52+00:00  2022-01-01
# 3134 2022-01-01 00:53:13+00:00  2022-01-01
#
# [3135 rows x 3 columns]

# %%
df_musk_2022 = pd.DataFrame(elon_musk_2022[['Text', 'Date_New']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 df_musk_2022 = pd.DataFrame(elon_musk_2022[['Text', 'Date_New']])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Date_New'] not in index"

# %%
df_musk_2022
# Out:
#                                                    Text  \
# 0                                     the bird is freed
# 1     Falcon rockets to orbit as seen from LA https:...
# 2                                   @Gfilche @Twitter 🤣
# 3                                 @PeterSchiff 🤣 thanks
# 4                                 @ZubyMusic Absolutely
# ...                                                 ...
# 3130                            https://t.co/LA9hPzVlGx
# 3131                Let’s make the roaring 20’s happen!
# 3132  Great work by Tesla team worldwide! https://t....
# 3133                                  @BLKMDL3 @Tesla 🔥
# 3134                  @MiFSDBetaTester @WholeMarsBlog 🤣
#
#                       Datetime    Date_New
# 0    2022-10-28 03:49:11+00:00  2022-10-28
# 1    2022-10-28 01:50:49+00:00  2022-10-28
# 2    2022-10-27 21:45:47+00:00  2022-10-27
# 3    2022-10-27 16:17:39+00:00  2022-10-27
# 4    2022-10-27 13:19:25+00:00  2022-10-27
# ...                        ...         ...
# 3130 2022-01-02 22:56:00+00:00  2022-01-02
# 3131 2022-01-02 18:19:33+00:00  2022-01-02
# 3132 2022-01-02 17:56:50+00:00  2022-01-02
# 3133 2022-01-01 01:58:52+00:00  2022-01-01
# 3134 2022-01-01 00:53:13+00:00  2022-01-01
#
# [3135 rows x 3 columns]

# %%
df_musk_2022.columns
# Out:
# Index(['Text', 'Datetime', 'Date_New'], dtype='object')

# %%
df_musk_2022 = df_musk_2022.drop('Datetime', axis=1)

# %%
df_musk_2022
# Out:
#                                                    Text    Date_New
# 0                                     the bird is freed  2022-10-28
# 1     Falcon rockets to orbit as seen from LA https:...  2022-10-28
# 2                                   @Gfilche @Twitter 🤣  2022-10-27
# 3                                 @PeterSchiff 🤣 thanks  2022-10-27
# 4                                 @ZubyMusic Absolutely  2022-10-27
# ...                                                 ...         ...
# 3130                            https://t.co/LA9hPzVlGx  2022-01-02
# 3131                Let’s make the roaring 20’s happen!  2022-01-02
# 3132  Great work by Tesla team worldwide! https://t....  2022-01-02
# 3133                                  @BLKMDL3 @Tesla 🔥  2022-01-01
# 3134                  @MiFSDBetaTester @WholeMarsBlog 🤣  2022-01-01
#
# [3135 rows x 2 columns]

# %%
df_musk_2022.to_csv('df_musk_2022.csv')

# %% [markdown]
# ## API TWITTER

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /Users/saori/opt/anaconda3/lib/python3.9/site-packages (4.12.1)
# Requirement already satisfied: requests<3,>=2.27.0 in /Users/saori/opt/anaconda3/lib/python3.9/site-packages (from tweepy) (2.27.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /Users/saori/opt/anaconda3/lib/python3.9/site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /Users/saori/opt/anaconda3/lib/python3.9/site-packages (from tweepy) (3.2.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/saori/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/saori/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/saori/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/saori/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy

# %%
api_key = 'vcCmOETCASdUd0CpAdCtAT1H7'

api_secret = '8KEdeRxbIiQdRzC5oQFpJreC6b87I3LN2Sq6cwLXlkBB1aEGTw'

bearer_token = 'AAAAAAAAAAAAAAAAAAAAAKnFRAEAAAAA0WTW5LZ0FZm0YaTCHQpjYW2BzmI%3DAis5txxF8CKfT5UfsbcG9UznM61bmjCuN6FqlZwqJIjycjw9Hl'

access_token = '1410231389220376584-B2PrnZFEXKU6coWb3AEWGPODV4YJ9F'

access_token_secret = 'PPwZ8sh80xzCPochgHytGCzk3USP2RQkmUeRPqq2LqiHR'

auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# ### GET MY OWN TWEETS

# %%
public_tweets = api.home_timeline()
print(public_tweets)
# Out:
# [Status(_api=<tweepy.api.API object at 0x7ff8f1989970>, _json={'created_at': 'Tue Dec 06 15:39:05 +0000 2022', 'id': 1600152856337735680, 'id_str': '1600152856337735680', 'text': 'Today we see Stanislas feeding a dog with his feet until the dog puked.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">DumbStanislasBot</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1410231389220376584, 'id_str': '1410231389220376584', 'name': 'Dumb Stanislas', 'screen_name': 'DumbStanislas', 'location': '', 'description': 'Stanislas woud like to be a YouTuber but is to shy for taking the leap. So for now his mother writes tweets telling what her son could vlog about. His life.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 4, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Wed Jun 30 13:39:43 +0000 2021', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 456, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1410232965427351553/cUVEY018_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1410232965427351553/cUVEY018_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 12, 6, 15, 39, 5, tzinfo=datetime.timezone.utc), id=1600152856337735680, id_str='1600152856337735680', text='Today we see Stanislas feeding a dog with his feet until the dog puked.', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='DumbStanislasBot', source_url='https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7ff8f1989970>, _json={'id': 1410231389220376584, 'id_str': '1410231389220376584', 'name': 'Dumb Stanislas', 'screen_name': 'DumbStanislas', 'location': '', 'description': 'Stanislas woud like to be a YouTuber but is to shy for taking the leap. So for now his mother writes tweets telling what her son could vlog about. His life.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 4, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Wed Jun 30 13:39:43 +0000 2021', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 456, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1410232965427351553/cUVEY018_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_image ...

# %%
import pandas as pd

# create dataframe
columns = ['Time', 'User', 'Tweet']

data = []
for tweet in public_tweets:
    data.append([tweet.created_at, tweet.user.screen_name, tweet.text])

df = pd.DataFrame(data, columns=columns)

df.to_csv('tweets.csv')

# %%
df
# Out:
#                         Time           User  \
# 0  2022-12-06 15:39:05+00:00  DumbStanislas
# 1  2022-12-04 15:39:06+00:00  DumbStanislas
# 2  2022-12-03 15:39:05+00:00  DumbStanislas
# 3  2022-12-02 15:39:06+00:00  DumbStanislas
# 4  2022-12-01 15:39:05+00:00  DumbStanislas
# 5  2022-11-30 15:39:05+00:00  DumbStanislas
# 6  2022-11-29 15:39:05+00:00  DumbStanislas
# 7  2022-11-28 15:39:05+00:00  DumbStanislas
# 8  2022-11-26 15:39:05+00:00  DumbStanislas
# 9  2022-11-25 15:39:05+00:00  DumbStanislas
# 10 2022-11-24 15:39:05+00:00  DumbStanislas
# 11 2022-11-23 15:39:05+00:00  DumbStanislas
# 12 2022-11-22 15:39:07+00:00  DumbStanislas
# 13 2022-11-21 15:39:06+00:00  DumbStanislas
# 14 2022-11-20 15:39:05+00:00  DumbStanislas
# 15 2022-11-19 15:39:06+00:00  DumbStanislas
# 16 2022-11-18 15:39:06+00:00  DumbStanislas
# 17 2022-11-17 15:39:06+00:00  DumbStanislas
# 18 2022-11-16 15:39:05+00:00  DumbStanislas
# 19 2022-11-15 15:39:07+00:00  DumbStanislas
#
#                                                 Tweet
# 0   Today we see Stanislas feeding a dog with his ...
# 1   Today Stanislas and his friends decided to sta...
# 2   Today, july 1st is the day of the pride. Stani...
# 3   Today Stanislas had to choose between a red th...
# 4   Today Stanislas was too lazy to talk about hai...
# 5   Today Stanislas tried to make food without ing...
# 6   Today Stanislas is on a mission. He will accom...
# 7   Today Stanislas tries to like a baby. Has he c...
# 8   Today Stanislas wanted to prove if people at t...
# 9   Today Stanislas explored his body to see what ...
# 10  Today Stanislas is on a video trip with his fr...
# 11  That's the story of Clémence. A pretty quiet g...
# 12  Today Stanislas tried to make a rocket to trav...
# 13  Today Stanislas and his friends decided to thi...
# 14  Today Stanislas went to a car rental to do a d...
# 15  Today Stanislas pulled a prank on a couple, wh...
# 16  Today Stanislas decided that he was going to t...
# 17  Today is the one year anniversary of the death...
# 18  Today Stanislas got confronted by one of his a...
# 19  Today Stanislas get a package that said "puzzl...

# %% [markdown]
# ### TESLA # TWEETS

# %%
import tweepy

#Put your Bearer Token in the parenthesis below
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAKnFRAEAAAAA0WTW5LZ0FZm0YaTCHQpjYW2BzmI%3DAis5txxF8CKfT5UfsbcG9UznM61bmjCuN6FqlZwqJIjycjw9Hl')

"""
If you don't understand search queries, there is an excellent introduction to it here: 
https://github.com/twitterdev/getting-started-with-the-twitter-api-v2-for-academic-research/blob/main/modules/5-how-to-write-search-queries.md
"""

# Get tweets that contain the hashtag #petday
# -is:retweet means I don't want retweets
# lang:en is asking for the tweets to be in english
query = '#tesla -is:retweet lang:en'
tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)
tweets[0][1]
# Out:
# <Tweet id=1600843539373498369 text='Around 200 #Model3 and #ModelY are waiting for their new owners in #Tesla Service Center Bremen/Ottersberg in Germany. Additional space had to be rented for the upcoming wave of cars, including MS and MX. Arrival of new cars each day. @AllThingsTSLA @DirtyTesLa @TeslaOwnersDEU https://t.co/2bajg1BWTw'>

# %%
tweets[0][2]
# Out:
# <Tweet id=1600843519736057857 text='@elonmusk - less Tweeting and more Tesla-ing. Rgds, a $tsla owner. #tesla'>

# %%
tweets, likes, time = [], [], []

cursor = tweepy.Cursor(api.user_timeline, id='elonmusk', tweet_mode="extendet").items(1300)

for tweet in tweepy.Cursor(api.user_timeline, id='elonmusk', tweet_mode="extendet").items(1300):
    tweets.append(tweet.text)
    time.append(tweet.created_at)
    
musk_new = pd.DataFrame(data=[tweets, time]).T
musk_new.columns = ["tweets", "time"]
musk_new
# Out:
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
#                                                  tweets  \
# 0                   Woke v Woke https://t.co/hmhC5eelik
# 1                            @EthanBitcoin @dergigi lol
# 2                @EddieZipperer https://t.co/92voOIH5d8
# 3     RT @teslaownersSV: Tesla Semi is super quiet w...
# 4     RT @SpaceX: Teams completed additional vehicle...
# ...                                                 ...
# 1295  @ThorstenBasch @spideycyp_155 @BillyM2k Russia...
# 1296  @spideycyp_155 @BillyM2k If Russia faced calam...
# 1297                    @jamesplloyd @SpaceX I do. Yes.
# 1298  @spideycyp_155 @BillyM2k Still very unlikely, ...
# 1299  @teslaownersSV @BillyM2k Just guessing, but pr...
#
#                           time
# 0    2022-12-08 09:44:29+00:00
# 1    2022-12-08 09:25:59+00:00
# 2    2022-12-08 07:20:25+00:00
# 3    2022-12-08 02:31:37+00:00
# 4    2022-12-07 22:24:57+00:00
# ...                        ...
# 1295 2022-10-21 05:45:12+00:00
# 1296 2022-10-21 05:12:37+00:00
# 1297 2022-10-21 05:09:52+00:00
# 1298 2022-10-21 05:06:29+00:00
# 1299 2022-10-21 04:53:50+00:00
#
# [1300 rows x 2 columns]

# %%
musk_new['Date_New'] = musk_new['time'].dt.date
# display the dataframe
print(musk_new)
# Out:
#                                                  tweets  \
# 0                   Woke v Woke https://t.co/hmhC5eelik
# 1                            @EthanBitcoin @dergigi lol
# 2                @EddieZipperer https://t.co/92voOIH5d8
# 3     RT @teslaownersSV: Tesla Semi is super quiet w...
# 4     RT @SpaceX: Teams completed additional vehicle...
# ...                                                 ...
# 1295  @ThorstenBasch @spideycyp_155 @BillyM2k Russia...
# 1296  @spideycyp_155 @BillyM2k If Russia faced calam...
# 1297                    @jamesplloyd @SpaceX I do. Yes.
# 1298  @spideycyp_155 @BillyM2k Still very unlikely, ...
# 1299  @teslaownersSV @BillyM2k Just guessing, but pr...
#
#                           time    Date_New
# 0    2022-12-08 09:44:29+00:00  2022-12-08
# 1    2022-12-08 09:25:59+00:00  2022-12-08
# 2    2022-12-08 07:20:25+00:00  2022-12-08
# 3    2022-12-08 02:31:37+00:00  2022-12-08
# 4    2022-12-07 22:24:57+00:00  2022-12-07
# ...                        ...         ...
# 1295 2022-10-21 05:45:12+00:00  2022-10-21
# 1296 2022-10-21 05:12:37+00:00  2022-10-21
# 1297 2022-10-21 05:09:52+00:00  2022-10-21
# 1298 2022-10-21 05:06:29+00:00  2022-10-21
# 1299 2022-10-21 04:53:50+00:00  2022-10-21
#
# [1300 rows x 3 columns]

# %%
musk_new.columns
# Out:
# Index(['tweets', 'time', 'Date_New'], dtype='object')

# %%
musk_nov_dec_2022 = pd.DataFrame(musk_new[['tweets', 'Date_New']])

# %%
musk_nov_dec_2022
# Out:
#                                                  tweets    Date_New
# 0                   Woke v Woke https://t.co/hmhC5eelik  2022-12-08
# 1                            @EthanBitcoin @dergigi lol  2022-12-08
# 2                @EddieZipperer https://t.co/92voOIH5d8  2022-12-08
# 3     RT @teslaownersSV: Tesla Semi is super quiet w...  2022-12-08
# 4     RT @SpaceX: Teams completed additional vehicle...  2022-12-07
# ...                                                 ...         ...
# 1295  @ThorstenBasch @spideycyp_155 @BillyM2k Russia...  2022-10-21
# 1296  @spideycyp_155 @BillyM2k If Russia faced calam...  2022-10-21
# 1297                    @jamesplloyd @SpaceX I do. Yes.  2022-10-21
# 1298  @spideycyp_155 @BillyM2k Still very unlikely, ...  2022-10-21
# 1299  @teslaownersSV @BillyM2k Just guessing, but pr...  2022-10-21
#
# [1300 rows x 2 columns]

# %%
delate = musk_new[musk_new['Date_New'].between(pd.to_datetime("21/10/2022"), pd.to_datetime("28/10/2022"))]
# Out:
# /var/folders/wt/6z_4m2nx6w38qbh8gzrxfdcm0000gp/T/ipykernel_14448/183461897.py:1: UserWarning: Parsing '21/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   delate = musk_new[musk_new['Date_New'].between(pd.to_datetime("21/10/2022"), pd.to_datetime("28/10/2022"))]
# /var/folders/wt/6z_4m2nx6w38qbh8gzrxfdcm0000gp/T/ipykernel_14448/183461897.py:1: UserWarning: Parsing '28/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   delate = musk_new[musk_new['Date_New'].between(pd.to_datetime("21/10/2022"), pd.to_datetime("28/10/2022"))]
# /Users/saori/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)

# %%
len(delate)
# Out:
# 119

# %%
musk_new.drop(musk_new.tail(129).index,inplace=True)

# %%
musk_new
# Out:
#                                                  tweets  \
# 0                   Woke v Woke https://t.co/hmhC5eelik
# 1                            @EthanBitcoin @dergigi lol
# 2                @EddieZipperer https://t.co/92voOIH5d8
# 3     RT @teslaownersSV: Tesla Semi is super quiet w...
# 4     RT @SpaceX: Teams completed additional vehicle...
# ...                                                 ...
# 1166  @TomFitton @Twitter @JustTheNews I will look i...
# 1167                 @danzwku @ID_AA_Carmack Absolutely
# 1168                             @ID_AA_Carmack d(he)ll
# 1169  @WholeMarsBlog @karpathy Andrej will always be...
# 1170                                      @lexfridman 🤣
#
#                           time    Date_New
# 0    2022-12-08 09:44:29+00:00  2022-12-08
# 1    2022-12-08 09:25:59+00:00  2022-12-08
# 2    2022-12-08 07:20:25+00:00  2022-12-08
# 3    2022-12-08 02:31:37+00:00  2022-12-08
# 4    2022-12-07 22:24:57+00:00  2022-12-07
# ...                        ...         ...
# 1166 2022-10-30 04:11:36+00:00  2022-10-30
# 1167 2022-10-30 03:39:17+00:00  2022-10-30
# 1168 2022-10-30 03:36:16+00:00  2022-10-30
# 1169 2022-10-30 01:37:23+00:00  2022-10-30
# 1170 2022-10-29 18:14:45+00:00  2022-10-29
#
# [1171 rows x 3 columns]

# %%
musk_new.to_csv('musk_new.csv')

# %%
"""
What context_annotations are: 
https://developer.twitter.com/en/docs/twitter-api/annotations/overview
"""
x  = []
for tweet in tweets.data:
    print(tweet.text)
    if len(tweet.context_annotations) > 0:
        print(tweet.context_annotations)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [167], in <cell line: 6>()
#       1 """
#       2 What context_annotations are:
#       3 https://developer.twitter.com/en/docs/twitter-api/annotations/overview
#       4 """
#       5 x  = []
# ----> 6 for tweet in tweets.data:
#       7     print(tweet.text)
#       8     if len(tweet.context_annotations) > 0:
#
# AttributeError: 'list' object has no attribute 'data'

# %%
#tweets, tweets_date = [], []
for index, element in enumerate(tweets.data):
    print(tweets.data[index].created_at, tweets.data[index])
    #tweets.append(tweets.data[index])
    #tweets_date.append(tweets.data[index].created_at)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [168], in <cell line: 2>()
#       1 #tweets, tweets_date = [], []
# ----> 2 for index, element in enumerate(tweets.data):
#       3     print(tweets.data[index].created_at, tweets.data[index])
#
# AttributeError: 'list' object has no attribute 'data'

# %%
tweets.data[0].created_at
# Out:
# datetime.datetime(2022, 12, 8, 10, 57, 48, tzinfo=datetime.timezone.utc)

# %%
import pandas as pd

# create dataframe
columns = ['Time', 'User', 'Tweet']

tesla = []
for tweet in tweets.data:
    tesla.append([tweet.created_at, tweet.user.screen_name, tweet.text])

df_tesla = pd.DataFrame(data, columns=columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [92], in <cell line: 7>()
#       6 tesla = []
#       7 for tweet in tweets.data:
# ----> 8     tesla.append([tweet.created_at, tweet.user.screen_name, tweet.text])
#      10 df_tesla = pd.DataFrame(data, columns=columns)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/mixins.py:35, in DataMapping.__getattr__(self, name)
#      33     return self.data[name]
#      34 except KeyError:
# ---> 35     raise AttributeError from None
#
# AttributeError:

# %%
import tweepy
import config
import json
def getClient():
    client = tweepy.Client(bearer_token=config.BEARER_TOKEN,
                           consumer_key=config.API_KEY,
                           consumer_secret=config.API_KEY_SECRET,
                           access_token=config.ACCESS_TOKEN,
                           access_token_secret=config.ACCESS_TOKEN_SECRET)
    return client
def searchTweets(client, query, max_results):
tweets = client.search_recent_tweets(query=query, max_results=max_results)
tweet_data =  tweets.data
    results = []
if not tweet_data is None and len(tweet_data) > 0:
        for tweet in tweet_data:
            obj = {}
            obj['id'] = tweet.id
            obj['text'] = tweet.text
            results.append(obj)
return results
def getTweet(client, id):
    tweet = client.get_tweet(id, expansions=['author_id'], user_fields=['username'])
    return tweet
def returnSearchTweetList(query, max_results):
    client = getClient()
    tweets = searchTweets(client, query, max_results)
objs = []
if len(tweets) > 0:
        for tweet in tweets:
            twt = getTweet(client, tweet['id'])
            obj = {}
            obj['text'] = tweet['text']
            obj['username'] = twt.includes['users'][0].username
            obj['id'] = tweet['id']
            obj['url'] = 'https://twitter.com/{}/status/{}'.format(twt.includes['users'][0].username, tweet['id'])
            objs.append(obj)
return objs
def retweet(id):
    client = getClient()
    client.retweet(id)
# Out:
#   Input In [169]
#     tweets = client.search_recent_tweets(query=query, max_results=max_results)
#     ^
# IndentationError: expected an indented block
