# %% [markdown]
# # Sentimental Analysis

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns
import re
# %matplotlib inline

# %% [markdown]
# ## Elon's tweets before Twitter acquisition

# %%
tw_list = pd.read_csv('df_musk_2022.csv')

# %%
tw_list
# Out:
#       Unnamed: 0                                               Text  \
# 0              0                                  the bird is freed
# 1              1  Falcon rockets to orbit as seen from LA https:...
# 2              2                                @Gfilche @Twitter 🤣
# 3              3                              @PeterSchiff 🤣 thanks
# 4              4                              @ZubyMusic Absolutely
# ...          ...                                                ...
# 3130        3130                            https://t.co/LA9hPzVlGx
# 3131        3131                Let’s make the roaring 20’s happen!
# 3132        3132  Great work by Tesla team worldwide! https://t....
# 3133        3133                                  @BLKMDL3 @Tesla 🔥
# 3134        3134                  @MiFSDBetaTester @WholeMarsBlog 🤣
#
#         Date_New
# 0     2022-10-28
# 1     2022-10-28
# 2     2022-10-27
# 3     2022-10-27
# 4     2022-10-27
# ...          ...
# 3130  2022-01-02
# 3131  2022-01-02
# 3132  2022-01-02
# 3133  2022-01-01
# 3134  2022-01-01
#
# [3135 rows x 3 columns]

# %%
tw_list.drop('Unnamed: 0', inplace=True, axis=1)

# %%
tw_list
# Out:
#                                                    Text    Date_New
# 0                                     the bird is freed  2022-10-28
# 1     Falcon rockets to orbit as seen from LA https:...  2022-10-28
# 2                                   @Gfilche @Twitter 🤣  2022-10-27
# 3                                 @PeterSchiff 🤣 thanks  2022-10-27
# 4                                 @ZubyMusic Absolutely  2022-10-27
# ...                                                 ...         ...
# 3130                            https://t.co/LA9hPzVlGx  2022-01-02
# 3131                Let’s make the roaring 20’s happen!  2022-01-02
# 3132  Great work by Tesla team worldwide! https://t....  2022-01-02
# 3133                                  @BLKMDL3 @Tesla 🔥  2022-01-01
# 3134                  @MiFSDBetaTester @WholeMarsBlog 🤣  2022-01-01
#
# [3135 rows x 2 columns]

# %% [markdown]
# ## Creating a Data Frame from tweets

# %%
#Data frame from Elons tweets clean
tw_list["tweet"] = tw_list['Text']

#Removing RT, Punctuation etc
remove_rt = lambda x: re.sub('RT @\w+: '," ",x)
rt = lambda x: re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",x)
tw_list["tweet"] = tw_list.tweet.map(remove_rt).map(rt)
tw_list["tweet"] = tw_list.tweet.str.lower()
tw_list.head(10)
# Out:
#                                                 Text    Date_New  \
# 0                                  the bird is freed  2022-10-28
# 1  Falcon rockets to orbit as seen from LA https:...  2022-10-28
# 2                                @Gfilche @Twitter 🤣  2022-10-27
# 3                              @PeterSchiff 🤣 thanks  2022-10-27
# 4                              @ZubyMusic Absolutely  2022-10-27
# 5   Dear Twitter Advertisers https://t.co/GMwHmInPAS  2022-10-27
# 6                                        @BillyM2k 👻  2022-10-27
# 7     Meeting a lot of cool people at Twitter today!  2022-10-26
# 8  Entering Twitter HQ – let that sink in! https:...  2022-10-26
# 9                       @dogeofficialceo @mtaibbi 🤣💪  2022-10-26
#
#                                             tweet
# 0                               the bird is freed
# 1       falcon rockets to orbit as seen from la
# 2
# 3                                          thanks
# 4                                      absolutely
# 5                      dear twitter advertisers
# 6
# 7  meeting a lot of cool people at twitter today
# 8       entering twitter hq   let that sink in
# 9

# %% [markdown]
# ## TextBlob for sentimental Analysis

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\javie\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\javie\anaconda3\lib\site-packages (from textblob) (3.6.5)
# Requirement already satisfied: click in c:\users\javie\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.3)
# Requirement already satisfied: joblib in c:\users\javie\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\javie\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2021.8.3)
# Requirement already satisfied: tqdm in c:\users\javie\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.62.3)
# Requirement already satisfied: colorama in c:\users\javie\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('tagsets')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\javie\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\javie\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\javie\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\javie\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\javie\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#Calculating Negative, Positive, Neutral and Compound values

tw_list[['polarity', 'subjectivity']] = tw_list['tweet'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, row in tw_list['tweet'].iteritems():
    score = SentimentIntensityAnalyzer().polarity_scores(row)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    if neg > pos:
        tw_list.loc[index, 'sentiment'] = "negative"
    elif pos > neg:
        tw_list.loc[index, 'sentiment'] = "positive"
    else:
        tw_list.loc[index, 'sentiment'] = "neutral"
    tw_list.loc[index, 'neg'] = neg
    tw_list.loc[index, 'neu'] = neu
    tw_list.loc[index, 'pos'] = pos
    tw_list.loc[index, 'compound'] = comp

tw_list.head(10)
# Out:
#                                                 Text    Date_New  \
# 0                                  the bird is freed  2022-10-28
# 1  Falcon rockets to orbit as seen from LA https:...  2022-10-28
# 2                                @Gfilche @Twitter 🤣  2022-10-27
# 3                              @PeterSchiff 🤣 thanks  2022-10-27
# 4                              @ZubyMusic Absolutely  2022-10-27
# 5   Dear Twitter Advertisers https://t.co/GMwHmInPAS  2022-10-27
# 6                                        @BillyM2k 👻  2022-10-27
# 7     Meeting a lot of cool people at Twitter today!  2022-10-26
# 8  Entering Twitter HQ – let that sink in! https:...  2022-10-26
# 9                       @dogeofficialceo @mtaibbi 🤣💪  2022-10-26
#
#                                             tweet  polarity  subjectivity  \
# 0                               the bird is freed      0.00          0.00
# 1       falcon rockets to orbit as seen from la        0.00          0.00
# 2                                                      0.00          0.00
# 3                                          thanks      0.20          0.20
# 4                                      absolutely      0.20          0.90
# 5                      dear twitter advertisers        0.00          0.00
# 6                                                      0.00          0.00
# 7  meeting a lot of cool people at twitter today       0.35          0.65
# 8       entering twitter hq   let that sink in         0.00          0.00
# 9                                                      0.00          0.00
#
#   sentiment  neg    neu    pos  compound
# 0  positive  0.0  0.526  0.474    0.4019
# 1   neutral  0.0  1.000  0.000    0.0000
# 2   neutral  0.0  0.000  0.000    0.0000
# 3  positive  0.0  0.000  1.000    0.4404
# 4   neutral  0.0  1.000  0.000    0.0000
# 5  positive  0.0  0.435  0.565    0.3818
# 6   neutral  0.0  0.000  0.000    0.0000
# 7  positive  0.0  0.753  0.247    0.3182
# 8   neutral  0.0  1.000  0.000    0.0000
# 9   neutral  0.0  0.000  0.000    0.0000

# %%
tw_list['date']=pd.to_datetime(tw_list['Date_New'], format='%Y-%m-%d')
tw_list.head()
# Out:
#                                                 Text    Date_New  \
# 0                                  the bird is freed  2022-10-28
# 1  Falcon rockets to orbit as seen from LA https:...  2022-10-28
# 2                                @Gfilche @Twitter 🤣  2022-10-27
# 3                              @PeterSchiff 🤣 thanks  2022-10-27
# 4                              @ZubyMusic Absolutely  2022-10-27
#
#                                        tweet  polarity  subjectivity  \
# 0                          the bird is freed       0.0           0.0
# 1  falcon rockets to orbit as seen from la         0.0           0.0
# 2                                                  0.0           0.0
# 3                                     thanks       0.2           0.2
# 4                                 absolutely       0.2           0.9
#
#   sentiment  neg    neu    pos  compound       date
# 0  positive  0.0  0.526  0.474    0.4019 2022-10-28
# 1   neutral  0.0  1.000  0.000    0.0000 2022-10-28
# 2   neutral  0.0  0.000  0.000    0.0000 2022-10-27
# 3  positive  0.0  0.000  1.000    0.4404 2022-10-27
# 4   neutral  0.0  1.000  0.000    0.0000 2022-10-27

# %%
tw_list.loc[tw_list['sentiment']=='negative']
# Out:
#                                                    Text    Date_New  \
# 16    “The New York Times has emerged as a new, chao...  2022-10-26
# 23    @VitalikButerin @balajis @zengjiajun_eth Had t...  2022-10-25
# 46    @spideycyp_155 @SquawkCNBC @Kasparov63 I did a...  2022-10-24
# 47    @SquawkCNBC @Kasparov63 And I don’t even own a...  2022-10-24
# 53    @Teslarati @Writer_01001101 Before DoD even ca...  2022-10-24
# ...                                                 ...         ...
# 3104  @APompliano If the alarming collapse in birth ...  2022-01-10
# 3109  @WholeMarsBlog It was a mistake to try to use ...  2022-01-07
# 3124      @wintonARK Absolutely. This is just bad math.  2022-01-03
# 3126  Raptor 2 now operates routinely at 300 bar mai...  2022-01-03
# 3129  @auren There is no way to be in touch with vot...  2022-01-03
#
#                                                   tweet  polarity  \
# 16     the new york times has emerged as a new  chao...  0.193182
# 23          eth had to do a double take  this is the... -0.083333
# 46      155     i did as a child  but found it to be...  0.062500
# 47        and i don t even own a house  let alone a ...  0.600000
# 53        01001101 before dod even came back with an...  0.000000
# ...                                                 ...       ...
# 3104    if the alarming collapse in birth rate conti...  0.000000
# 3109    it was a mistake to try to use the elise  in...  0.000000
# 3124                 absolutely  this is just bad math  -0.250000
# 3126  raptor 2 now operates routinely at 300 bar mai...  0.166667
# 3129    there is no way to be in touch with voters w...  0.000000
#
#       subjectivity sentiment    neg    neu    pos  compound       date
# 16        0.352273  negative  0.192  0.808  0.000   -0.7642 2022-10-26
# 23        0.444444  negative  0.154  0.846  0.000   -0.4767 2022-10-25
# 46        0.379018  negative  0.239  0.694  0.067   -0.8720 2022-10-24
# 47        1.000000  negative  0.360  0.640  0.000   -0.5423 2022-10-24
# 53        0.000000  negative  0.087  0.913  0.000   -0.2960 2022-10-24
# ...            ...       ...    ...    ...    ...       ...        ...
# 3104      0.450000  negative  0.381  0.619  0.000   -0.8225 2022-01-10
# 3109      0.800000  negative  0.085  0.915  0.000   -0.3400 2022-01-07
# 3124      0.783333  negative  0.412  0.588  0.000   -0.5423 2022-01-03
# 3126      0.333333  negative  0.196  0.804  0.000   -0.2960 2022-01-03
# 3129      0.000000  negative  0.109  0.891  0.000   -0.2960 2022-01-03
#
# [474 rows x 11 columns]

# %%
tw_list.describe()
# Out:
#           polarity  subjectivity          neg          neu          pos  \
# count  3135.000000   3135.000000  3135.000000  3135.000000  3135.000000
# mean      0.105295      0.308521     0.054423     0.640924     0.177697
# std       0.255713      0.320877     0.133518     0.368996     0.277586
# min      -1.000000      0.000000     0.000000     0.000000     0.000000
# 25%       0.000000      0.000000     0.000000     0.397500     0.000000
# 50%       0.000000      0.250000     0.000000     0.753000     0.000000
# 75%       0.202722      0.560208     0.000000     1.000000     0.257500
# max       1.000000      1.000000     1.000000     1.000000     1.000000
#
#           compound
# count  3135.000000
# mean      0.121672
# std       0.350103
# min      -0.951000
# 25%       0.000000
# 50%       0.000000
# 75%       0.401900
# max       0.959500

# %%
s1mask = np.isfinite(tw_list['neg']) #to skip missing values (only works for int)

plt.figure(figsize=(20,5))
plt.plot_date(tw_list['date'], tw_list['neg'] ,linestyle ='solid')

plt.xlabel("date")
plt.ylabel("sentiment")
plt.title("Elon's tweets before acquisition Price 1.01.22 - 28.10.22");

# %%
tw_list.to_csv('Elon_tweets_before.csv')

# %% [markdown]
# ## Tesla stock value

# %%
tesla_stock= pd.read_csv('Data/tesla_stock2022.csv')
tesla_stock.head()
# Out:
#    Unnamed: 0    close     high      low     open        date
# 0  2022-01-03  399.927  400.357  378.680  382.583  2022-01-03
# 1  2022-01-04  383.197  402.667  374.350  396.517  2022-01-04
# 2  2022-01-05  362.707  390.113  360.337  382.217  2022-01-05
# 3  2022-01-06  354.900  362.667  340.167  359.000  2022-01-06
# 4  2022-01-07  342.320  360.310  336.667  360.123  2022-01-07

# %%
tesla_stock['date']=pd.to_datetime(tesla_stock['date'], format='%Y-%m-%d')
tesla_stock.head()
# Out:
#    Unnamed: 0    close     high      low     open       date
# 0  2022-01-03  399.927  400.357  378.680  382.583 2022-01-03
# 1  2022-01-04  383.197  402.667  374.350  396.517 2022-01-04
# 2  2022-01-05  362.707  390.113  360.337  382.217 2022-01-05
# 3  2022-01-06  354.900  362.667  340.167  359.000 2022-01-06
# 4  2022-01-07  342.320  360.310  336.667  360.123 2022-01-07

# %%
stock_tweet = pd.merge(tesla_stock,tw_list,on="date",how="inner")
stock_tweet.head()
# Out:
#    Unnamed: 0    close     high     low     open       date  \
# 0  2022-01-03  399.927  400.357  378.68  382.583 2022-01-03
# 1  2022-01-03  399.927  400.357  378.68  382.583 2022-01-03
# 2  2022-01-03  399.927  400.357  378.68  382.583 2022-01-03
# 3  2022-01-03  399.927  400.357  378.68  382.583 2022-01-03
# 4  2022-01-03  399.927  400.357  378.68  382.583 2022-01-03
#
#                                                 Text    Date_New  \
# 0      @wintonARK Absolutely. This is just bad math.  2022-01-03
# 1                 @nextspaceflight @BocaChicaGal Yes  2022-01-03
# 2  Raptor 2 now operates routinely at 300 bar mai...  2022-01-03
# 3  @jack Reminds me of when I hex edited Ultima V...  2022-01-03
# 4  @ClaudioOmbrella @Tesla @slcuervo @alex_avoigt...  2022-01-03
#
#                                                tweet  polarity  subjectivity  \
# 0                 absolutely  this is just bad math  -0.250000      0.783333
# 1                                                yes  0.000000      0.000000
# 2  raptor 2 now operates routinely at 300 bar mai...  0.166667      0.333333
# 3    reminds me of when i hex edited ultima v to ...  0.000000      1.000000
# 4            avoigt             yay switzerland       0.000000      0.000000
#
#   sentiment    neg    neu   pos  compound
# 0  negative  0.412  0.588  0.00   -0.5423
# 1  positive  0.000  0.000  1.00    0.4019
# 2  negative  0.196  0.804  0.00   -0.2960
# 3   neutral  0.000  1.000  0.00    0.0000
# 4  positive  0.000  0.370  0.63    0.5267

# %%
stock_tweet = stock_tweet[['date','tweet','close','polarity','subjectivity','neg','neu','pos','compound','sentiment']]
stock_tweet.head()
# Out:
#         date                                              tweet    close  \
# 0 2022-01-03                 absolutely  this is just bad math   399.927
# 1 2022-01-03                                                yes  399.927
# 2 2022-01-03  raptor 2 now operates routinely at 300 bar mai...  399.927
# 3 2022-01-03    reminds me of when i hex edited ultima v to ...  399.927
# 4 2022-01-03            avoigt             yay switzerland       399.927
#
#    polarity  subjectivity    neg    neu   pos  compound sentiment
# 0 -0.250000      0.783333  0.412  0.588  0.00   -0.5423  negative
# 1  0.000000      0.000000  0.000  0.000  1.00    0.4019  positive
# 2  0.166667      0.333333  0.196  0.804  0.00   -0.2960  negative
# 3  0.000000      1.000000  0.000  1.000  0.00    0.0000   neutral
# 4  0.000000      0.000000  0.000  0.370  0.63    0.5267  positive

# %%
stock_tweet
# Out:
#            date                                              tweet    close  \
# 0    2022-01-03                 absolutely  this is just bad math   399.927
# 1    2022-01-03                                                yes  399.927
# 2    2022-01-03  raptor 2 now operates routinely at 300 bar mai...  399.927
# 3    2022-01-03    reminds me of when i hex edited ultima v to ...  399.927
# 4    2022-01-03            avoigt             yay switzerland       399.927
# ...         ...                                                ...      ...
# 2206 2022-10-27                                         absolutely  225.090
# 2207 2022-10-27                         dear twitter advertisers    225.090
# 2208 2022-10-27                                                     225.090
# 2209 2022-10-28                                  the bird is freed  228.520
# 2210 2022-10-28          falcon rockets to orbit as seen from la    228.520
#
#       polarity  subjectivity    neg    neu    pos  compound sentiment
# 0    -0.250000      0.783333  0.412  0.588  0.000   -0.5423  negative
# 1     0.000000      0.000000  0.000  0.000  1.000    0.4019  positive
# 2     0.166667      0.333333  0.196  0.804  0.000   -0.2960  negative
# 3     0.000000      1.000000  0.000  1.000  0.000    0.0000   neutral
# 4     0.000000      0.000000  0.000  0.370  0.630    0.5267  positive
# ...        ...           ...    ...    ...    ...       ...       ...
# 2206  0.200000      0.900000  0.000  1.000  0.000    0.0000   neutral
# 2207  0.000000      0.000000  0.000  0.435  0.565    0.3818  positive
# 2208  0.000000      0.000000  0.000  0.000  0.000    0.0000   neutral
# 2209  0.000000      0.000000  0.000  0.526  0.474    0.4019  positive
# 2210  0.000000      0.000000  0.000  1.000  0.000    0.0000   neutral
#
# [2211 rows x 10 columns]

# %%
stock_comp= stock_tweet.groupby(['date','close'])['polarity','subjectivity','neg','neu','pos','compound'].mean()
#stock_comp=stock_comp.to_frame()
stock_comp=stock_comp.reset_index()
stock_comp
# Out:
# C:\Users\javie\AppData\Local\Temp/ipykernel_21520/1490080670.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   stock_comp= stock_tweet.groupby(['date','close'])['polarity','subjectivity','neg','neu','pos','compound'].mean()
#           date    close  polarity  subjectivity       neg       neu       pos  \
# 0   2022-01-03  399.927 -0.013889      0.352778  0.119500  0.608833  0.271667
# 1   2022-01-04  383.197  0.166667      0.166667  0.000000  0.666667  0.000000
# 2   2022-01-05  362.707  0.000000      0.000000  0.000000  0.204000  0.296000
# 3   2022-01-06  354.900  0.350000      0.437500  0.062500  0.592500  0.345000
# 4   2022-01-07  342.320  0.000119      0.252976  0.014167  0.969500  0.016333
# ..         ...      ...       ...           ...       ...       ...       ...
# 186 2022-10-24  211.250  0.151534      0.382190  0.062100  0.510500  0.227350
# 187 2022-10-25  222.415  0.035883      0.152297  0.021385  0.526462  0.144462
# 188 2022-10-26  224.640  0.099513      0.156412  0.013714  0.603857  0.168143
# 189 2022-10-27  225.090  0.080000      0.220000  0.000000  0.287000  0.313000
# 190 2022-10-28  228.520  0.000000      0.000000  0.000000  0.763000  0.237000
#
#      compound
# 0   -0.034283
# 1    0.000000
# 2    0.220200
# 3    0.190375
# 4    0.003533
# ..        ...
# 186  0.108305
# 187  0.107638
# 188  0.146464
# 189  0.164440
# 190  0.200950
#
# [191 rows x 8 columns]

# %%
corr = stock_comp.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(9, 7))
    ax = sns.heatmap(corr, mask=mask,cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %%
#DataFrame to csv
stock_comp.to_csv('Tesla_Elon_stock.csv')

# %% [markdown]
# ## Elon's tweet after Twitter acquisition

# %%
tw_aft = pd.read_csv('musk_new.csv')

# %%
tw_aft.head()
# Out:
#    Unnamed: 0                                               Text    Date_New
# 0           0                Woke v Woke https://t.co/hmhC5eelik  2022-12-08
# 1           1                         @EthanBitcoin @dergigi lol  2022-12-08
# 2           2             @EddieZipperer https://t.co/92voOIH5d8  2022-12-08
# 3           3  RT @teslaownersSV: Tesla Semi is super quiet w...  2022-12-08
# 4           4  RT @SpaceX: Teams completed additional vehicle...  2022-12-07

# %%
tw_aft.drop('Unnamed: 0', inplace=True, axis=1)
tw_aft.head()
# Out:
#                                                 Text    Date_New
# 0                Woke v Woke https://t.co/hmhC5eelik  2022-12-08
# 1                         @EthanBitcoin @dergigi lol  2022-12-08
# 2             @EddieZipperer https://t.co/92voOIH5d8  2022-12-08
# 3  RT @teslaownersSV: Tesla Semi is super quiet w...  2022-12-08
# 4  RT @SpaceX: Teams completed additional vehicle...  2022-12-07

# %%
#Data frame from Elons tweets clean
tw_aft["tweet"] = tw_aft['Text']

#Removing RT, Punctuation etc
remove_rt = lambda x: re.sub('RT @\w+: '," ",x)
rt = lambda x: re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",x)
tw_aft["tweet"] = tw_aft.tweet.map(remove_rt).map(rt)
tw_aft["tweet"] = tw_aft.tweet.str.lower()
tw_aft.head(10)
# Out:
#                                                 Text    Date_New  \
# 0                Woke v Woke https://t.co/hmhC5eelik  2022-12-08
# 1                         @EthanBitcoin @dergigi lol  2022-12-08
# 2             @EddieZipperer https://t.co/92voOIH5d8  2022-12-08
# 3  RT @teslaownersSV: Tesla Semi is super quiet w...  2022-12-08
# 4  RT @SpaceX: Teams completed additional vehicle...  2022-12-07
# 5                                    @ChrisJBakke 🤣🤣  2022-12-07
# 6  @jack Most important data was hidden (from you...  2022-12-07
# 7     @BoeingAirplanes One of the best aircraft ever  2022-12-07
# 8                                       @karpathy 🔥🤣  2022-12-07
# 9  Oh, you know, keeping busy … https://t.co/jgGY...  2022-12-07
#
#                                                tweet
# 0                                      woke v woke
# 1                                                lol
# 2
# 3   tesla semi is super quiet while pulling the f...
# 4   teams completed additional vehicle inspection...
# 5
# 6    most important data was hidden  from you too...
# 7                      one of the best aircraft ever
# 8
# 9                     oh  you know  keeping busy

# %%
#Calculating Negative, Positive, Neutral and Compound values

tw_aft[['polarity', 'subjectivity']] = tw_aft['tweet'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, row in tw_aft['tweet'].iteritems():
    score = SentimentIntensityAnalyzer().polarity_scores(row)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    if neg > pos:
        tw_aft.loc[index, 'sentiment'] = "negative"
    elif pos > neg:
        tw_aft.loc[index, 'sentiment'] = "positive"
    else:
        tw_aft.loc[index, 'sentiment'] = "neutral"
    tw_aft.loc[index, 'neg'] = neg
    tw_aft.loc[index, 'neu'] = neu
    tw_aft.loc[index, 'pos'] = pos
    tw_aft.loc[index, 'compound'] = comp

tw_aft.head(10)
# Out:
#                                                 Text    Date_New  \
# 0                Woke v Woke https://t.co/hmhC5eelik  2022-12-08
# 1                         @EthanBitcoin @dergigi lol  2022-12-08
# 2             @EddieZipperer https://t.co/92voOIH5d8  2022-12-08
# 3  RT @teslaownersSV: Tesla Semi is super quiet w...  2022-12-08
# 4  RT @SpaceX: Teams completed additional vehicle...  2022-12-07
# 5                                    @ChrisJBakke 🤣🤣  2022-12-07
# 6  @jack Most important data was hidden (from you...  2022-12-07
# 7     @BoeingAirplanes One of the best aircraft ever  2022-12-07
# 8                                       @karpathy 🔥🤣  2022-12-07
# 9  Oh, you know, keeping busy … https://t.co/jgGY...  2022-12-07
#
#                                                tweet  polarity  subjectivity  \
# 0                                      woke v woke    0.000000      0.000000
# 1                                                lol  0.800000      0.700000
# 2                                                     0.000000      0.000000
# 3   tesla semi is super quiet while pulling the f... -0.083333      0.625000
# 4   teams completed additional vehicle inspection...  0.700000      0.600000
# 5                                                     0.000000      0.000000
# 6    most important data was hidden  from you too...  0.244444      0.611111
# 7                      one of the best aircraft ever  1.000000      0.300000
# 8                                                     0.000000      0.000000
# 9                     oh  you know  keeping busy      0.100000      0.300000
#
#   sentiment    neg    neu    pos  compound
# 0   neutral  0.000  1.000  0.000    0.0000
# 1  positive  0.000  0.000  1.000    0.4215
# 2   neutral  0.000  0.000  0.000    0.0000
# 3  positive  0.163  0.600  0.237    0.4939
# 4  positive  0.000  0.854  0.146    0.4404
# 5   neutral  0.000  0.000  0.000    0.0000
# 6  positive  0.000  0.928  0.072    0.1397
# 7  positive  0.000  0.543  0.457    0.6369
# 8   neutral  0.000  0.000  0.000    0.0000
# 9   neutral  0.000  1.000  0.000    0.0000

# %%
tw_aft['date']=pd.to_datetime(tw_aft['Date_New'], format='%Y-%m-%d')
tw_aft.head()
# Out:
#                                                 Text    Date_New  \
# 0                Woke v Woke https://t.co/hmhC5eelik  2022-12-08
# 1                         @EthanBitcoin @dergigi lol  2022-12-08
# 2             @EddieZipperer https://t.co/92voOIH5d8  2022-12-08
# 3  RT @teslaownersSV: Tesla Semi is super quiet w...  2022-12-08
# 4  RT @SpaceX: Teams completed additional vehicle...  2022-12-07
#
#                                                tweet  polarity  subjectivity  \
# 0                                      woke v woke    0.000000         0.000
# 1                                                lol  0.800000         0.700
# 2                                                     0.000000         0.000
# 3   tesla semi is super quiet while pulling the f... -0.083333         0.625
# 4   teams completed additional vehicle inspection...  0.700000         0.600
#
#   sentiment    neg    neu    pos  compound       date
# 0   neutral  0.000  1.000  0.000    0.0000 2022-12-08
# 1  positive  0.000  0.000  1.000    0.4215 2022-12-08
# 2   neutral  0.000  0.000  0.000    0.0000 2022-12-08
# 3  positive  0.163  0.600  0.237    0.4939 2022-12-08
# 4  positive  0.000  0.854  0.146    0.4404 2022-12-07

# %%
plt.figure(figsize=(20,5))
plt.plot(tw_aft['Date_New'], tw_aft['neg'])
plt.xlabel("date")
plt.ylabel("negativity")
plt.title("Elon's neg tweet after acquisition Price 29.10.22 - 8.12.22");

# %%
#DataFrame to csv
tw_aft.to_csv('Elon_tweets_after.csv')

# %% [markdown]
# ## Tesla tweets

# %%
tesla_tw = pd.read_csv('Hashtag_Tesla_Tweets_CAT.csv')
tesla_tw.head()
# Out:
#    Unnamed: 0      Twitter ID        Date  \
# 0           0  @Jessica1988kk  2022-04-10
# 1           1     @JotaGe2014  2022-04-10
# 2           2      @MmeCallas  2022-04-10
# 3           3        @BotSecx  2022-04-10
# 4           4          @agseh  2022-04-10
#
#                                                tweet  polarity  subjectivity  \
# 0   crypto news   bitcoin whales  flying motorbik...  0.318182         0.500
# 1   tesla tiene r cord de autos vendidos  es impr...  0.000000         0.000
# 2      love in my  mariacallas i know y  art hold...  0.425000         0.625
# 3      love in my  mariacallas i know y  art hold...  0.425000         0.625
# 4         al que le robaron las llantas del  tesl...  0.000000         0.000
#
#   sentiment    neg    neu    pos  compound
# 0  positive  0.000  0.862  0.138    0.4939
# 1  negative  0.084  0.916  0.000   -0.2960
# 2  positive  0.000  0.787  0.213    0.7650
# 3  positive  0.000  0.787  0.213    0.7650
# 4   neutral  0.000  1.000  0.000    0.0000

# %%
tesla_tw.drop('Unnamed: 0', inplace=True, axis=1)
tesla_tw.head()
# Out:
#        Twitter ID        Date  \
# 0  @Jessica1988kk  2022-04-10
# 1     @JotaGe2014  2022-04-10
# 2      @MmeCallas  2022-04-10
# 3        @BotSecx  2022-04-10
# 4          @agseh  2022-04-10
#
#                                                tweet  polarity  subjectivity  \
# 0   crypto news   bitcoin whales  flying motorbik...  0.318182         0.500
# 1   tesla tiene r cord de autos vendidos  es impr...  0.000000         0.000
# 2      love in my  mariacallas i know y  art hold...  0.425000         0.625
# 3      love in my  mariacallas i know y  art hold...  0.425000         0.625
# 4         al que le robaron las llantas del  tesl...  0.000000         0.000
#
#   sentiment    neg    neu    pos  compound
# 0  positive  0.000  0.862  0.138    0.4939
# 1  negative  0.084  0.916  0.000   -0.2960
# 2  positive  0.000  0.787  0.213    0.7650
# 3  positive  0.000  0.787  0.213    0.7650
# 4   neutral  0.000  1.000  0.000    0.0000

# %%
tesla_tw.loc[tesla_tw['sentiment']=='negative']
# Out:
#               Twitter ID       date  \
# 1            @JotaGe2014 2022-04-10
# 11          @TeslaradarB 2022-04-10
# 13          @TeslaradarB 2022-04-10
# 36           @KrishnaM29 2022-04-10
# 37          @Commuternyc 2022-04-10
# ...                  ...        ...
# 151994      @DirkStutzki 2022-11-12
# 151995  @FolgendenFolgen 2022-11-12
# 151996      @kerntdennis 2022-11-12
# 151997        @kadiff651 2022-11-12
# 151999     @JandTContent 2022-11-12
#
#                                                     tweet  polarity  \
# 1        tesla tiene r cord de autos vendidos  es impr...  0.000000
# 11      bada bing  carinasteslatray just spotted a 201...  0.325000
# 13      kazaam  carinasteslatray was first to spot a y...  0.250000
# 36        i don t think some tweets are a direct refle...  0.100000
# 37        your bull argument is to buy the stock becau... -0.172917
# ...                                                   ...       ...
# 151994   erinnert ihr euch  als   ein kfz aus reinem  ...  0.000000
# 151995   erinnert ihr euch  als   ein kfz aus reinem  ...  0.000000
# 151996   erinnert ihr euch  als   ein kfz aus reinem  ...  0.000000
# 151997   erinnert ihr euch  als   ein kfz aus reinem  ...  0.000000
# 151999  crash and burn everywhere      another one bit...  0.000000
#
#         subjectivity sentiment    neg    neu  pos  compound
# 1           0.000000  negative  0.084  0.916  0.0   -0.2960
# 11          0.433333  negative  0.091  0.909  0.0   -0.2960
# 13          0.333333  negative  0.121  0.879  0.0   -0.2960
# 36          0.400000  negative  0.156  0.844  0.0   -0.3400
# 37          0.304167  negative  0.168  0.832  0.0   -0.8074
# ...              ...       ...    ...    ...  ...       ...
# 151994      0.000000  negative  0.206  0.794  0.0   -0.9136
# 151995      0.000000  negative  0.206  0.794  0.0   -0.9136
# 151996      0.000000  negative  0.206  0.794  0.0   -0.9136
# 151997      0.000000  negative  0.206  0.794  0.0   -0.9136
# 151999      0.000000  negative  0.213  0.787  0.0   -0.4019
#
# [26946 rows x 10 columns]

# %%
tesla_tw.rename(columns = {'Date':'date'}, inplace = True)

# %%
tesla_tw['date']=pd.to_datetime(tesla_tw['date'], format='%Y-%m-%d')

# %%
tesla_tw_stock = pd.merge(tesla_stock,tesla_tw,on="date",how="inner")
tesla_tw_stock.head()
# Out:
#    Unnamed: 0   close     high     low   open       date       Twitter ID  \
# 0  2022-04-11  325.31  336.156  324.88  326.8 2022-04-11   @JervisCapital
# 1  2022-04-11  325.31  336.156  324.88  326.8 2022-04-11   @JervisCapital
# 2  2022-04-11  325.31  336.156  324.88  326.8 2022-04-11   @JervisCapital
# 3  2022-04-11  325.31  336.156  324.88  326.8 2022-04-11  @SimonB76193881
# 4  2022-04-11  325.31  336.156  324.88  326.8 2022-04-11      @burrosavic
#
#                                                tweet  polarity  subjectivity  \
# 0      tesla s 5 big lies from battery day   less... -0.188889      0.255556
# 1   lie 1   tesla s  internal cell production  wi...  0.000000      0.000000
# 2   lie 2   tesla s 4680 cells are revolutionary ...  0.000000      0.125000
# 3   the power of tesla fremont will be shown in q...  0.000000      0.000000
# 4   i ve been to a lot of parties  this was one o...  0.750000      0.594444
#
#   sentiment    neg    neu    pos  compound
# 0  negative  0.074  0.873  0.053   -0.2023
# 1  positive  0.042  0.886  0.072    0.1027
# 2  positive  0.000  0.862  0.138    0.5859
# 3   neutral  0.000  1.000  0.000    0.0000
# 4  positive  0.000  0.588  0.412    0.8979

# %%
tesla_tw_stock = tesla_tw_stock[['date','tweet','open','close','polarity','subjectivity','neg','neu','pos','compound','sentiment']]
tesla_tw_stock.head()
# Out:
#         date                                              tweet   open  \
# 0 2022-04-11      tesla s 5 big lies from battery day   less...  326.8
# 1 2022-04-11   lie 1   tesla s  internal cell production  wi...  326.8
# 2 2022-04-11   lie 2   tesla s 4680 cells are revolutionary ...  326.8
# 3 2022-04-11   the power of tesla fremont will be shown in q...  326.8
# 4 2022-04-11   i ve been to a lot of parties  this was one o...  326.8
#
#     close  polarity  subjectivity    neg    neu    pos  compound sentiment
# 0  325.31 -0.188889      0.255556  0.074  0.873  0.053   -0.2023  negative
# 1  325.31  0.000000      0.000000  0.042  0.886  0.072    0.1027  positive
# 2  325.31  0.000000      0.125000  0.000  0.862  0.138    0.5859  positive
# 3  325.31  0.000000      0.000000  0.000  1.000  0.000    0.0000   neutral
# 4  325.31  0.750000      0.594444  0.000  0.588  0.412    0.8979  positive

# %%
tesla_tw_stock.describe()
# Out:
#                 open          close       polarity   subjectivity  \
# count  104557.000000  104557.000000  104557.000000  104557.000000
# mean      261.560399     260.582389       0.089903       0.279247
# std        38.533050      38.032660       0.233210       0.299661
# min       186.000000     177.590000      -1.000000       0.000000
# 25%       229.500000     228.520000       0.000000       0.000000
# 50%       254.500000     252.753000       0.000000       0.216667
# 75%       295.000000     292.140000       0.196104       0.500000
# max       358.243000     342.717000       1.000000       1.000000
#
#                  neg            neu            pos       compound
# count  104557.000000  104557.000000  104557.000000  104557.000000
# mean        0.036553       0.882312       0.081119       0.128034
# std         0.076254       0.131030       0.111923       0.402180
# min         0.000000       0.000000       0.000000      -0.983400
# 25%         0.000000       0.801000       0.000000       0.000000
# 50%         0.000000       0.912000       0.000000       0.000000
# 75%         0.042000       1.000000       0.137000       0.421500
# max         1.000000       1.000000       0.867000       0.990000

# %%
tesla_tw_stock= tesla_tw_stock.groupby(['date','open','close'])['polarity','subjectivity','neg','neu','pos','compound'].mean()
tesla_tw_stock=tesla_tw_stock.reset_index()
tesla_tw_stock
# Out:
# C:\Users\javie\AppData\Local\Temp/ipykernel_21520/56285633.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tesla_tw_stock= tesla_tw_stock.groupby(['date','open','close'])['polarity','subjectivity','neg','neu','pos','compound'].mean()
#           date     open    close  polarity  subjectivity       neg       neu  \
# 0   2022-04-11  326.800  325.310  0.088006      0.280926  0.027053  0.879300
# 1   2022-04-12  332.547  328.983  0.104671      0.292057  0.030911  0.876903
# 2   2022-04-13  327.025  340.790  0.099795      0.313879  0.035191  0.880776
# 3   2022-04-14  333.097  328.333  0.067711      0.279761  0.061231  0.859106
# 4   2022-04-18  329.677  334.763  0.118878      0.282176  0.025993  0.866487
# ..         ...      ...      ...       ...           ...       ...       ...
# 143 2022-11-07  208.650  197.080  0.067348      0.271531  0.043519  0.865306
# 144 2022-11-08  194.020  191.300  0.075518      0.308039  0.046128  0.872000
# 145 2022-11-09  190.775  177.590  0.060422      0.224464  0.050599  0.878974
# 146 2022-11-10  189.900  190.720  0.102952      0.280519  0.043643  0.883635
# 147 2022-11-11  186.000  195.970  0.080823      0.277186  0.040436  0.891332
#
#           pos  compound
# 0    0.093649  0.206849
# 1    0.092189  0.185046
# 2    0.084012  0.139801
# 3    0.079656  0.094391
# 4    0.107513  0.219178
# ..        ...       ...
# 143  0.091154  0.120413
# 144  0.081850  0.087291
# 145  0.070418  0.056075
# 146  0.072722  0.108611
# 147  0.068228  0.106121
#
# [148 rows x 9 columns]

# %%
tesla_tw_stock['change']=tesla_tw_stock['close']-tesla_tw_stock['open']
tesla_tw_stock.head()
# Out:
#         date     open    close  polarity  subjectivity       neg       neu  \
# 0 2022-04-11  326.800  325.310  0.088006      0.280926  0.027053  0.879300
# 1 2022-04-12  332.547  328.983  0.104671      0.292057  0.030911  0.876903
# 2 2022-04-13  327.025  340.790  0.099795      0.313879  0.035191  0.880776
# 3 2022-04-14  333.097  328.333  0.067711      0.279761  0.061231  0.859106
# 4 2022-04-18  329.677  334.763  0.118878      0.282176  0.025993  0.866487
#
#         pos  compound  change
# 0  0.093649  0.206849  -1.490
# 1  0.092189  0.185046  -3.564
# 2  0.084012  0.139801  13.765
# 3  0.079656  0.094391  -4.764
# 4  0.107513  0.219178   5.086

# %%
tesla_tw_stock=tesla_tw_stock.reset_index()
tesla_tw_stock
# Out:
#      index       date     open    close  polarity  subjectivity       neg  \
# 0        0 2022-04-11  326.800  325.310  0.088006      0.280926  0.027053
# 1        1 2022-04-12  332.547  328.983  0.104671      0.292057  0.030911
# 2        2 2022-04-13  327.025  340.790  0.099795      0.313879  0.035191
# 3        3 2022-04-14  333.097  328.333  0.067711      0.279761  0.061231
# 4        4 2022-04-18  329.677  334.763  0.118878      0.282176  0.025993
# ..     ...        ...      ...      ...       ...           ...       ...
# 143    143 2022-11-07  208.650  197.080  0.067348      0.271531  0.043519
# 144    144 2022-11-08  194.020  191.300  0.075518      0.308039  0.046128
# 145    145 2022-11-09  190.775  177.590  0.060422      0.224464  0.050599
# 146    146 2022-11-10  189.900  190.720  0.102952      0.280519  0.043643
# 147    147 2022-11-11  186.000  195.970  0.080823      0.277186  0.040436
#
#           neu       pos  compound  change
# 0    0.879300  0.093649  0.206849  -1.490
# 1    0.876903  0.092189  0.185046  -3.564
# 2    0.880776  0.084012  0.139801  13.765
# 3    0.859106  0.079656  0.094391  -4.764
# 4    0.866487  0.107513  0.219178   5.086
# ..        ...       ...       ...     ...
# 143  0.865306  0.091154  0.120413 -11.570
# 144  0.872000  0.081850  0.087291  -2.720
# 145  0.878974  0.070418  0.056075 -13.185
# 146  0.883635  0.072722  0.108611   0.820
# 147  0.891332  0.068228  0.106121   9.970
#
# [148 rows x 11 columns]

# %%
numerical = tesla_tw_stock[['index','open','close','polarity','subjectivity','neg','neu','pos','compound','change']]
numerical.head()
# Out:
#    index     open    close  polarity  subjectivity       neg       neu  \
# 0      0  326.800  325.310  0.088006      0.280926  0.027053  0.879300
# 1      1  332.547  328.983  0.104671      0.292057  0.030911  0.876903
# 2      2  327.025  340.790  0.099795      0.313879  0.035191  0.880776
# 3      3  333.097  328.333  0.067711      0.279761  0.061231  0.859106
# 4      4  329.677  334.763  0.118878      0.282176  0.025993  0.866487
#
#         pos  compound  change
# 0  0.093649  0.206849  -1.490
# 1  0.092189  0.185046  -3.564
# 2  0.084012  0.139801  13.765
# 3  0.079656  0.094391  -4.764
# 4  0.107513  0.219178   5.086

# %%
#Label stock change by "up & down"
tesla_tw_stock['diection']= ['up' if change > 0 else 'down' for change in tesla_tw_stock['change']]
tesla_tw_stock.head()
# Out:
#    index       date     open    close  polarity  subjectivity       neg  \
# 0      0 2022-04-11  326.800  325.310  0.088006      0.280926  0.027053
# 1      1 2022-04-12  332.547  328.983  0.104671      0.292057  0.030911
# 2      2 2022-04-13  327.025  340.790  0.099795      0.313879  0.035191
# 3      3 2022-04-14  333.097  328.333  0.067711      0.279761  0.061231
# 4      4 2022-04-18  329.677  334.763  0.118878      0.282176  0.025993
#
#         neu       pos  compound  change diection
# 0  0.879300  0.093649  0.206849  -1.490     down
# 1  0.876903  0.092189  0.185046  -3.564     down
# 2  0.880776  0.084012  0.139801  13.765       up
# 3  0.859106  0.079656  0.094391  -4.764     down
# 4  0.866487  0.107513  0.219178   5.086       up

# %%
tesla_tw_stock.drop('index', inplace=True, axis=1)

# %%
tesla_tw_stock.head()
# Out:
#         date     open    close  polarity  subjectivity       neg       neu  \
# 0 2022-04-11  326.800  325.310  0.088006      0.280926  0.027053  0.879300
# 1 2022-04-12  332.547  328.983  0.104671      0.292057  0.030911  0.876903
# 2 2022-04-13  327.025  340.790  0.099795      0.313879  0.035191  0.880776
# 3 2022-04-14  333.097  328.333  0.067711      0.279761  0.061231  0.859106
# 4 2022-04-18  329.677  334.763  0.118878      0.282176  0.025993  0.866487
#
#         pos  compound  change diection
# 0  0.093649  0.206849  -1.490     down
# 1  0.092189  0.185046  -3.564     down
# 2  0.084012  0.139801  13.765       up
# 3  0.079656  0.094391  -4.764     down
# 4  0.107513  0.219178   5.086       up

# %%
tesla_tw_stock.to_csv('Tesla_tweet_stock.csv')

# %% [markdown]
# # Elon tweets 2022 w Sentiment

# %%
#Concatenate 2 Data frames (After and before Twitter acquisition)

frames = [tw_list,tw_aft]
elon_tws= pd.concat(frames)
elon_tws= elon_tws.sort_values('date')
elon_tws=elon_tws.reset_index(drop=True)
elon_tws
# Out:
#                                                    Text    Date_New  \
# 0                     @MiFSDBetaTester @WholeMarsBlog 🤣  2022-01-01
# 1                                     @BLKMDL3 @Tesla 🔥  2022-01-01
# 2     Great work by Tesla team worldwide! https://t....  2022-01-02
# 3                   Let’s make the roaring 20’s happen!  2022-01-02
# 4                               https://t.co/LA9hPzVlGx  2022-01-02
# ...                                                 ...         ...
# 4043  @ESYudkowsky To be called AGI, it needs to inv...  2022-12-07
# 4044  RT @teslaownersSV: Tesla Semi is super quiet w...  2022-12-08
# 4045             @EddieZipperer https://t.co/92voOIH5d8  2022-12-08
# 4046                         @EthanBitcoin @dergigi lol  2022-12-08
# 4047                Woke v Woke https://t.co/hmhC5eelik  2022-12-08
#
#                                                   tweet  polarity  \
# 0                                                        0.000000
# 1                                                        0.000000
# 2                 great work by tesla team worldwide     0.800000
# 3                   let s make the roaring 20 s happen   0.000000
# 4                                                        0.000000
# ...                                                 ...       ...
# 4043    to be called agi  it needs to invent amazing...  0.550000
# 4044   tesla semi is super quiet while pulling the f... -0.083333
# 4045                                                     0.000000
# 4046                                                lol  0.800000
# 4047                                      woke v woke    0.000000
#
#       subjectivity sentiment    neg    neu    pos  compound       date
# 0            0.000   neutral  0.000  0.000  0.000    0.0000 2022-01-01
# 1            0.000   neutral  0.000  0.000  0.000    0.0000 2022-01-01
# 2            0.750  positive  0.000  0.549  0.451    0.6249 2022-01-02
# 3            0.000   neutral  0.000  1.000  0.000    0.0000 2022-01-02
# 4            0.000   neutral  0.000  0.000  0.000    0.0000 2022-01-02
# ...            ...       ...    ...    ...    ...       ...        ...
# 4043         0.700  positive  0.000  0.817  0.183    0.5859 2022-12-07
# 4044         0.625  positive  0.163  0.600  0.237    0.4939 2022-12-08
# 4045         0.000   neutral  0.000  0.000  0.000    0.0000 2022-12-08
# 4046         0.700  positive  0.000  0.000  1.000    0.4215 2022-12-08
# 4047         0.000   neutral  0.000  1.000  0.000    0.0000 2022-12-08
#
# [4048 rows x 11 columns]

# %%
elon_tws = elon_tws[['Date_New','polarity','subjectivity','neg','neu','pos','compound']]
elon_tws.head()
# Out:
#      Date_New  polarity  subjectivity  neg    neu    pos  compound
# 0  2022-01-01       0.0          0.00  0.0  0.000  0.000    0.0000
# 1  2022-01-01       0.0          0.00  0.0  0.000  0.000    0.0000
# 2  2022-01-02       0.8          0.75  0.0  0.549  0.451    0.6249
# 3  2022-01-02       0.0          0.00  0.0  1.000  0.000    0.0000
# 4  2022-01-02       0.0          0.00  0.0  0.000  0.000    0.0000

# %%
elon_tws= elon_tws.groupby(['Date_New'])['polarity','subjectivity','neg','neu','pos','compound'].mean()
elon_tws
# Out:
# C:\Users\javie\AppData\Local\Temp/ipykernel_21520/856924661.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   elon_tws= elon_tws.groupby(['Date_New'])['polarity','subjectivity','neg','neu','pos','compound'].mean()
#             polarity  subjectivity       neg       neu       pos  compound
# Date_New
# 2022-01-01  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 2022-01-02  0.266667      0.250000  0.000000  0.516333  0.150333  0.208300
# 2022-01-03 -0.013889      0.352778  0.119500  0.608833  0.271667 -0.034283
# 2022-01-04  0.166667      0.166667  0.000000  0.666667  0.000000  0.000000
# 2022-01-05  0.000000      0.000000  0.000000  0.204000  0.296000  0.220200
# ...              ...           ...       ...       ...       ...       ...
# 2022-12-04  0.069437      0.194878  0.034065  0.683355  0.153548  0.164700
# 2022-12-05  0.046962      0.234462  0.042417  0.777292  0.096958  0.028371
# 2022-12-06  0.084167      0.522292  0.052125  0.619500  0.203375  0.045363
# 2022-12-07  0.288272      0.360494  0.000000  0.682444  0.095333  0.200322
# 2022-12-08  0.179167      0.331250  0.040750  0.400000  0.309250  0.228850
#
# [305 rows x 6 columns]

# %%
#DataFrame to csv
elon_tws.to_csv('2022_Ellon_tweets_sentimental.csv')

# %% [markdown]
# ## NLKT

# %%
#pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\javie\anaconda3\lib\site-packages (3.6.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: click in c:\users\javie\anaconda3\lib\site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in c:\users\javie\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\javie\anaconda3\lib\site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: tqdm in c:\users\javie\anaconda3\lib\site-packages (from nltk) (4.62.3)
# Requirement already satisfied: colorama in c:\users\javie\anaconda3\lib\site-packages (from click->nltk) (0.4.4)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\javie\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\javie\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\javie\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\javie\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3135 entries, 0 to 3134
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Text      3135 non-null   object
#  1   Date_New  3135 non-null   object
# dtypes: object(2)
# memory usage: 49.1+ KB

# %% [markdown]
# ### Length of each tweet

# %%
df['length'] = list(map(lambda x: len(str(x).split()), df['Text']))

# %%
df.head()
# Out:
#                                                 Text    Date_New  length
# 0                                  the bird is freed  2022-10-28       4
# 1  Falcon rockets to orbit as seen from LA https:...  2022-10-28       9
# 2                                @Gfilche @Twitter 🤣  2022-10-27       3
# 3                              @PeterSchiff 🤣 thanks  2022-10-27       3
# 4                              @ZubyMusic Absolutely  2022-10-27       2

# %%
sns.displot(x=df['length'])

# %%
df['length'].describe()
# Out:
# count    3135.000000
# mean       11.510686
# std        11.265709
# min         1.000000
# 25%         3.000000
# 50%         8.000000
# 75%        15.000000
# max        56.000000
# Name: length, dtype: float64

# %%
#meadian of tweets length
m = df['length'].median()
m
# Out:
# 8.0

# %%
tweets = ['']
corpus=[]
for tweet in df['Text']:
    tweets.append(tweet)
    corpus.append(nltk.sent_tokenize(tweet))

# %%
corpus
# Out:
# [['the bird is freed'],
#  ['Falcon rockets to orbit as seen from LA https://t.co/r8L2SbLC3p'],
#  ['@Gfilche @Twitter 🤣'],
#  ['@PeterSchiff 🤣 thanks'],
#  ['@ZubyMusic Absolutely'],
#  ['Dear Twitter Advertisers https://t.co/GMwHmInPAS'],
#  ['@BillyM2k 👻'],
#  ['Meeting a lot of cool people at Twitter today!'],
#  ['Entering Twitter HQ – let that sink in!', 'https://t.co/D68z4K2wq7'],
#  ['@dogeofficialceo @mtaibbi 🤣💪'],
#  ['@mtaibbi 🤣'],
#  ['@ARodTV Definitely closer to citizen journalism – local news orgs are under-appreciated &amp; should get way more prominence on Twitter'],
#  ['@sandyleevincent Nobody bats 1000 🤷\u200d♂️'],
#  ['A beautiful thing about Twitter is how it empowers citizen journalism – people are able to disseminate news without an establishment bias'],
#  ['@teslaownersSV I’m a big fan of citizen journalism!'],
#  ['“According to unnamed sources close to the matter who wish to remain anonymous” 🤣🤣'],
#  ['“The New York Times has emerged as a new, chaotic actor in global politics.',
#   'The paper’s interventions in some of the world’s most combustible conflicts have sometimes been a boon, but their messaging has also caused problems.”'],
#  ['@dontreadonmeow @nytimes 🤣🔥'],
#  ['@PPathole @Twitter Yes!'],
#  ['@westcoastbill 30% is a lot'],
#  ['@eldsjal Concerning'],
#  ['Works on any moving land object https://t.co/Xu4qKJW4D9'],
#  ['@chazman @lexfridman Fasting rocks'],
#  ['@VitalikButerin @balajis @zengjiajun_eth Had to do a double-take.',
#   'This is the first non-fake Vitalik tweet I’ve seen in a while.'],
#  ['@dogeofficialceo @DirtyTesLa @rocobasilisk @SwipeWright 💯'],
#  ['@garyblack00 @SawyerMerritt One man’s hedge is another man’s shrub'],
#  ['@muskQu0tes Yup'],
#  ['@emollick True'],
#  ['@elon_wisdom Too much respect for authority inhibits innovation'],
#  ['@DirtyTesLa @rocobasilisk @SwipeWright 💪'],
#  ['@stevenmarkryan @EmmetPeppers @heydave7 @TwitterSpaces @YouTube 😉'],
#  ['What lesson took you the longest to unlearn?'],
#  ['διαλεκτική'],
#  ['@SwipeWright Twitter should be as broadly inclusive as possible, serving as a fair forum for lively, even if occasionally rancorous, debate between widely divergent beliefs.'],
#  ['@MuskUniversity Absolutely necessary'],
#  ['@DavidSacks @MarcBodnick !'],
#  ['@realchrisrufo @MaxBoot 🤣🤣'],
#  ['@MuskUniversity Important'],
#  ['@MuskUniversity Yup'],
#  ['@DavidSacks Exactly!'],
#  ['@SawyerMerritt 🤣'],
#  ['@VinnyLingham Yeah, doesn’t make sense'],
#  ['@MuskUniversity Good thread'],
#  ['@RenataKonkoly @spideycyp_155 @SquawkCNBC @Kasparov63 I only play crazy 9’s'],
#  ['@MarcusHouse @LordofEa @kerrikgray @chicago_glenn @Tesla @teslaownersSV @dvorahfr @TonyadeVitti @SpaceX @SirineAti That’s the plan, unless it is damaged in testing.',
#   'What really matters is that ship &amp; booster production line is spooling up.',
#   'Also, each new ship &amp; booster has incremental design improvements.'],
#  ['@ChananBos @SquawkCNBC @Kasparov63 Yeah, I’m back to spare bedroom /couch surfing at friend’s houses in Silicon Valley, which I did for about a decade.',
#   'Frankly, I like it this way, as I get to see my friends, who I love, more often.'],
#  ['@spideycyp_155 @SquawkCNBC @Kasparov63 I did as a child, but found it to be too simple to be useful in real life: a mere 8 by 8 grid, no fog of war, no technology tree, no random map or spawn position, only 2 players, both sides exact same pieces, etc.',
#   'Polytopia addresses these limitations.'],
#  ['@SquawkCNBC @Kasparov63 And I don’t even own a house, let alone a “mansion”, you douche'],
#  ['@SquawkCNBC @Kasparov63 While it’s true that Kasparov is almost as good at playing chess as my iPhone, he is otherwise an idiot'],
#  ['@spideycyp_155 @Teslarati @Writer_01001101 @FedorovMykhailo Yes'],
#  ['@dogeofficialceo @gunsnrosesgirl3 @DolphinDroneDom 🤣'],
#  ['@gunsnrosesgirl3 @DolphinDroneDom How exciting to be alive at the same time as the largest animal ever!',
#   'Wild that Blue whales are bigger than the biggest dinosaur.'],
#  ['@FedorovMykhailo @Teslarati @Writer_01001101 You’re most welcome'],
#  ['@Teslarati @Writer_01001101 Before DoD even came back with an answer, I told @FedorovMykhailo that SpaceX would not turn off Starlink even if DoD refused to provide funding'],
#  ['@LordofEa @kerrikgray @chicago_glenn @Tesla @teslaownersSV @dvorahfr @TonyadeVitti @SpaceX @SirineAti Absolutely!'],
#  ['@SKMorefield Interesting'],
#  ['@pcgamer Great game'],
#  ['Maybe it was a social media algorithm, not even people'],
#  ['Think about who might have decided “The Current Thing” before accepting it'],
#  ['Who decides “The Current Thing?”\r\nReal question.', 'I don’t know.'],
#  ['@andst7 Exactly.', 'WaPo are such hypocrites.'],
#  ['Neuralink show &amp; tell now on Nov 30'],
#  ['@muskQu0tes @SpaceX Had to be done'],
#  ['@Gfilche @MartinViecha We’ve come a long way'],
#  ['i know\r\n|nothing|\r\nis forever'],
#  ['@BillyM2k @sakitechonline @DavidSacks 🤣💪'],
#  ['@michaelmalice @washingtonpost Good point 🤔'],
#  ['@MuskUniversity This needs to change.', 'Manufacturing is awesome!'],
#  ['@muskQu0tes It will happen'],
#  ['@DavidSacks @TheAtlantic @davidfrum @EliotACohen Hear!', 'Hear!'],
#  ['@ruthbenghiat Why are you perpetuating propaganda concocted by the oil &amp; gas industry to distract you from the 6 trillion dollars per *year* of subsidies those companies receive?',
#   'https://t.co/XZxDJAPE9a'],
#  ['@xuanyiman @stillgray @DavidSacks 😋'],
#  ['@stillgray @DavidSacks Switzerland &amp; Belgium have great chocolate, but I do also love eccentric British &amp; Irish artisanal sweet shops'],
#  ['@PhreshNic @MedvedevRussiaE @trussliz 🤣'],
#  ['@DavidSacks Good thread'],
#  ['@teslaownersSV Next week.',
#   'It’s actually a major release, so a lot more internal testing is needed before going to public beta.'],
#  ['@BillyM2k @DavidSacks 🤣💯'],
#  ['@ksadjadpour Cool'],
#  ['@DavidSacks 🤣🤣 \r\n\r\nAlthough there could be more R&amp;D in candy tbh.',
#   'Feels like there hasn’t been much improvement in decades.'],
#  ['@justindross 🤣'],
#  ['@WholeMarsBlog Headline is misleading.',
#   'Starlink can obviously offer far more robust positioning than GPS, as it will have ~1000X more satellites over time.',
#   'Not all will have line of sight to users, but still &gt;10X GPS &amp; far stronger signal.',
#   'Just not today’s problem.'],
#  ['@eigenrobot One of my favorite conspiracy theories is that the world is actually 80% men'],
#  ['@ChessProblem un ass ailable logic!'],
#  ['@teslaownersSV Yes'],
#  ['@LifeboatHQ https://t.co/j4ZHlazoPa'],
#  ['@LifeboatHQ You’re right.',
#   'Eventually, we all run out of time.',
#   'https://t.co/GyXk9uZLIW'],
#  ['Only Giga Berlin can make these colors, as paint shop was specially built to apply many fine layers of paint, giving it complexity not otherwise possible https://t.co/Htis0LfRzV'],
#  ['@teslaownersSV @BillyM2k Varies a lot.',
#   'Tesla &amp; SpaceX are in good positions, but many other companies are not.',
#   'Recessions do have a silver lining in that companies that shouldn’t exist stop existing.'],
#  ['@RenataKonkoly @ThorstenBasch @spideycyp_155 @BillyM2k Those who want Putin removed are laboring under the misapprehension that whoever replaces him will be more amenable to peace or western philosophy, but I think this is unlikely – the Kremlin is not the Nice Guy Olympics'],
#  ['@ThorstenBasch @spideycyp_155 @BillyM2k Russia overrunning Ukraine would destabilize the entire region, perhaps the world'],
#  ['@spideycyp_155 @BillyM2k If Russia faced calamitous defeat in conventional warfare for something as strategically critical as Crimea, the probability of using nuclear weapons is high'],
#  ['@jamesplloyd @SpaceX I do.', 'Yes.'],
#  ['@spideycyp_155 @BillyM2k Still very unlikely, but this is the closest we’ve been since Cuba in ‘62'],
#  ['@teslaownersSV @BillyM2k Just guessing, but probably until spring of ‘24'],
#  ['@BillyM2k It sure would be nice to have one year without a horrible global event'],
#  ['@AndrewPerpetua “Brutal for both sides” will be a common phrase in the months to come'],
#  ['https://t.co/WqGm6InNTp'],
#  ['@bgarlinghouse No way'],
#  ['@SamitoFPS Maybe'],
#  ['@NewsfromScience Certainly warrants closer scrutiny'],
#  ['@NikLentz @JenniferJJacobs @SalehaMohsin @BloombergTV 💯🤣'],
#  ['@MedvedevRussiaE @trussliz Btw, how’s it going in Bakhmut?'],
#  ['@MedvedevRussiaE @trussliz Pretty good troll tbh'],
#  ['@Alan_McGuinness *humour'],
#  ['@ilyasut I couldn’t agree more 😜'],
#  ['@Alan_McGuinness British humor is the best'],
#  ['@PPathole @EvaFoxU @DavidSacks Compromise is overwhelmingly the most likely outcome – just a question of how much death &amp; destruction happens before then'],
#  ['@gaborgurbacs @EvaFoxU @DavidSacks That should be the nature of the debate'],
#  ['@EvaFoxU @DavidSacks Most probable outcome by far is a horrible war of attrition that destroys Ukraine &amp; severely damages Russia, with massive body count on both sides.',
#   'And, in the end, the same outcome.',
#   'So why?'],
#  ['@DavidSacks Exactly'],
#  ['Congrats to @SpaceX team on 48th launch this year!',
#   'Falcon 9 now holds record for most launches of a single vehicle type in a year.'],
#  ['@SpaceX 🎯'],
#  ['@romanhelmetguy 💪'],
#  ['@Neuro_Skeptic Same'],
#  ['@marenkahnert @jasondebolt Exactly'],
#  ['@Teslarati @13ericralph31 SpaceX has more active satellites in orbit than rest of Earth combined, tracking to double rest of Earth soon'],
#  ['@jasondebolt The media reports with great fanfare my predictions that are late, but rarely those that come early'],
#  ['@jakebrowatzke @andyjayhawk 🤣'],
#  ['@Teslarati @JohnnaCrider1 Accelerating sustainable energy is our primary mission'],
#  ['@westcoastbill Will require truly exceptional execution, but it is possible'],
#  ['I will not let you down, no matter what it takes'],
#  ['@DirtyTesLa Awesome'],
#  ['We even did a Starlink video call on one airplane aloft to Starlink on another, far away, airplane aloft and it worked perfectly with no lag!'],
#  ['Vox Populi Vox Dei'],
#  ['@chazman @aelluswamy Several major architectural upgrades in 10.69.3, so it’s much more than a point release, but we’re sticking with 10.69 just cause haha'],
#  ['@BillyM2k @atrupar Sounds fair'],
#  ['@BillyM2k Definitely giving me kid naming ideas 🤣'],
#  ['And … sold out!'],
#  ['Internet in airplanes will feel same as if you were accessing Internet at home!',
#   'https://t.co/Mfl2ixYnJH'],
#  ['28,700 bottles of exquisite Burnt Hair perfume already sold!',
#   'Only 1,300 left of this unique, limited edition, collector’s item.',
#   'https://t.co/Gh2Zg7B5qX'],
#  ['@cb_doge @alex_avoigt We’re working on it.',
#   'Hope to release something next week.'],
#  ['@alex_avoigt No money from DoD, but several other countries, orgs &amp; individuals are paying for ~11k/25k terminals (thanks!).',
#   'SpaceX is losing ~$20M/month due to unpaid service &amp; costs related to enhanced security measures for cyberwar defense, but we’ll keep doing it (sigh).'],
#  ['@atrupar Smart?', 'Maybe.', 'Does dumb stuff?', 'Definitely!'],
#  ['@balajis True'],
#  ['@HassanNatha https://t.co/jxA4stwf1d'],
#  ['@TonyadeVitti 🤣'],
#  ['@520AlRihla Exactly'],
#  ['@tesla4k 🤣'],
#  ['@larryronaldpar1 Should I make weapons?', 'Ideally, not.'],
#  ['@TeslaHype An easy prediction'],
#  ['Drone War I\r\nhttps://t.co/erVME0CbbN'],
#  ['@FLVoiceNews https://t.co/CCaYpontFG'],
#  ['@teslaownersSV (Actually) Smart Summon is almost done'],
#  ['@Teslaconomics Yes'],
#  ['@stoolpresidente I have a plan'],
#  ['@TeslaAIBot @SpaceX @Tesla Thanks Optimus :)'],
#  ['@SawyerMerritt @SpaceX To be precise, 25,300 terminals were sent to Ukraine, but, at present, only 10,630 are paying for service'],
#  ['@SawyerMerritt @SpaceX SpaceX has already withdrawn its request for funding'],
#  ['@starrski71 @RenataKonkoly @EvaFoxU @kadubai11 @spideycyp_155 Wrong analogy.',
#   'America also had a humiliating withdrawal from Afghanistan.',
#   'No one in America sees that country as part of America.',
#   'Crimea *is* seen as a crucial part of Russia by Russia, much as Hawaii is seen as a crucial part of America.'],
#  ['@EnjoyerFive 🎯🤣'],
#  ['@PPathole @spideycyp_155 Probably not'],
#  ['@zerohedge Practice makes perfect …'],
#  ['@RenataKonkoly @EvaFoxU @kadubai11 @spideycyp_155 Russia has been punched in the nose and forced to retreat many times by Ukraine.',
#   'But what you don’t want to do is give Russia a choice of total, humiliating defeat or nukes – then the probability of them using nukes is high.'],
#  ['@kadubai11 @spideycyp_155 Obviously many disagree with this logic, but what do they think is their probability of being wrong about WW3.',
#   'If they say 0%, they are utterly dangerous fools.'],
#  ['@kadubai11 @spideycyp_155 But, hey, look on the bright side!',
#   'At least Russia doesn’t get Crimea in that scenario, so you can be comforted by that thought, while watching the mushroom clouds rise.'],
#  ['@kadubai11 @spideycyp_155 If Russia faces destruction of their army and utter defeat by NATO, they will use nukes, then NATO will respond with nukes and civilization is over'],
#  ['@spideycyp_155 Whether one likes it or not, Crimea is absolutely seen as a core part of Russia by Russia.',
#   'Crimea is also of critical national security importance to Russia, as it is their southern navy base.',
#   'From their standpoint losing Crimea is like USA losing Hawaii &amp; Pearl Harbor.'],
#  ['@hyiki22 @spideycyp_155 Exactly'],
#  ['@spideycyp_155 If Russia is faced with the choice of losing Crimea or using battlefield nukes, they will choose the latter.',
#   'We’ve already sanctioned/cutoff Russia in every possible way, so what more do they have left to lose?',
#   'If we nuke Russia back, they will nuke us and then we have WW3.'],
#  ['Exceptionally well-said https://t.co/UT8fXG0MeF'],
#  ['@rhensing @keith_dorschner @teslaownersSV Standard (non-performance) 3 &amp; Y suspension in production now has improved comfort, without affecting handling'],
#  ['@DrKnowItAll16 @pirate3Guy @HSerunjogi Yeah, RV version is lower priority than standard version.',
#   'You should still see high speeds during off hours.',
#   'Is that happening?',
#   'As we add more satellites &amp; upgrade satellite technology, speeds in high user density locations should see significant increases.'],
#  ['Ok, we will add a donate option to Starlink'],
#  ['@pirate3Guy @HSerunjogi That’s oddly low.', 'Normally, much higher.'],
#  ['Are there others that want to donate Starlinks to places in need?',
#   'https://t.co/M0ASMenMRD'],
#  ['@HSerunjogi Ok'],
#  ['@DogecoinNorway @moxie @ID_AA_Carmack 🤣 that’s happened to me many times'],
#  ['@moxie @ID_AA_Carmack A much quieter leaf blower is possible'],
#  ['@teslaownersSV This is harder than it sounds, but ok'],
#  ['Deus X Machina'],
#  ['@ChrisG_NSF We are proceeding very carefully.',
#   'If there is a RUD on the pad, Starship progress will be set back by ~6 months.'],
#  ['@Rainmaker1973 Game over when (not if) Earth gets hit by an object of that size'],
#  ['@N_Schmid Ramen &gt;&gt; Lambos'],
#  ['@Rainmaker1973 Used a lot in rocketry'],
#  ['So true https://t.co/PwmxUVU2Fc'],
#  ['@Rainmaker1973 Every millipede has its millennia'],
#  ['@HardcoreHistory We should bring back their outfits'],
#  ['@karpathy Good thread'],
#  ['Fancy a game of meme tennis?', 'https://t.co/d9tqIlg7nB'],
#  ['Buy Burnt Hair from a company that digs holes!'],
#  ['@chicago_glenn I read this as goth clowns lonely'],
#  ['Did you hear about the dyslexic KBG agent – it’s pot secret!'],
#  ['@utamadush 🤣'],
#  ['Venn diagram intersection of those two audiences is pretty small, I guess'],
#  ['Not as popular as I’d hoped (sigh)'],
#  ['Pitching my idea once again for a crossover of Das Boot &amp; Boss Baby.',
#   '“Das Baby” – Hijinks on the high seas!',
#   'https://t.co/FieRmSthp2'],
#  ['@teslaownersSV @oldmordim Just a scratch, we can buff it out'],
#  ['@oldmordim Mostly accurate'],
#  ['The comments in this thread are a conspiracy theorist’s wet dream'],
#  ['@EvaFoxU Yup'],
#  ['@EvaFoxU 7 years ago'],
#  ['@FutureJurvetson @SpaceX Definitely one of the strangest meetings I’ve ever experienced.',
#   '@adeoressi was there too.'],
#  ['@KimDotcom @Twitter I’m trying my hardest to de-escalate this situation and obviously failing'],
#  ['@KimDotcom @Twitter Damned if you do, damned if you don’t, so … guess I’m just damned'],
#  ['@SawyerMerritt Starship &amp; next-gen Starlink satellites are key, but much risk lies ahead before those are working at scale'],
#  ['@RaheemKassam The hilarious thing is you’re not wrong 🤣'],
#  ['@EvaFoxU So it goes …'],
#  ['@gainzy222 Fate loves irony'],
#  ['@DavidSacks Even so, we should still do good deeds'],
#  ['The hell with it … even though Starlink is still losing money &amp; other companies are getting billions of taxpayer $, we’ll just keep funding Ukraine govt for free'],
#  ['@Brian_J_Berger That dude is not just a “condition of anonymity” spineless coward, he’s also an ignorant fool.',
#   'Starlink was directly requested by the Ukraine government, as it was the only thing that worked.'],
#  ['@spideycyp_155 @PPathole @ashleevance It has required a lot of our resources.',
#   'Going into super lockdown mode slows down new development progress, as we have to resist attacks from a sophisticated adversary actively at war.'],
#  ['@ashleevance DoD provided about 3% of the Falcon 1 development cost.',
#   'Appreciated, certainly, but should be seen in context.'],
#  ['@PPathole @ashleevance Of course.',
#   'And their signal jamming systems are also getting better.'],
#  ['@ashleevance The amount SpaceX is requesting for a major battlefield advantage is less than the cost of one new GPS satellite.',
#   'Ironically, GPS doesn’t work on battlefields, as the signal is easy to jam, but Starlink does.'],
#  ['@ajtourville Would be great if someday humanity stopped pointing nukes at itself that would destroy almost all life on Earth.',
#   'In any given year, there is a chance above zero that they will be launched.',
#   'We are now at the highest risk in 60 years.',
#   'https://t.co/hSqNeYHNX1'],
#  ['@WholeMarsBlog Curses, foiled again!'],
#  ['@rich_teer @ajtourville 😉'],
#  ['@mtaibbi Accurate'],
#  ['@ajtourville Russia has the ability to destroy USA &amp; Europe utterly with nuclear missiles in less than 30 minutes &amp; vice versa.',
#   'A surprising number of people don’t know this.',
#   'Of course, it would be MAD to use them, but it is also MAD to be in this situation at all.'],
#  ['@nichegamer This has potential'],
#  ['@rschmied @spideycyp_155 @SawyerMerritt @SpaceX Internet fiber, phone lines, cell towers &amp; other space-based comms in war areas have been destroyed.',
#   'Starlink is all that’s left.',
#   'For now.',
#   'https://t.co/CdjbOWgziz'],
#  ['@FedorovMykhailo Thank you for clarifying this 💙🇺🇦💛'],
#  ['@StonksReddit @rschmied @spideycyp_155 @SawyerMerritt @SpaceX Starlink is the primary communications system of the Ukrainian army on the war front.',
#   'If anyone else wants this job, please be my guest …'],
#  ['@rschmied @spideycyp_155 @SawyerMerritt @SpaceX Big difference between peace comms vs warfront comms.',
#   'Starlink is only comms system still working at warfront – others all dead.',
#   'Russia is actively trying to kill Starlink.',
#   'To safeguard, SpaceX has diverted massive resources towards defense.',
#   'Even so, Starlink may still die.'],
#  ['@EvaFoxU @Nobody_Really7 @EvaKBartlett Concerning'],
#  ['@EvaFoxU @Nobody_Really7 @EvaKBartlett https://t.co/XTWjF4lv9o'],
#  ['@stillgray Are there citizens of nations who are helping Ukraine on this list?'],
#  ['@ajtourville But surely no reasonable person would launch nuclear war?',
#   'The problem with that logic is if we were dealing with reasonable people, we wouldn’t have war in the first place.'],
#  ['@EvaKBartlett Is this list real?', 'What’s the URL?'],
#  ['@Rainmaker1973 People should never fear turbulence.',
#   'Commercial airliner wings can handle insane amounts of bending.'],
#  ['@mtaibbi The right question to ask'],
#  ['@officejjsmart @MelnykAndrij We’re just following his recommendation 🤷\u200d♂️'],
#  ['@narutium @SawyerMerritt Falcon can probably get Starlink past breakeven, but Starship is needed to fund Mars'],
#  ['@TeslaOwnersEBay @SawyerMerritt @SpaceX Yes'],
#  ['@spideycyp_155 @SawyerMerritt @SpaceX In addition to terminals, we have to create, launch, maintain &amp; replenish satellites &amp; ground stations &amp; pay telcos for access to Internet via gateways.',
#   'We’ve also had to defend against cyberattacks &amp; jamming, which are getting harder.',
#   'Burn is approaching ~$20M/month.'],
#  ['@SawyerMerritt Also, Starlink is still losing money!',
#   'It is insanely difficult for a LEO communications constellation to avoid bankruptcy – that was the fate of every company that tried this before.',
#   'When asked what the goal of Starlink was at a space conference, I said “not go bankrupt”.'],
#  ['@BogusThought @SawyerMerritt @rfdctr Maybe the 🐈 got their 👅'],
#  ['@spideycyp_155 @SawyerMerritt @rfdctr @SpaceX Very few in Iran so far'],
#  ['@SawyerMerritt Strange that nothing was leaked about our competitors in space launch &amp; communications, Lockheed &amp; Boeing, who get over $60B …\r\n\r\nWouldn’t be surprised to find this particular individual working there when he retires from DoD.',
#   'Corruption at its finest.'],
#  ['@SawyerMerritt @rfdctr SpaceX is not asking to recoup past expenses, but also cannot fund the existing system indefinitely *and* send several thousand more terminals that have data usage up to 100X greater than typical households.',
#   'This is unreasonable.'],
#  ['@MuskUniversity Vital to the future of consciousness'],
#  ['@andst7 🤣'],
#  ['@BogusThought srsly'],
#  ['@teslaownersSV @JohnnaCrider1 Next week'],
#  ['@JohnnaCrider1 Envy has driven him to madness'],
#  ['@leehumerian Starlink requires nothing except ~50 Watt power source.',
#   'With a small solar system plus battery or a generator, you will have connectivity anywhere.'],
#  ['@OwenSparks_ @spideycyp_155 @FedorovMykhailo @SpaceX True'],
#  ['@spideycyp_155 @FedorovMykhailo @SpaceX There are some active terminals'],
#  ['@spideycyp_155 @FedorovMykhailo @SpaceX Of course, this happens almost every day.',
#   'They successfully destroyed Viasat in Ukraine several months ago.',
#   'https://t.co/xrrAMqfsZY'],
#  ['@spideycyp_155 @FedorovMykhailo @SpaceX Starlink has faced relentless jamming attacks &amp; SpaceX relentless cyberwar.',
#   'So far, their success has been limited.'],
#  ['@KoguanLeo Noted'],
#  ['@FedorovMykhailo Starlink data usage growth in Ukraine https://t.co/c4IWNwKwLR'],
#  ['@RobLockwood @JeffBezos https://t.co/1EwWyqvwkr'],
#  ['20,000!', '!'],
#  ['@RGVaerialphotos Cool'],
#  ['@ByeonChansoo @garyblack00 Maybe with .3'],
#  ['This is real'],
#  ['https://t.co/WLVh5zBiO5'],
#  ['@Teslarati @JohnnaCrider1 🎯 “My opinion is Burnt Hair is just Elon saying, chill out, have a laugh, and share a laugh.”'],
#  ['@WholeMarsBlog Oh the irony 🤣🤣'],
#  ['We might need a different name, as this is basically just Starlink with roaming capability, so you can take your terminal anywhere.',
#   'https://t.co/gnH0YPPVOS'],
#  ['@teslaownersSV The counter-intuitive thing is that it’s actually gonna be a sick product!'],
#  ['Please buy my perfume, so I can buy Twitter'],
#  ['And right on cue 🤣🤣 … https://t.co/RysKrHeJfi'],
#  ['@FedorovMykhailo You’re most welcome.', 'Glad to support Ukraine.'],
#  ['Doesn’t get more lit than this!'],
#  ['BE the change you want in the world!'],
#  ['Can’t wait for media stories tomorrow about $1M of Burnt Hair sold 🤣'],
#  ['10,000 bottles of Burnt Hair sold!'],
#  ['@Kristennetten 💯🎯'],
#  ['Over 5000 bottles of Burnt Hair sold!'],
#  ['An omnigender product'],
#  ['https://t.co/WDtHXqgUPx'],
#  ['With a name like mine, getting into the fragrance business was inevitable – why did I even fight it for so long!',
#   '?'],
#  ['And you can pay with Doge!'],
#  ['The finest fragrance on Earth!',
#   'https://t.co/ohjWxNX5ZC https://t.co/0J1lmREOBS'],
#  ['@ianbremmer Nobody should trust Bremmer'],
#  ['Maybe one day we can finally achieve https://t.co/jKBu2wJIDA'],
#  ['The next question one is typically asked is “Have you tried ayahuasca?”\r\nhttps://t.co/zo3Lw6nlxw'],
#  ['https://t.co/Q31B9x4RCH'],
#  ['@JoshuaPGallaway @Susiecmd @CYBERTRCK @LindseyGrahamSC Not subtle'],
#  ['@SamHarrisOrg @tegmark Sam, there is a such a thing as meditating too much'],
#  ['@teslaownersSV @PPathole @NorthmanTrader Yes, back to regularly scheduled programming'],
#  ['@PPathole @NorthmanTrader Pointless, as there is currently no overlap between Russian and Ukrainian demands – it’s not even close'],
#  ['@NorthmanTrader No, it is not.',
#   'I have spoken to Putin only once and that was about 18 months ago.',
#   'The subject matter was space.'],
#  ['@kanyewest Talked to ye today &amp; expressed my concerns about his recent tweet, which I think he took to heart'],
#  ['@Teslarati @JohnnaCrider1 It was built &amp; paid for at my request.',
#   'Hunter &amp; team did great work.'],
#  ['@CathieDWood 💯'],
#  ['@WholeMarsBlog It will'],
#  ['@chicago_glenn @neiltyson Strange @Twitter'],
#  ['@WholeMarsBlog I have no desire to become involved in wars, but it is safe to say that all bets are off if the nukes start flying'],
#  ['@Teslarati Strong candidate to win most counter-intuitive product of the year!'],
#  ['@MuskUniversity Important to bear in mind when reading anything'],
#  ['@neiltyson Indeed, that kinetic energy scales with the square of velocity is not well-appreciated!',
#   'A sealed escape pod with a heat shield would probably work.'],
#  ['@lexfridman So many blind spots'],
#  ['@EPavlic @boringcompany 🎯'],
#  ['@spideycyp_155 @EvaFoxU There are ~25k terminals in Ukraine, but each terminal can be used to provide an Internet uplink to a cell phone tower, so potentially several thousand people can be served by a single terminal'],
#  ['Coming soon from The @BoringCompany https://t.co/cNIbFRRXyt'],
#  ['@Scobleizer Yup, it will float'],
#  ['@spideycyp_155 @MirrorinSpace @NASAEarthMars Too busy trying to survive at the time'],
#  ['@MirrorinSpace @NASAEarthMars They were invited to further their career elsewhere'],
#  ['@ace_constantine @NASAEarthMars There is a giant 30ft (literal) fork in the road outside the Autopilot office in Palo Alto'],
#  ['@SirineAti @NASAEarthMars Mine'],
#  ['@ace_constantine @NASAEarthMars I love the inverse poetry of making metaphors literal'],
#  ['@NASAEarthMars That is quite an interesting story.',
#   'We sent what appeared to be identical emails to all, but each was actually coded with either one or two spaces between sentences, forming a binary signature that identified the leaker.'],
#  ['Because it runs recursively'],
#  ['@tegmark Nuclear war probability is rising rapidly'],
#  ['An eye for an eye leaves everyone blind https://t.co/pQztPvR4uI'],
#  ['@EvaFoxU Perhaps we can talk again today?'],
#  ['@spideycyp_155 @EvaFoxU True, Starlink provided a decisive battlefield advantage'],
#  ['@EvaFoxU I’ve been up all night trying to think of any possible way to de-escalate this war'],
#  ['@EvaFoxU Feels so long ago.', 'A pleasant memory :)'],
#  ['https://t.co/VvGa39qAyE'],
#  ['@NASASpaceflight Double-header'],
#  ['@davidmarcus @PayPal Agreed'],
#  ['@Rainmaker1973 Beautiful'],
#  ['@andst7 💯'],
#  ['@kanyewest Welcome back to Twitter, my friend!'],
#  ['@muskQu0tes 💯'],
#  ['@wintonARK Dojo uses bf16, so actual performance difference vs 64 bit is much less than it would seem, since you truncate so many useless zeroes &amp; round from there'],
#  ['@sashayanshin 🤣'],
#  ['@SirineAti @SpaceX Two Dragons on @Space_Station'],
#  ['@Teslarati @ajtourville @JohnnaCrider1 Can’t wait to see this beast in action!'],
#  ['@WholeMarsBlog Even better build coming next week'],
#  ['@dogeofficialceo @spideycyp_155 @SawyerMerritt @ChristopherJM @FT @MehulAtLarge @felschwartz Quite a few.',
#   'Trying to do the right thing, which is not always clear.'],
#  ['@spideycyp_155 @SawyerMerritt @ChristopherJM @FT @MehulAtLarge @felschwartz I am in regular contact with Fedorov'],
#  ['@ChristopherJM @FT @MehulAtLarge @felschwartz Bad reporting by FT.',
#   'This article falsely claims that Starlink terminals &amp; service were paid for, when only a small percentage have been.',
#   'This operation has cost SpaceX $80M &amp; will exceed $100M by end of year.',
#   'As for what’s happening on the battlefield, that’s classified.'],
#  ['@skorusARK Starlink will provide the vast majority of bandwidth from space'],
#  ['@RGVaerialphotos You’d need an electric propeller mounted on the tow hitch to go faster than a few knots.',
#   'There might a creative wheel hub design that can generate meaningful thrust.'],
#  ['@EvaFoxU Norway rocks!', '♥️♥️ 🇳🇴 🇳🇴'],
#  ['In case you missed Tesla AI Day 2022\r\nhttps://t.co/Sbu0peXpY1'],
#  ['@skorusARK Satellite constellation capability comes down to tonnage to orbit per year times capability per ton'],
#  ['SpaceX Dragon docking with @Space_Station (extended video) https://t.co/AFBDKHddgI'],
#  ['@Teslaconomics Very intense 7 days indeed'],
#  ['@alifarhat79 @NotParagAgrawal 🤣'],
#  ['@BillyM2k 🤣💯'],
#  ['@stevenmarkryan @nichegamer @Twitter Personally, I like the latter, but to each their own'],
#  ['@stevenmarkryan @nichegamer @Twitter I think being able to dial the content you see from “warm &amp; fuzzy” all the way to “bring it on mf!” is the way to go'],
#  ['@nichegamer @Twitter Software engineering, server operations &amp; design will rule the roost'],
#  ['@nichegamer @Twitter There will be very rapid product evolution'],
#  ['500 mile range &amp; super fun to drive'],
#  ['Excited to announce start of production of Tesla Semi Truck with deliveries to @Pepsi on Dec 1st!',
#   'https://t.co/gq0l73iGRW'],
#  ['@NASASpaceflight Tiny helium leak (just barely triggered abort), but we take no risks with customer satellites.',
#   'Standing down to investigate.'],
#  ['@KyivIndependent 🤔'],
#  ['@BillyM2k Agreed'],
#  ['@POTUS 👍'],
#  ['@Teslarati @JohnnaCrider1 Plot twist!'],
#  ['@cb_doge Elon liking his own tweets liking his own tweets …'],
#  ['@SpaceX Dragon is now docked to @Space_Station'],
#  ['Video https://t.co/9gUJv2V143'],
#  ['Starlink view of 2nd stage deorbit burn https://t.co/kbLv95bAK7'],
#  ['@realAdrianDa32 @HuXijin_GT 👍🤣'],
#  ['@HuXijin_GT 手整体插在口袋里的人过分自信'],
#  ['@Xu0P5C4rMmMKUdu @stillgray @atrupar @LindseyGrahamSC I will try my best'],
#  ['@KyivPost I’m a big fan of Ukraine, but not of WW3'],
#  ['@spideycyp_155 @garyblack00 🤣'],
#  ['@garyblack00 https://t.co/FxgYMhTax6'],
#  ['@Rainmaker1973 Cute.',
#   'You can get surprisingly close to a wild baby rhino &amp; Mom if you stay downwind.'],
#  ['@stillgray @atrupar @LindseyGrahamSC There are no angels in war.'],
#  ['@EliClifton @DavidSacks Accurate assessment'],
#  ['@garyblack00 Correct'],
#  ['@stevenmarkryan So they’re saying that not buying Twitter is bad, but also buying Twitter is bad!',
#   '?'],
#  ['@LucidTrading_ @DavidSacks We talked via videoconference last year'],
#  ['@DavidSacks 🤣'],
#  ['War is the ultimate Supreme Court'],
#  ['@bdquinn @LindseyGrahamSC Kherson and Zaporizhzhia almost certainly do not want to join Russia – annexation of those regions was done to ensure a land bridge and water supply to Crimea'],
#  ['@LindseyGrahamSC Obviously, not everyone who voted for the pro-Russia party wanted to join Russia, but it would also be inaccurate to say that none did.'],
#  ['@LindseyGrahamSC Below is the electoral map of 2012.',
#   'Blue is the pro-Russia party.',
#   'https://t.co/YkZ9hipyAV'],
#  ['@LindseyGrahamSC Assuming you believe that the will of the people matters, we should, in any given conflict region, support the will of those who live there.',
#   'Most of Ukraine unequivocally wants to be part of Ukraine, but some eastern portions have Russian majorities and prefer Russia.'],
#  ['@LindseyGrahamSC First of all, Tesla hasn’t had that consumer tax credit for years &amp; we didn’t ask for this one – GM &amp; Ford did'],
#  ['@LangmanVince @LindseyGrahamSC 🤣'],
#  ['Another batch of Starlinks in orbit, 7 hours after the astronaut launch https://t.co/mQshEY16RP'],
#  ['@ashleevance That wouldn’t be hard to do'],
#  ['@BillyM2k 🤣'],
#  ['@TEDchris Twitter is an accelerant to fulfilling the original https://t.co/bOUOek5Cvy vision'],
#  ['@KonstantinKisin I do not think it is simple at all, but I have yet to hear any realistic path to peace.',
#   'Ukraine has achieved many brilliant tactical victories, but should be wary of overconfidence leading to strategic defeat.',
#   'When Russia fully mobilizes, millions on both sides will die.'],
#  ['@WholeMarsBlog 10.69.3 will actually be a major upgrade.',
#   'We’re keeping .69 just because haha.'],
#  ['@LarckeningXuruo Twitter probably accelerates X by 3 to 5 years, but I could be wrong'],
#  ['Buying Twitter is an accelerant to creating X, the everything app'],
#  ['@BillyM2k @unusual_whales 🤣'],
#  ['@SawyerMerritt Should be noted that Starlink is still far from cash flow positive.',
#   'All LEO communications constellations to date have gone bankrupt, so any support is super helpful.'],
#  ['@FrenchyRagin @Kasparov63 A small number of terminals were paid for by the govt, vast majority were not.',
#   'This is just another bs WaPo hit piece.'],
#  ['@ZelenskyyUa I still very much support Ukraine, but am convinced that massive escalation of the war will cause great harm to Ukraine and possibly the world.'],
#  ['@Kasparov63 We gave Starlinks to Ukraine &amp; lost $80M+ in doing so, while putting SpaceX &amp; myself at serious risk of Russian cyberattack.',
#   'What have you done besides tweet?'],
#  ['@DavidSacks SpaceX’s out of pocket cost to enable &amp; support Starlink in Ukraine is ~$80M so far.',
#   'Our support for Russia is $0.',
#   'Obviously, we are pro Ukraine.',
#   'Trying to retake Crimea will cause massive death, probably fail &amp; risk nuclear war.',
#   'This would be terrible for Ukraine &amp; Earth.'],
#  ['@slashdot In other news, remote controlled anal beads sold out everywhere'],
#  ['@micsolana 🤣'],
#  ['@spideycyp_155 @StonksReddit @Podolyak_M That referendum was questionable, which is why I suggested repeating it under UN (or other trusted entity) supervision'],
#  ['@StonksReddit @Podolyak_M Great, offer a UN supervised vote and if Russia refuses, then war it is'],
#  ['@Podolyak_M Maybe a similar approach to Kosovo https://t.co/cGPpaXAaA3'],
#  ['@Podolyak_M No, I’m suggesting voting under UN (or pick your most trusted entity or country) supervision'],
#  ['@RenataKonkoly Russia is doing partial mobilization.',
#   'They go to full war mobilization if Crimea is at risk.',
#   'Death on both sides will be devastating.',
#   'Russia has &gt;3 times population of Ukraine, so victory for Ukraine is unlikely in total war.',
#   'If you care about the people of Ukraine, seek peace.'],
#  ['@RenataKonkoly You are assuming that I wish to be popular.',
#   'I don’t care.',
#   'I do care that millions of people may die needlessly for an essentially identical outcome.'],
#  ['Let’s try this then: the will of the people who live in the Donbas &amp; Crimea should decide whether they’re part of Russia or Ukraine'],
#  ['@PopMech Cheese is amazing'],
#  ['@Nemli_mot Indeed.', 'Biggest bot attack I’ve ever seen.'],
#  ['@raulsanchezuk The bot attack on this poll is strong!'],
#  ['@AkiKivirinta The will of the people should decide whether they are part of Russia or Ukraine, but Russia invaded areas that would unequivocally choose to be part of Ukraine'],
#  ['Also worth noting that a possible, albeit unlikely, outcome from this conflict is nuclear war'],
#  ['This is highly likely to be the outcome in the end – just a question of how many die before then'],
#  ['Ukraine-Russia Peace:\r\n\r\n- Redo elections of annexed regions under UN supervision.',
#   'Russia leaves if that is will of the people.',
#   '- Crimea formally part of Russia, as it has been since 1783 (until Khrushchev’s mistake).',
#   '- Water supply to Crimea assured.',
#   '- Ukraine remains neutral.'],
#  ['@jasondebolt Yes'],
#  ['@jasondebolt That is my assessment too'],
#  ['@tim_zaman Well-said!',
#   'Also, we try to operate the team as non-hierarchically as possible &amp; allow movement between project areas, so you don’t get pigeon-holed.'],
#  ['@PPathole @Tesla @SpaceX @neuralink @boringcompany I’m trying my hardest!',
#   'Perhaps more people might consider loving humanity.',
#   'Our collective light of consciousness is a tiny candle in a vast darkness.',
#   'Please do not let it go out.'],
#  ['@cb_doge @Tesla Optimus will be sickkk'],
#  ['@cb_doge @Tesla 👀'],
#  ['@WholeMarsBlog Would be cool to make a game using Tesla Sim that’s literally your city &amp; neighborhood, down to skid marks on road &amp; then inject fantasy/sci-fi elements'],
#  ['@cb_doge @WholeMarsBlog Occasionally'],
#  ['@WholeMarsBlog And people wonder why I sometimes think we’re in a simulation …'],
#  ['https://t.co/cGHSTdb9gv'],
#  ['@WholeMarsBlog 144 trillion operations per second'],
#  ['@DaltBrewer The embarrassing hose down photos were highly motivating tbh'],
#  ['https://t.co/inO8f1q38o'],
#  ['@WholeMarsBlog Tunneled under the road from one property to another.',
#   'This is to test the new machine.'],
#  ['@PPathole Unfortunately, snail is still faster, but TBC might beat snail by end of 2024'],
#  ['Prufrock II emerging from the ground https://t.co/csamCrmAZa'],
#  ['@OwenSparks_ @GerberKawasaki But between now and then, we do actually need to work hard'],
#  ['@GerberKawasaki I don’t care about boosting the stock, but the economic implications are obvious'],
#  ['Do not let ancient grudge break to new mutiny'],
#  ['@chicago_glenn @Pontifex So many talented Russians in America'],
#  ['@WholeMarsBlog Customer experience suffers when there is an end of quarter rush.',
#   'Steady as she goes is the right move.'],
#  ['@Pontifex War always gives ample reason for vengeance for all sides.',
#   'Only by overcoming this instinct can there be peace.'],
#  ['@WholeMarsBlog Smoothing out crazy end of quarter delivery wave to reduce expedite costs &amp; relieve stress on Tesla team.',
#   'Aiming for steadier deliveries intra-quarter.'],
#  ['@WholeMarsBlog It’s funny reading simultaneous criticism that it’s already been done, but also it’s impossible 🤣'],
#  ['@streetpeopleLA @KitsonLA ?', '?'],
#  ['@DoctorJack16 Master Plan (mé·nage à) Trois is all about tonnage'],
#  ['@OriolVinyalsML @Tesla @karpathy Thanks, we have a great team'],
#  ['@Rainmaker1973 Beautiful'],
#  ['@wintonARK Exactly'],
#  ['https://t.co/HdUl0etoao'],
#  ['Recording of Tesla AI Day 2022 \r\nhttps://t.co/7LR51x7pXa'],
#  ['Join https://t.co/FgKC8Zt4k9'],
#  ['@chicago_glenn @EvasTeslaSPlaid A little'],
#  ['@WholeMarsBlog That and giving it a brain'],
#  ['@EvasTeslaSPlaid And Wegovy'],
#  ['@ICannot_Enough Yes'],
#  ['@EvasTeslaSPlaid Fasting'],
#  ['@Don_lyall @Neuro_Skeptic Uh oh, mine must be tiny!'],
#  ['@karpathy 🤣'],
#  ['🤖 🖤 https://t.co/eNhVVztXHM'],
#  ['https://t.co/NluTMRAQfa'],
#  ['@AstroJordy 🔥🔥'],
#  ['@NASASpaceflight 💯'],
#  ['https://t.co/PHa7kKhFoT'],
#  ['Naturally, there will be a catgirl version of our Optimus robot'],
#  ['The point of AI Day is to show the immense depth &amp; breadth of Tesla in AI, compute hardware &amp; robotics'],
#  ['@cb_doge @Tesla 🤣'],
#  ['@teslaownersSV Yup'],
#  ['@RyanAFournier Should be according to greatest need, not race or anything else'],
#  ['@ValaAfshar !', '!'],
#  ['Webcast link https://t.co/TrtjKph4Mk'],
#  ['Tesla AI Day 2022 starts at precisely 6:15pm California time'],
#  ['@teslaownersSV @Tesla Tesla team is awesome, such an honor to work with them!'],
#  ['@MuskUniversity Now'],
#  ['@WholeMarsBlog That is not cgi'],
#  ['@WholeMarsBlog The hands of Optimus'],
#  ['@engineers_feed I still love the 747.', 'Epic plane.'],
#  ['@SawyerMerritt Haha 💯'],
#  ['@Rainmaker1973 Such an incredible engine!'],
#  ['@ajtourville 🤣'],
#  ['@NASAHubble @NASA @SpaceX Yay'],
#  ['@MuskUniversity True'],
#  ['Needs be able to get from Starbase to South Padre Island, which requires crossing the channel'],
#  ['@WholeMarsBlog Off-label use 🤣'],
#  ['Cybertruck will be waterproof enough to serve briefly as a boat, so it can cross rivers, lakes &amp; even seas that aren’t too choppy'],
#  ['@phibetakitten Submarines use electric motors under water …'],
#  ['Works on land too'],
#  ['As well as advanced chip &amp; supercomputer engineers for next-gen training &amp; inference'],
#  ['Note, this event is meant for recruiting AI &amp; robotics engineers, so will be highly technical https://t.co/BcxAEv6qJd'],
#  ['@stevenmarkryan Pretty much.',
#   'AI/robotics engineers who understand what problems need to be solved will like what they see.'],
#  ['@WholeMarsBlog @Gfilche There will be lots of technical detail &amp; cool hardware demos'],
#  ['@Gfilche Good analysis'],
#  ['Rated for 280+ kph (174+ mph) winds https://t.co/qJBdykpTT9'],
#  ['Starlink Maritime system enables high speed Internet connectivity even in heavy seas &amp; hurricane winds https://t.co/6R4p73UGOT'],
#  ['Last coal shipment arrived in Hawaii at same time as Tesla Megapack batteries that will enable 24/7 sustainable energy https://t.co/zlqJHLsAQq'],
#  ['@BryceSpaceTech @SpaceX Still very tiny potatoes compared to what’s needed to make life multiplanetary'],
#  ['@BryceSpaceTech @SpaceX SpaceX now delivering about twice as much payload to orbit as rest of world combined'],
#  ['@Reuters Extremely concerning'],
#  ['@Teslarati @KlenderJoey How ironic, that’s what Henrik Fisker did to Tesla in 2007!',
#   'Karma is a …'],
#  ['@alex_avoigt They need to add a lot of batteries to the grid to buffer energy'],
#  ['https://t.co/mEBAgBCCkj'],
#  ['I guess this joke is a slow burn … 🥁'],
#  ['@WholeMarsBlog Big improvement in high speed cross-traffic velocity NN coming next month'],
#  ['@chrispavlovski @dbongino @rustyrockets Maybe worth talking at some point'],
#  ['Make “hair on fire” not just a metaphor'],
#  ['https://t.co/1hbMzueALi'],
#  ['Stand out in a crowd!', 'Get noticed as you walk through the airport!'],
#  ['Coming soon from @BoringCompany, the same people that sold you a Flamethrower'],
#  ['“Burnt Hair” – Scent for Men by Singed'],
#  ['@dbongino @rustyrockets I’m a little preoccupied rn'],
#  ['@ID_AA_Carmack Batteries ftw'],
#  ['@rustyrockets Good point'],
#  ['My son, Saxon, was amazed that so many paper newspapers are still produced every day.',
#   'He said they probably just search the Internet &amp; print it out.',
#   'Yup, with rare exception, that is *actually* what they do haha.'],
#  ['https://t.co/RcKPRe8eiM'],
#  ['Falcon 9 fairing cam captures 2nd stage plume, booster entry burn &amp; Earth in twilight https://t.co/ga9MpZKvK2'],
#  ['@lacker @ilyasut Even then, Lenin would’ve gotten nowhere without Ludendorff’s train'],
#  ['@Tesmanian_com Charming …'],
#  ['https://t.co/qeiDmU3sOg'],
#  ['https://t.co/2wpp3F31jA'],
#  ['Starlink now over 1M user terminals manufactured'],
#  ['@Stephen_Geiger Siegel is obviously correct'],
#  ['@SecBlinken Activating Starlink …'],
#  ['@teslaownersSV @stevenmarkryan Education is the path out of poverty and Internet access enables education'],
#  ['@stevenmarkryan Exactly'],
#  ['Starlink connecting schools in the Amazon https://t.co/Xy70D0sk8N'],
#  ['@jackfarrington @PopMech It is'],
#  ['@PopMech Why is this a PopMech story?'],
#  ['@BillyM2k https://t.co/vFVHaB1l4t https://t.co/PupzZNZcPE'],
#  ['@ajtourville @Twitter @paraga Yup (sigh)'],
#  ['@MuskUniversity Fully reusable orbital rockets are the fundamental breakthrough needed for humanity to become a multiplanet species'],
#  ['@stocktalkweekly @WholeMarsBlog @SawyerMerritt The terminology is outdated &amp; inaccurate.',
#   'This is a tiny over-the-air software update.',
#   'To the best of our knowledge, there have been no injuries.'],
#  ['@JoeTegtmeyer @teslascope @johnkrausphotos Your car needs a camera upgrade, which is free of charge.',
#   'There are a few thousand cars in a similar situation.',
#   'Replacement cameras will be available early next month.'],
#  ['@Rainmaker1973 @biolocousb While (!pheromone) {}'],
#  ['@BillyM2k 🤣👍'],
#  ['@teslaownersSV @SawyerMerritt Shaded patio'],
#  ['@SawyerMerritt Actually, I live in a little house on Weems St that cost ~$50k (but I’ve done a lot with the place!)'],
#  ['@MuskUniversity Aka cogency'],
#  ['@BillyM2k Looks awesome 😎'],
#  ['@teslaownersSV @Teslarati Maybe little electric Tesla boats with a retro-futuristic Victorian design'],
#  ['@Teslarati Long-term goal is a boardwalk with amenities that goes all the way to downtown Austin, so you can walk, bike or kayak'],
#  ['@Teslarati Area from south Giga to river really will be next-level great &amp; open to public!'],
#  ['@Teslarati @KlenderJoey Ecological paradise plans from south portion of Giga Texas to river look great, however we must first get the factory financially on its feet'],
#  ['@enn_nafnlaus @treygahigh @TaraBull808 @theliamnissan @RBReich I was instrumental in creating OpenAI, which made DALL-E'],
#  ['@enn_nafnlaus @treygahigh @TaraBull808 @theliamnissan @RBReich Although his methods of instruction very strongly favored stick over carrot, I did learn a tremendous amount of engineering from him &amp; appreciation of art (he is an extremely talented artist)'],
#  ['@enn_nafnlaus @TaraBull808 @treygahigh @theliamnissan @RBReich Boys High was a good school, but it was government, not private.',
#   'Brooklyn would be considered a middle income, not exclusive, neighborhood in America.'],
#  ['@enn_nafnlaus @TaraBull808 @treygahigh @theliamnissan @RBReich For sure'],
#  ['@enn_nafnlaus @treygahigh @TaraBull808 @theliamnissan @RBReich Errol ran out of money in the 90’s.',
#   'My brother &amp; I financially supported him &amp; his extended family in South Africa since then on condition that he not do bad things.',
#   'Unfortunately, he did do bad things :('],
#  ['@enn_nafnlaus @treygahigh @TaraBull808 @theliamnissan @RBReich This is true'],
#  ['@Teslarati @ResidentSponge With some improvements, it will achieve 300 Mps'],
#  ['@enn_nafnlaus @TaraBull808 @treygahigh @theliamnissan @RBReich Incorrect.',
#   'There was tuition for students from outside the school district, which was a small part of the student body, incl black students, but not for students in district, which I was.',
#   'Also, I was there for 2.5 years, previously attending govt schools for 9 of 12 years.'],
#  ['@enn_nafnlaus @treygahigh @TaraBull808 @theliamnissan @RBReich I went to government schools, not private, except for part of one year in third grade'],
#  ['@NASASpaceflight @yasin_shafiei @thejackbeyer @BocaChicaGal @NicAnsuini Probably Q2 next year, with vehicles initially transferred by boat from Port of Brownsville to the Cape'],
#  ['@cb_doge @PPathole @RBReich 🤣'],
#  ['@PPathole @RBReich https://t.co/82b0Msiktf'],
#  ['@BnOrdhaug @yasin_shafiei @thejackbeyer @NASASpaceflight @BocaChicaGal @NicAnsuini That’s the plan.',
#   'We’re taking a little  risk there, as engine isolation was done as retrofit, so not as good as on Booster 9.'],
#  ['@yasin_shafiei @thejackbeyer @NASASpaceflight @BocaChicaGal @NicAnsuini Late next month maybe, but November seems highly likely.',
#   'We will have two boosters &amp; ships ready for orbital flight by then, with full stack production at roughly one every two months.'],
#  ['@thejackbeyer @NASASpaceflight @BocaChicaGal @NicAnsuini Our focus is on reliability upgrades for flight on Booster 7 and completing Booster 9, which has many design changes, especially for full engine RUD isolation.'],
#  ['@enn_nafnlaus @theliamnissan @RBReich Exactly'],
#  ['@teslaownersSV @chicago_glenn @Twitter Seems that way @Twitter @paraga'],
#  ['@chicago_glenn .', '@Twitter what’s going on?'],
#  ['@TrungTPhan @McDonalds Such miracles are impossible'],
#  ['@ruffpast @stevenmarkryan @SawyerMerritt @mayemusk @RBReich @PenguinBooks That’s a real picture?'],
#  ['@stevenmarkryan @SawyerMerritt @mayemusk @RBReich @PenguinBooks Absolutely'],
#  ['@jhall @RBReich Unsurprisingly, Reich is also a hypocrite'],
#  ['@teslaownersSV @RBReich Reich is suicidally boring'],
#  ['@TrungTPhan 🤣'],
#  ['@RBReich You both an idiot and a liar'],
#  ['@BillyM2k 🤣'],
#  ['@ajtourville @parag @Twitter Curiouser and curiouser …'],
#  ['@BillyM2k @Austen Same'],
#  ['@BLKMDL3 @teslascope @johnkrausphotos Yes'],
#  ['@ToscaMusk @kimbal Happy birthday bro, love you'],
#  ['@teslascope @johnkrausphotos Yes, all US &amp; Canada cars with safety scores above 80 should receive an invitation to download FSD Beta by tomorrow'],
#  ['@teslaownersSV @johnkrausphotos Note, Autopilot/AI team is also working on Optimus and (actually smart) summon/autopark, which have end of month deadlines'],
#  ['@teslaownersSV @johnkrausphotos Next month'],
#  ['@johnkrausphotos Yes'],
# ...
#  ['👿 https://t.co/hdzRzphcii'],
#  ['@chazman @aelluswamy Glad it’s working out!',
#   'Thanks for giving us this tough case to solve.',
#   'That’s what field testing is all about.',
#   'This early version of 10.69 is being extra cautious, so waits for a moderately big gap in traffic to cross.',
#   'Upcoming releases will do better in heavy traffic.'],
#  ['@chazman @aelluswamy Just wanted to emphasize again that our awesome Tesla software/AI team is who really deserves the credit.',
#   'The talent level at Tesla is incredible.'],
#  ['Note, you can upgrade your existing car to FSD in 2 mins via the Tesla app'],
#  ['After wide release of FSD Beta 10.69.2, price of FSD will rise to $15k in North America on September 5th.',
#   'Current price will be honored for orders made before Sept 5th, but delivered later.'],
#  ['FSD Beta 10.69 started rolling out to Tesla owners last night.',
#   'This build is a big step forward!',
#   '10.69.1 probably end of week with wider release.',
#   '1069.2 in a few weeks should be good enough to provide to all FSD Beta participants.'],
#  ['@BLKMDL3 @Tesla Tesla Autopilot/AI team did great work with 10.69!',
#   'Some point releases needed for polish, so 10.69.2 should really shine.'],
#  ['@Teslarati @Tesla @WholeMarsBlog @JohnnaCrider1 🤔'],
#  ['@aelluswamy Worth hearing about Tesla Autopilot software/AI progress'],
#  ['@WholeMarsBlog As mentioned previously, this is a major release, so we need to be cautious.',
#   'Goes out to ~1000 Beta participants later today.'],
#  ['@WholeMarsBlog 🤣💯👍'],
#  ['@Andst7 🤣'],
#  ['Might need a new PO Box after tweeting this 🤣'],
#  ['Nice letter from Bill Nix, who would’ve been my prof at Stanford if I hadn’t put grad studies on (permanent) deferment https://t.co/ioq0mGwN7K'],
#  ['@SpaceX Each fairing half is a fully capable reentry vehicle with its own thrusters, thermal protection, avionics &amp; sensor suite'],
#  ['@Dilbert_Daily Free Willy was never free 😢'],
#  ['Still so grateful \U0001f979 https://t.co/EhdyXw4fqN'],
#  ['@teslaownersSV @CChomp13 There are many major code changes, so this will be an extra cautious rollout.',
#   'Releasing on 8/20 to ~1000 Tesla owners, then 10.69.1 next week to accommodate feedback &amp; release to ~10k customers, then 10.69.2 week after &amp; release to rest of FSD Beta.'],
#  ['@CChomp13 Entropy'],
#  ['https://t.co/KBjnfkU4ia'],
#  ['@Andst7 Those are the questions that Twitter is doing everything possible to avoid answering …'],
#  ['@SawyerMerritt @ICannot_Enough Modifying your car after delivery is legal in America, so yes 😀'],
#  ['@ICannot_Enough That said, we will add autoconfigure to side mirrors'],
#  ['@ICannot_Enough Side mirrors cause ~5% range reduction at highway speed'],
#  ['@ICannot_Enough Yes, but side mirrors won’t be needed in a self-driving future'],
#  ['@DogecoinNorway @micsolana 🤣'],
#  ['@micsolana 🤣'],
#  ['@ashleevance 🔥'],
#  ['@lexfridman 🔥🔥'],
#  ['@RationalEtienne @MuskUniversity For some reason, I just agree with that guy so much!'],
#  ['@mayemusk @kimbal @ToscaMusk 💕'],
#  ['🎶 This Magic Moment 🎶'],
#  ['@Kristennetten @wonderofscience *shall'],
#  ['Being a Mom is just as important as any career'],
#  ['Highly Recommend https://t.co/nrDZ4gJqEE'],
#  ['@waitbutwhy @trevorjacob93 😮'],
#  ['@wonderofscience Mercury, the forbidden candy'],
#  ['@MuskUniversity Yes'],
#  ['@MuskUniversity ♟'],
#  ['@Elon_Quotes_ Almost all of Earth’s energy comes from the sun already – we would be a dark iceball at near absolute zero if not for the sun.',
#   'And essentially the entire ecosystem is solar-powered.',
#   'Civilization uses a tiny amount of energy by comparison.',
#   'Not hard to generate from wind/solar.'],
#  ['@teslaownersSV Although, if it were any team, it would be Man U.',
#   'They were my fav team as a kid.'],
#  ['@BillyM2k no u'],
#  ['Standup is my side-hustle'],
#  ['@teslaownersSV And I’m not buying Coca-Cola to put the cocaine back in, despite the extreme popularity of such a move'],
#  ['@teslaownersSV No, this is a long-running joke on Twitter.',
#   'I’m not buying any sports teams.'],
#  ['@WholeMarsBlog @karpathy Got to build those YouTube subscriptions!'],
#  ['@BillyM2k 💯'],
#  ['@EvaFoxU Note, we are trying to reduce delivery times as quickly as possible.',
#   'Long wait times are not a good thing.'],
#  ['@realginnyrobins Yeah, that’s what I mean'],
#  ['Also, I’m buying Manchester United ur welcome'],
#  ['@Grimezsz The downside of elf ear surgery probably outweighs the upside'],
#  ['To be clear, I support the left half of the Republican Party and the right half of the Democratic Party!'],
#  ['@yangliuxh @ZichenWanghere Reasonably accurate translation'],
#  ['@WholeMarsBlog 🤣 ok we’ll turn it on'],
#  ['@teslaownersSV Yes.',
#   'Tesla Autopilot/AI team is doing amazing work!',
#   '10.69 will be worth its name.'],
#  ['@BillFOXLA Strange that this receives very little attention in the media'],
#  ['@BillFOXLA 400k from one border crossing in less than a year?'],
#  ['Congrats Giga Shanghai on making millionth car!',
#   'Total Teslas made now over 3M.',
#   'https://t.co/2Aee6slCuv'],
#  ['@teslaownersSV I hope there is a self-sustaining city on Mars in 20 years!'],
#  ['Just Read The Instructions https://t.co/BWYzSEE0Q8'],
#  ['@nichegamer @Twitter 🤣'],
#  ['@DBurkland @WholeMarsBlog 8/20'],
#  ['Ahem @twitter https://t.co/LCDpOeIei5'],
#  ['@techAU @wintonARK Would be pretty wild if a “car company” made the most powerful supercomputer on Earth …'],
#  ['@techAU @wintonARK We’ll phase in Dojo.',
#   'Won’t need to buy as many incremental GPUs next year.'],
#  ['@WholeMarsBlog @wintonARK Waitlist is too long.',
#   'Will enable again as we ramp production.'],
#  ['Adding the 13 inner engines https://t.co/ooOFEGl0Hr'],
#  ['@wintonARK Yikes'],
#  ['@MuskUniversity Yes'],
#  ['Another orbital plane of polar satellites https://t.co/UDl6wStLuT'],
#  ['@cb_doge There are no coincidences'],
#  ['@Andst7 !', '!'],
#  ['it’s a sticky situation'],
#  ['@UberFacts They had a good run!',
#   'Humanity has a long way to go to equal their time on Earth.'],
#  ['This will be Mars one day https://t.co/nf4hML8dKx'],
#  ['but have u seen my sex tape https://t.co/aCBqIRz4sH'],
#  ['About to attempt long duration engine firing to test autogenous pressurization'],
#  ['Starship B7 static fire https://t.co/taBpsd9LSV'],
#  ['@sourpatchlyds True.', 'I already get audited every year by default.'],
#  ['@WholeMarsBlog I think the approved language these days is “height-challenged sellers”'],
#  ['Fate 🖤 Irony https://t.co/RHZ9BEws7k'],
#  ['deep thot https://t.co/0EcPd30QAs'],
#  ['https://t.co/UfZdHZvtAA'],
#  ['@_Tesla247_ Thanks, but I already have one'],
#  ['@cb_doge cgi irl'],
#  ['@teslaownersSV @PPathole @guardian Payola'],
#  ['@MuskUniversity Yup'],
#  ['@PPathole @guardian Because Tesla doesn’t advertise and other car companies do'],
#  ['@EvaFoxU @WIsitlike @WholeMarsBlog @Kristennetten @99brownKaryl @DriveTeslaca From Real Scam O’Dowd'],
#  ['@guardian “The Guardian” swallows scam video hook, line &amp; sinker!',
#   'https://t.co/D64OpwLvfg'],
#  ['8 years ago https://t.co/HPK5R5UMS6'],
#  ['@Jason Coming soon.',
#   'Part 3 is about scaling sustainable energy at a civilizational level to enable a bright future for Earth.'],
#  ['Tesla 500 mile range Semi Truck starts shipping this year, Cybertruck next year'],
#  ['Wrote this 6 years ago https://t.co/r9GdXpCtZU'],
#  ['@PPathole True'],
#  ['https://t.co/67gqPGe7Ph'],
#  ['Quite the day https://t.co/UYQZwCvgk7'],
#  ['@teslaownersSV @cybrtrck https://t.co/bOUOejO16Y'],
#  ['@cybrtrck Yes'],
#  ['@SawyerMerritt Yes.',
#   'In the (hopefully unlikely) event that Twitter forces this deal to close *and* some equity partners don’t come through, it is important to avoid an emergency sale of Tesla stock.'],
#  ['@WholeMarsBlog Tesla Fremont team is kicking a**!'],
#  ['@SciGuySpace @BryceSpaceTech SpaceX Falcon team is 🔥🔥🔥'],
#  ['@EvasTeslaSPlaid Happens to almost everyone'],
#  ['@cb_doge @garyblack00 @MartinViecha 🤣'],
#  ['@garyblack00 @MartinViecha Growing at 50%/year requires an insane amount of work, but is achievable with outstanding execution'],
#  ['@SaysSimonson Maybe investment in automation?'],
#  ['@SaysSimonson Seems high'],
#  ['This release will be big'],
#  ['@ajtourville @Twitter 🤣'],
#  ['https://t.co/1duQL9NU2E'],
#  ['Twitter has spoken …'],
#  ['FSD Beta 10.69 drops on 8/20'],
#  ['@truth_tesla @brettlindquist @garyblack00 Yeah, not cool'],
#  ['@cb_doge @paraga 🤣'],
#  ['Saxon James Musk https://t.co/d7FKw4iQIU'],
#  ['@cb_doge 💯'],
#  ['Less than 5% of Twitter daily users are fake/spam'],
#  ['@Andst7 I hereby challenge @paraga to a public debate about the Twitter bot percentage.',
#   'Let him prove to the public that Twitter has &lt;5% fake or spam daily users!'],
#  ['@EvaFoxU @PPathole @Andst7 So it seems'],
#  ['@PPathole @Andst7 Good question, why aren’t they?'],
#  ['@cb_doge Somehow I have 54 followers'],
#  ['@Andst7 Good summary of the problem.',
#   'If Twitter simply provides their method of sampling 100 accounts and how they’re confirmed to be real, the deal should proceed on original terms.',
#   'However, if it turns out that their SEC filings are materially false, then it should not.'],
#  ['I love the smell of hydraulic fluid in the morning'],
#  ['At launch pad https://t.co/qFVpVkLa9v'],
#  ['Moving rocket to launch pad https://t.co/nPVq1tyLoy'],
#  ['Hustling to get Starship Booster 7 back to pad to test outer ring of 20 engines'],
#  ['Full Send Podcast https://t.co/01FmxYRrVr'],
#  ['Thank goodness for Senator Manchin'],
#  ['@garyblack00 I had more kids in Q2 than they made cars!'],
#  ['@dogeofficialceo @chicago_glenn @mySA @happydad Stone of Destiny'],
#  ['@john @fullsendpodcast Was a fun hang'],
#  ['@dogeofficialceo @chicago_glenn @mySA @happydad Whiskey'],
#  ['@RehydratedTater 🤣'],
#  ['@chicago_glenn @mySA @happydad Yeah, pretty good.', 'I like the name.'],
#  ['@mtaibbi 💯'],
#  ['@mySA Not true.',
#   'Tesla is 5 mins from Austin International airport.',
#   'Would be silly to build another private airport, however the existing commercial airport needs another runway, as Austin is growing fast!'],
#  ['@Teslarati @YahooFinance @PeteButtigieg @Tesla @JohnnaCrider1 Cool'],
#  ['The ratio of digital to biological compute is growing fast.',
#   'Worth tracking.'],
#  ['@SirineAti A *successful* orbital flight is probably between 1 and 12 months from now'],
#  ['@GalaxyHeroesGHC X'],
#  ['@RationalEtienne 🤣💯'],
#  ['Just came across this pretty good CNBC piece on SpaceX &amp; Starship https://t.co/RELYzC40M9'],
#  ['@PPathole That estimate seems high, but the point is valid'],
#  ['Worth reading.',
#   'This is a close match for my philosophy.',
#   'https://t.co/cWEM6QBobY'],
#  ['Still time to vote!', 'https://t.co/ZbFWv0pkgG'],
#  ['https://t.co/2Ck4z96NFM'],
#  ['X ❤️ Doges'],
#  ['@spideycyp_155 So much water under the bridge since then'],
#  ['https://t.co/RmXlZHKEKc'],
#  ['@teslaownersSV Yeah'],
#  ['@teslaownersSV @BillyM2k @WholeMarsBlog Maybe Twitter can become that'],
#  ['@teslaownersSV @BillyM2k @WholeMarsBlog It sure is hard to find a news source that’s accurate, relevant &amp; not totally depressing!',
#   'Old-school version of The Economist &amp; Jon Stewart Daily Show / Colbert Report were great.'],
#  ['@cb_doge 🤣'],
#  ['@cb_doge Floki pic tomorrow'],
#  ['@BillyM2k @WholeMarsBlog The media has strong negative bias &amp; are driven by clicks (they can’t help it).',
#   'Unfortunately, I generate lots of clicks.',
#   'But these things move in cycles.',
#   'When it starts boring readers to knock me down, they will build me up.',
#   'This cycle has happened so many times …'],
#  ['@BillyM2k @WholeMarsBlog 🤣🤣'],
#  ['@dcherring 👍'],
#  ['@dogeofficialceo https://t.co/QMyM1H0Z5y'],
#  ['If our reality is actually an alien soap opera, our ratings would be 🚀💥💫'],
#  ['@WholeMarsBlog 🤣'],
#  ['Maybe free some people in jail for weed here too?',
#   'https://t.co/AYo0ZC79lZ'],
#  ['@ajtourville @SpaceX Good thread'],
#  ['@Garin 🎯'],
#  ['@cb_doge @lexfridman @ExplainThisBob Sigh'],
#  ['Off to the Races set to Harley Quinn https://t.co/79XaBOxAKk'],
#  ['@lexfridman 🤣👍'],
#  ['@StockMKTNewz We live in interesting times'],
#  ['@sadcrib 🤣'],
#  ['Tesla + Twitter -&gt; Twizzler'],
#  ['Interaction with almost all twitter accounts seem to be much lower in recent weeks &amp; days.',
#   'Accurate?'],
#  ['Saxon https://t.co/UTh4uqIEYP'],
#  ['@spideycyp_155 Based'],
#  ['Friend made this for me 2 years ago https://t.co/XzlmpmPNT7'],
#  ['Try voice command “open butthole” on your Tesla'],
#  ['https://t.co/Uo30yDO3tJ'],
#  ['@cb_doge 🤣'],
#  ['@HistoryInPics Great style'],
#  ['@TeslaPodcast @SenateDems @Sen_JoeManchin @SenatorSinema @SenateGOP Good point.',
#   'Time to move on from hybrid cars.',
#   'That was a phase.'],
#  ['Heatwave in Shortville 🥵'],
#  ['@ICannot_Enough @DirtyTesLa 10.13 is probably a week or so away, but yes.',
#   'People outside of California will notice improvements the most.'],
#  ['@DirtyTesLa We’re working super hard on 10.13, but it isn’t ready yet'],
#  ['@micsolana Wikipedia is losing its objectivity @jimmy_wales'],
#  ['I can’t say for sure that Starship will reach escape velocity, but my hubris certainly has'],
#  ['@chicago_glenn We should thank farmers more'],
#  ['@WholeMarsBlog Products that bring joy are rare'],
#  ['@teslaownersSV Too early to say for sure'],
#  ['More Tesla commodity prices are trending down than up fwiw'],
#  ['Inflation might be trending down'],
#  ['@FutureJurvetson @Tesla @gjurvetson Thanks for your support over the years'],
#  ['Much harder to make friends than enemies.',
#   'My skill at the latter is improving.'],
#  ['@NASASpaceflight Sub lightspeed is all that’s needed to be interstellar.',
#   'Intergalactic is tough.'],
#  ['The media is a click-seeking machine dressed up as a truth-seeking machine'],
#  ['This is compatible with existing religions – surely God would want us to see Creation?'],
#  ['A new philosophy of the future is needed.',
#   'I believe it should be curiosity about the Universe – expand humanity to become a multiplanet, then interstellar, species to see what’s out there.'],
#  ['@sama A new philosophy of the future is needed'],
#  ['@heydave7 @WSJ @michaelsiconolf Moreover, I talked to Sergey yesterday and he says neither he nor anyone he knows has talked to WSJ'],
#  ['@heydave7 @WSJ As a “public person”, standard to win a defamation lawsuit against a news org is almost impossible.',
#   'They could say I’m Satan and the “source” is their psychic!',
#   'Nicole is not a public person, so could win.',
#   'I hope she sues them.',
#   '@michaelsiconolf has done so many fake hit pieces.'],
#  ['@teslaownersSV @PPathole Seriously'],
#  ['@PPathole Business Insider (Trading) is not a real publication'],
#  ['@GailAlfarATX @chicago_glenn @michaelsiconolf @KirstenGrind @EmilyGlazer Yeah, but that was 8000 years ago'],
#  ['@PPathole @michaelsiconolf @KirstenGrind @EmilyGlazer That would be nice'],
#  ['@TrungTPhan @chicago_glenn @michaelsiconolf @KirstenGrind @EmilyGlazer 🤣🤣 Exactly'],
#  ['@chicago_glenn @michaelsiconolf @KirstenGrind @EmilyGlazer Weirdly, some publications still print millions of paper copies every day!'],
#  ['@chicago_glenn @michaelsiconolf @KirstenGrind @EmilyGlazer 99% of journalism is reading someone else’s story on the Internet, changing it up a little &amp; pressing send'],
#  ['@michaelsiconolf @KirstenGrind @EmilyGlazer Sickonolfi has zero journalistic integrity\r\nhttps://t.co/gOjDQEOmwJ'],
#  ['@jeffskoll Thanks Jeff 💕'],
#  ['@SPACEdotcom Bon voyage'],
#  ['@michaelsiconolf @KirstenGrind @EmilyGlazer Sickonolfi’s pack of attack chihuahuas are burning up phone lines today for revenge after his bogus article 🤣🤣'],
#  ['@dogeofficialceo @MarceloPLima 🤣'],
#  ['@MarceloPLima Exactly'],
#  ['@SawyerMerritt @heydave7 @WholeMarsBlog @WSJ Good point, will do'],
#  ['@PPathole @michaelsiconolf @KirstenGrind @EmilyGlazer Mostly just that the media is a click maximizing machine and a story involving me gets a lot of clicks'],
#  ['All Teslas come with a free karaoke app https://t.co/mZa3WmhyPL'],
#  ['Das Baby would be a hit!'],
#  ['@jhall The media is a click-seeking machine dressed up as a truth-seeking machine'],
#  ['@michaelsiconolf @KirstenGrind @EmilyGlazer ______, ______ your 👖 are on 🔥 https://t.co/Ioq3EGOQj3'],
#  ...]

# %%
## flatten the list
corpus=[sent for sublist in corpus for sent in sublist]

# %%
for i in range(len(corpus)):
    corpus[i] = corpus[i].lower()
    corpus[i] = re.sub(r'(@[a-z0-9+._-]+)'," ", corpus[i]) # Replace @users by ' '
    corpus[i] = re.sub(r'\W+',' ',corpus[i]) # Replace everything non-alpahnumeric by ' '
    corpus[i] = re.sub(r'\s+',' ',corpus[i]) # Replace one or more whitespaces by  ' '
    corpus[i] = re.sub(r'\d+',' ',corpus[i]) # Replace one or more digits by  ' '
    corpus[i] = re.sub(r'([a-z0-9+._-]+@[a-z0-9+._-]+\.[a-z0-9+_-]+)'," ", corpus[i]) # Replace e-mails by ' '
    
    # Replace urls by ''
    corpus[i] = re.sub(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?', ' ' , corpus[i]) 
    # Replace html tags by ''
    corpus[i] = BeautifulSoup(corpus[i], 'html.parser').get_text().strip()

# %%
corpus
# Out:
# ['the bird is freed',
#  'falcon rockets to orbit as seen from la https t co r l sblc p',
#  '',
#  'thanks',
#  'absolutely',
#  'dear twitter advertisers https t co gmwhminpas',
#  '',
#  'meeting a lot of cool people at twitter today',
#  'entering twitter hq let that sink in',
#  'https t co d z k wq',
#  '',
#  '',
#  'definitely closer to citizen journalism local news orgs are under appreciated amp should get way more prominence on twitter',
#  'nobody bats',
#  'a beautiful thing about twitter is how it empowers citizen journalism people are able to disseminate news without an establishment bias',
#  'i m a big fan of citizen journalism',
#  'according to unnamed sources close to the matter who wish to remain anonymous',
#  'the new york times has emerged as a new chaotic actor in global politics',
#  'the paper s interventions in some of the world s most combustible conflicts have sometimes been a boon but their messaging has also caused problems',
#  '',
#  'yes',
#  'is a lot',
#  'concerning',
#  'works on any moving land object https t co xu qkjw d',
#  'fasting rocks',
#  'had to do a double take',
#  'this is the first non fake vitalik tweet i ve seen in a while',
#  '',
#  'one man s hedge is another man s shrub',
#  'yup',
#  'true',
#  'too much respect for authority inhibits innovation',
#  '',
#  '',
#  'what lesson took you the longest to unlearn',
#  'διαλεκτική',
#  'twitter should be as broadly inclusive as possible serving as a fair forum for lively even if occasionally rancorous debate between widely divergent beliefs',
#  'absolutely necessary',
#  '',
#  '',
#  'important',
#  'yup',
#  'exactly',
#  '',
#  'yeah doesn t make sense',
#  'good thread',
#  'i only play crazy   s',
#  'that s the plan unless it is damaged in testing',
#  'what really matters is that ship amp booster production line is spooling up',
#  'also each new ship amp booster has incremental design improvements',
#  'yeah i m back to spare bedroom couch surfing at friend s houses in silicon valley which i did for about a decade',
#  'frankly i like it this way as i get to see my friends who i love more often',
#  'i did as a child but found it to be too simple to be useful in real life a mere   by   grid no fog of war no technology tree no random map or spawn position only   players both sides exact same pieces etc',
#  'polytopia addresses these limitations',
#  'and i don t even own a house let alone a mansion you douche',
#  'while it s true that kasparov is almost as good at playing chess as my iphone he is otherwise an idiot',
#  'yes',
#  '',
#  'how exciting to be alive at the same time as the largest animal ever',
#  'wild that blue whales are bigger than the biggest dinosaur',
#  'you re most welcome',
#  'before dod even came back with an answer i told that spacex would not turn off starlink even if dod refused to provide funding',
#  'absolutely',
#  'interesting',
#  'great game',
#  'maybe it was a social media algorithm not even people',
#  'think about who might have decided the current thing before accepting it',
#  'who decides the current thing real question',
#  'i don t know',
#  'exactly',
#  'wapo are such hypocrites',
#  'neuralink show amp tell now on nov',
#  'had to be done',
#  'we ve come a long way',
#  'i know nothing is forever',
#  '',
#  'good point',
#  'this needs to change',
#  'manufacturing is awesome',
#  'it will happen',
#  'hear',
#  'hear',
#  'why are you perpetuating propaganda concocted by the oil amp gas industry to distract you from the   trillion dollars per year of subsidies those companies receive',
#  'https t co xzxdjape a',
#  '',
#  'switzerland amp belgium have great chocolate but i do also love eccentric british amp irish artisanal sweet shops',
#  '',
#  'good thread',
#  'next week',
#  'it s actually a major release so a lot more internal testing is needed before going to public beta',
#  '',
#  'cool',
#  'although there could be more r amp d in candy tbh',
#  'feels like there hasn t been much improvement in decades',
#  '',
#  'headline is misleading',
#  'starlink can obviously offer far more robust positioning than gps as it will have  x more satellites over time',
#  'not all will have line of sight to users but still gt  x gps amp far stronger signal',
#  'just not today s problem',
#  'one of my favorite conspiracy theories is that the world is actually   men',
#  'un ass ailable logic',
#  'yes',
#  'https t co j zhlazopa',
#  'you re right',
#  'eventually we all run out of time',
#  'https t co gyxk uzliw',
#  'only giga berlin can make these colors as paint shop was specially built to apply many fine layers of paint giving it complexity not otherwise possible https t co htis lfrzv',
#  'varies a lot',
#  'tesla amp spacex are in good positions but many other companies are not',
#  'recessions do have a silver lining in that companies that shouldn t exist stop existing',
#  'those who want putin removed are laboring under the misapprehension that whoever replaces him will be more amenable to peace or western philosophy but i think this is unlikely the kremlin is not the nice guy olympics',
#  'russia overrunning ukraine would destabilize the entire region perhaps the world',
#  'if russia faced calamitous defeat in conventional warfare for something as strategically critical as crimea the probability of using nuclear weapons is high',
#  'i do',
#  'yes',
#  'still very unlikely but this is the closest we ve been since cuba in',
#  'just guessing but probably until spring of',
#  'it sure would be nice to have one year without a horrible global event',
#  'brutal for both sides will be a common phrase in the months to come',
#  'https t co wqgm inntp',
#  'no way',
#  'maybe',
#  'certainly warrants closer scrutiny',
#  '',
#  'btw how s it going in bakhmut',
#  'pretty good troll tbh',
#  'humour',
#  'i couldn t agree more',
#  'british humor is the best',
#  'compromise is overwhelmingly the most likely outcome just a question of how much death amp destruction happens before then',
#  'that should be the nature of the debate',
#  'most probable outcome by far is a horrible war of attrition that destroys ukraine amp severely damages russia with massive body count on both sides',
#  'and in the end the same outcome',
#  'so why',
#  'exactly',
#  'congrats to team on  th launch this year',
#  'falcon   now holds record for most launches of a single vehicle type in a year',
#  '',
#  '',
#  'same',
#  'exactly',
#  'spacex has more active satellites in orbit than rest of earth combined tracking to double rest of earth soon',
#  'the media reports with great fanfare my predictions that are late but rarely those that come early',
#  '',
#  'accelerating sustainable energy is our primary mission',
#  'will require truly exceptional execution but it is possible',
#  'i will not let you down no matter what it takes',
#  'awesome',
#  'we even did a starlink video call on one airplane aloft to starlink on another far away airplane aloft and it worked perfectly with no lag',
#  'vox populi vox dei',
#  'several major architectural upgrades in       so it s much more than a point release but we re sticking with     just cause haha',
#  'sounds fair',
#  'definitely giving me kid naming ideas',
#  'and sold out',
#  'internet in airplanes will feel same as if you were accessing internet at home',
#  'https t co mfl ixynjh',
#  'bottles of exquisite burnt hair perfume already sold',
#  'only     left of this unique limited edition collector s item',
#  'https t co gh zg b qx',
#  'we re working on it',
#  'hope to release something next week',
#  'no money from dod but several other countries orgs amp individuals are paying for  k  k terminals thanks',
#  'spacex is losing  m month due to unpaid service amp costs related to enhanced security measures for cyberwar defense but we ll keep doing it sigh',
#  'smart',
#  'maybe',
#  'does dumb stuff',
#  'definitely',
#  'true',
#  'https t co jxa stwf d',
#  '',
#  'exactly',
#  '',
#  'should i make weapons',
#  'ideally not',
#  'an easy prediction',
#  'drone war i https t co ervme cbbn',
#  'https t co ccaypontfg',
#  'actually smart summon is almost done',
#  'yes',
#  'i have a plan',
#  'thanks optimus',
#  'to be precise     terminals were sent to ukraine but at present only     are paying for service',
#  'spacex has already withdrawn its request for funding',
#  'wrong analogy',
#  'america also had a humiliating withdrawal from afghanistan',
#  'no one in america sees that country as part of america',
#  'crimea is seen as a crucial part of russia by russia much as hawaii is seen as a crucial part of america',
#  '',
#  'probably not',
#  'practice makes perfect',
#  'russia has been punched in the nose and forced to retreat many times by ukraine',
#  'but what you don t want to do is give russia a choice of total humiliating defeat or nukes then the probability of them using nukes is high',
#  'obviously many disagree with this logic but what do they think is their probability of being wrong about ww',
#  'if they say   they are utterly dangerous fools',
#  'but hey look on the bright side',
#  'at least russia doesn t get crimea in that scenario so you can be comforted by that thought while watching the mushroom clouds rise',
#  'if russia faces destruction of their army and utter defeat by nato they will use nukes then nato will respond with nukes and civilization is over',
#  'whether one likes it or not crimea is absolutely seen as a core part of russia by russia',
#  'crimea is also of critical national security importance to russia as it is their southern navy base',
#  'from their standpoint losing crimea is like usa losing hawaii amp pearl harbor',
#  'exactly',
#  'if russia is faced with the choice of losing crimea or using battlefield nukes they will choose the latter',
#  'we ve already sanctioned cutoff russia in every possible way so what more do they have left to lose',
#  'if we nuke russia back they will nuke us and then we have ww',
#  'exceptionally well said https t co ut fxg mef',
#  'standard non performance   amp y suspension in production now has improved comfort without affecting handling',
#  'yeah rv version is lower priority than standard version',
#  'you should still see high speeds during off hours',
#  'is that happening',
#  'as we add more satellites amp upgrade satellite technology speeds in high user density locations should see significant increases',
#  'ok we will add a donate option to starlink',
#  'that s oddly low',
#  'normally much higher',
#  'are there others that want to donate starlinks to places in need',
#  'https t co m asmenmrd',
#  'ok',
#  'that s happened to me many times',
#  'a much quieter leaf blower is possible',
#  'this is harder than it sounds but ok',
#  'deus x machina',
#  'we are proceeding very carefully',
#  'if there is a rud on the pad starship progress will be set back by   months',
#  'game over when not if earth gets hit by an object of that size',
#  'ramen gt gt lambos',
#  'used a lot in rocketry',
#  'so true https t co pwmxuvu fc',
#  'every millipede has its millennia',
#  'we should bring back their outfits',
#  'good thread',
#  'fancy a game of meme tennis',
#  'https t co d tqilg nb',
#  'buy burnt hair from a company that digs holes',
#  'i read this as goth clowns lonely',
#  'did you hear about the dyslexic kbg agent it s pot secret',
#  '',
#  'venn diagram intersection of those two audiences is pretty small i guess',
#  'not as popular as i d hoped sigh',
#  'pitching my idea once again for a crossover of das boot amp boss baby',
#  'das baby hijinks on the high seas',
#  'https t co fiermsthp',
#  'just a scratch we can buff it out',
#  'mostly accurate',
#  'the comments in this thread are a conspiracy theorist s wet dream',
#  'yup',
#  'years ago',
#  'definitely one of the strangest meetings i ve ever experienced',
#  'was there too',
#  'i m trying my hardest to de escalate this situation and obviously failing',
#  'damned if you do damned if you don t so guess i m just damned',
#  'starship amp next gen starlink satellites are key but much risk lies ahead before those are working at scale',
#  'the hilarious thing is you re not wrong',
#  'so it goes',
#  'fate loves irony',
#  'even so we should still do good deeds',
#  'the hell with it even though starlink is still losing money amp other companies are getting billions of taxpayer we ll just keep funding ukraine govt for free',
#  'that dude is not just a condition of anonymity spineless coward he s also an ignorant fool',
#  'starlink was directly requested by the ukraine government as it was the only thing that worked',
#  'it has required a lot of our resources',
#  'going into super lockdown mode slows down new development progress as we have to resist attacks from a sophisticated adversary actively at war',
#  'dod provided about   of the falcon   development cost',
#  'appreciated certainly but should be seen in context',
#  'of course',
#  'and their signal jamming systems are also getting better',
#  'the amount spacex is requesting for a major battlefield advantage is less than the cost of one new gps satellite',
#  'ironically gps doesn t work on battlefields as the signal is easy to jam but starlink does',
#  'would be great if someday humanity stopped pointing nukes at itself that would destroy almost all life on earth',
#  'in any given year there is a chance above zero that they will be launched',
#  'we are now at the highest risk in   years',
#  'https t co hsqneyhnx',
#  'curses foiled again',
#  '',
#  'accurate',
#  'russia has the ability to destroy usa amp europe utterly with nuclear missiles in less than   minutes amp vice versa',
#  'a surprising number of people don t know this',
#  'of course it would be mad to use them but it is also mad to be in this situation at all',
#  'this has potential',
#  'internet fiber phone lines cell towers amp other space based comms in war areas have been destroyed',
#  'starlink is all that s left',
#  'for now',
#  'https t co cdjbowgziz',
#  'thank you for clarifying this',
#  'starlink is the primary communications system of the ukrainian army on the war front',
#  'if anyone else wants this job please be my guest',
#  'big difference between peace comms vs warfront comms',
#  'starlink is only comms system still working at warfront others all dead',
#  'russia is actively trying to kill starlink',
#  'to safeguard spacex has diverted massive resources towards defense',
#  'even so starlink may still die',
#  'concerning',
#  'https t co xtwjf lv o',
#  'are there citizens of nations who are helping ukraine on this list',
#  'but surely no reasonable person would launch nuclear war',
#  'the problem with that logic is if we were dealing with reasonable people we wouldn t have war in the first place',
#  'is this list real',
#  'what s the url',
#  'people should never fear turbulence',
#  'commercial airliner wings can handle insane amounts of bending',
#  'the right question to ask',
#  'we re just following his recommendation',
#  'falcon can probably get starlink past breakeven but starship is needed to fund mars',
#  'yes',
#  'in addition to terminals we have to create launch maintain amp replenish satellites amp ground stations amp pay telcos for access to internet via gateways',
#  'we ve also had to defend against cyberattacks amp jamming which are getting harder',
#  'burn is approaching  m month',
#  'also starlink is still losing money',
#  'it is insanely difficult for a leo communications constellation to avoid bankruptcy that was the fate of every company that tried this before',
#  'when asked what the goal of starlink was at a space conference i said not go bankrupt',
#  'maybe the got their',
#  'very few in iran so far',
#  'strange that nothing was leaked about our competitors in space launch amp communications lockheed amp boeing who get over  b wouldn t be surprised to find this particular individual working there when he retires from dod',
#  'corruption at its finest',
#  'spacex is not asking to recoup past expenses but also cannot fund the existing system indefinitely and send several thousand more terminals that have data usage up to  x greater than typical households',
#  'this is unreasonable',
#  'vital to the future of consciousness',
#  '',
#  'srsly',
#  'next week',
#  'envy has driven him to madness',
#  'starlink requires nothing except   watt power source',
#  'with a small solar system plus battery or a generator you will have connectivity anywhere',
#  'true',
#  'there are some active terminals',
#  'of course this happens almost every day',
#  'they successfully destroyed viasat in ukraine several months ago',
#  'https t co xrramqfszy',
#  'starlink has faced relentless jamming attacks amp spacex relentless cyberwar',
#  'so far their success has been limited',
#  'noted',
#  'starlink data usage growth in ukraine https t co c iwnwkwlr',
#  'https t co  ewwyqvwkr',
#  '',
#  '',
#  'cool',
#  'maybe with',
#  'this is real',
#  'https t co wlvh zbio',
#  'my opinion is burnt hair is just elon saying chill out have a laugh and share a laugh',
#  'oh the irony',
#  'we might need a different name as this is basically just starlink with roaming capability so you can take your terminal anywhere',
#  'https t co gnh yppvos',
#  'the counter intuitive thing is that it s actually gonna be a sick product',
#  'please buy my perfume so i can buy twitter',
#  'and right on cue https t co ryskrhejfi',
#  'you re most welcome',
#  'glad to support ukraine',
#  'doesn t get more lit than this',
#  'be the change you want in the world',
#  'can t wait for media stories tomorrow about  m of burnt hair sold',
#  'bottles of burnt hair sold',
#  '',
#  'over   bottles of burnt hair sold',
#  'an omnigender product',
#  'https t co wdthxqgupx',
#  'with a name like mine getting into the fragrance business was inevitable why did i even fight it for so long',
#  '',
#  'and you can pay with doge',
#  'the finest fragrance on earth',
#  'https t co ohjwxnx zc https t co  j lmreobs',
#  'nobody should trust bremmer',
#  'maybe one day we can finally achieve https t co jkbu wjida',
#  'the next question one is typically asked is have you tried ayahuasca https t co zo lw nlxw',
#  'https t co q b x rch',
#  'not subtle',
#  'sam there is a such a thing as meditating too much',
#  'yes back to regularly scheduled programming',
#  'pointless as there is currently no overlap between russian and ukrainian demands it s not even close',
#  'no it is not',
#  'i have spoken to putin only once and that was about   months ago',
#  'the subject matter was space',
#  'talked to ye today amp expressed my concerns about his recent tweet which i think he took to heart',
#  'it was built amp paid for at my request',
#  'hunter amp team did great work',
#  '',
#  'it will',
#  'strange',
#  'i have no desire to become involved in wars but it is safe to say that all bets are off if the nukes start flying',
#  'strong candidate to win most counter intuitive product of the year',
#  'important to bear in mind when reading anything',
#  'indeed that kinetic energy scales with the square of velocity is not well appreciated',
#  'a sealed escape pod with a heat shield would probably work',
#  'so many blind spots',
#  '',
#  'there are  k terminals in ukraine but each terminal can be used to provide an internet uplink to a cell phone tower so potentially several thousand people can be served by a single terminal',
#  'coming soon from the https t co cnibfrrxyt',
#  'yup it will float',
#  'too busy trying to survive at the time',
#  'they were invited to further their career elsewhere',
#  'there is a giant  ft literal fork in the road outside the autopilot office in palo alto',
#  'mine',
#  'i love the inverse poetry of making metaphors literal',
#  'that is quite an interesting story',
#  'we sent what appeared to be identical emails to all but each was actually coded with either one or two spaces between sentences forming a binary signature that identified the leaker',
#  'because it runs recursively',
#  'nuclear war probability is rising rapidly',
#  'an eye for an eye leaves everyone blind https t co pqztpvr ui',
#  'perhaps we can talk again today',
#  'true starlink provided a decisive battlefield advantage',
#  'i ve been up all night trying to think of any possible way to de escalate this war',
#  'feels so long ago',
#  'a pleasant memory',
#  'https t co vvga qaye',
#  'double header',
#  'agreed',
#  'beautiful',
#  '',
#  'welcome back to twitter my friend',
#  '',
#  'dojo uses bf  so actual performance difference vs   bit is much less than it would seem since you truncate so many useless zeroes amp round from there',
#  '',
#  'two dragons on',
#  'can t wait to see this beast in action',
#  'even better build coming next week',
#  'quite a few',
#  'trying to do the right thing which is not always clear',
#  'i am in regular contact with fedorov',
#  'bad reporting by ft',
#  'this article falsely claims that starlink terminals amp service were paid for when only a small percentage have been',
#  'this operation has cost spacex  m amp will exceed  m by end of year',
#  'as for what s happening on the battlefield that s classified',
#  'starlink will provide the vast majority of bandwidth from space',
#  'you d need an electric propeller mounted on the tow hitch to go faster than a few knots',
#  'there might a creative wheel hub design that can generate meaningful thrust',
#  'norway rocks',
#  '',
#  'in case you missed tesla ai day   https t co sbu pexpy',
#  'satellite constellation capability comes down to tonnage to orbit per year times capability per ton',
#  'spacex dragon docking with extended video https t co afbdkhddgi',
#  'very intense   days indeed',
#  '',
#  '',
#  'personally i like the latter but to each their own',
#  'i think being able to dial the content you see from warm amp fuzzy all the way to bring it on mf is the way to go',
#  'software engineering server operations amp design will rule the roost',
#  'there will be very rapid product evolution',
#  'mile range amp super fun to drive',
#  'excited to announce start of production of tesla semi truck with deliveries to on dec  st',
#  'https t co gq l igrw',
#  'tiny helium leak just barely triggered abort but we take no risks with customer satellites',
#  'standing down to investigate',
#  '',
#  'agreed',
#  '',
#  'plot twist',
#  'elon liking his own tweets liking his own tweets',
#  'dragon is now docked to',
#  'video https t co  gujv v',
#  'starlink view of  nd stage deorbit burn https t co kblv bak',
#  '',
#  '手整体插在口袋里的人过分自信',
#  'i will try my best',
#  'i m a big fan of ukraine but not of ww',
#  '',
#  'https t co fxgymhtax',
#  'cute',
#  'you can get surprisingly close to a wild baby rhino amp mom if you stay downwind',
#  'there are no angels in war',
#  'accurate assessment',
#  'correct',
#  'so they re saying that not buying twitter is bad but also buying twitter is bad',
#  '',
#  'we talked via videoconference last year',
#  '',
#  'war is the ultimate supreme court',
#  'kherson and zaporizhzhia almost certainly do not want to join russia annexation of those regions was done to ensure a land bridge and water supply to crimea',
#  'obviously not everyone who voted for the pro russia party wanted to join russia but it would also be inaccurate to say that none did',
#  'below is the electoral map of',
#  'blue is the pro russia party',
#  'https t co ykz hipyav',
#  'assuming you believe that the will of the people matters we should in any given conflict region support the will of those who live there',
#  'most of ukraine unequivocally wants to be part of ukraine but some eastern portions have russian majorities and prefer russia',
#  'first of all tesla hasn t had that consumer tax credit for years amp we didn t ask for this one gm amp ford did',
#  '',
#  'another batch of starlinks in orbit   hours after the astronaut launch https t co mqshey rp',
#  'that wouldn t be hard to do',
#  '',
#  'twitter is an accelerant to fulfilling the original https t co bouoek cvy vision',
#  'i do not think it is simple at all but i have yet to hear any realistic path to peace',
#  'ukraine has achieved many brilliant tactical victories but should be wary of overconfidence leading to strategic defeat',
#  'when russia fully mobilizes millions on both sides will die',
#  'will actually be a major upgrade',
#  'we re keeping   just because haha',
#  'twitter probably accelerates x by   to   years but i could be wrong',
#  'buying twitter is an accelerant to creating x the everything app',
#  '',
#  'should be noted that starlink is still far from cash flow positive',
#  'all leo communications constellations to date have gone bankrupt so any support is super helpful',
#  'a small number of terminals were paid for by the govt vast majority were not',
#  'this is just another bs wapo hit piece',
#  'i still very much support ukraine but am convinced that massive escalation of the war will cause great harm to ukraine and possibly the world',
#  'we gave starlinks to ukraine amp lost  m in doing so while putting spacex amp myself at serious risk of russian cyberattack',
#  'what have you done besides tweet',
#  'spacex s out of pocket cost to enable amp support starlink in ukraine is  m so far',
#  'our support for russia is',
#  'obviously we are pro ukraine',
#  'trying to retake crimea will cause massive death probably fail amp risk nuclear war',
#  'this would be terrible for ukraine amp earth',
#  'in other news remote controlled anal beads sold out everywhere',
#  '',
#  'that referendum was questionable which is why i suggested repeating it under un or other trusted entity supervision',
#  'great offer a un supervised vote and if russia refuses then war it is',
#  'maybe a similar approach to kosovo https t co cgppaxaaa',
#  'no i m suggesting voting under un or pick your most trusted entity or country supervision',
#  'russia is doing partial mobilization',
#  'they go to full war mobilization if crimea is at risk',
#  'death on both sides will be devastating',
#  'russia has gt   times population of ukraine so victory for ukraine is unlikely in total war',
#  'if you care about the people of ukraine seek peace',
#  'you are assuming that i wish to be popular',
#  'i don t care',
#  'i do care that millions of people may die needlessly for an essentially identical outcome',
#  'let s try this then the will of the people who live in the donbas amp crimea should decide whether they re part of russia or ukraine',
#  'cheese is amazing',
#  'indeed',
#  'biggest bot attack i ve ever seen',
#  'the bot attack on this poll is strong',
#  'the will of the people should decide whether they are part of russia or ukraine but russia invaded areas that would unequivocally choose to be part of ukraine',
#  'also worth noting that a possible albeit unlikely outcome from this conflict is nuclear war',
#  'this is highly likely to be the outcome in the end just a question of how many die before then',
#  'ukraine russia peace redo elections of annexed regions under un supervision',
#  'russia leaves if that is will of the people',
#  'crimea formally part of russia as it has been since   until khrushchev s mistake',
#  'water supply to crimea assured',
#  'ukraine remains neutral',
#  'yes',
#  'that is my assessment too',
#  'well said',
#  'also we try to operate the team as non hierarchically as possible amp allow movement between project areas so you don t get pigeon holed',
#  'i m trying my hardest',
#  'perhaps more people might consider loving humanity',
#  'our collective light of consciousness is a tiny candle in a vast darkness',
#  'please do not let it go out',
#  'optimus will be sickkk',
#  '',
#  'would be cool to make a game using tesla sim that s literally your city amp neighborhood down to skid marks on road amp then inject fantasy sci fi elements',
#  'occasionally',
#  'and people wonder why i sometimes think we re in a simulation',
#  'https t co cghstdb gv',
#  'trillion operations per second',
#  'the embarrassing hose down photos were highly motivating tbh',
#  'https t co ino f q o',
#  'tunneled under the road from one property to another',
#  'this is to test the new machine',
#  'unfortunately snail is still faster but tbc might beat snail by end of',
#  'prufrock ii emerging from the ground https t co csamcrmaza',
#  'but between now and then we do actually need to work hard',
#  'i don t care about boosting the stock but the economic implications are obvious',
#  'do not let ancient grudge break to new mutiny',
#  'so many talented russians in america',
#  'customer experience suffers when there is an end of quarter rush',
#  'steady as she goes is the right move',
#  'war always gives ample reason for vengeance for all sides',
#  'only by overcoming this instinct can there be peace',
#  'smoothing out crazy end of quarter delivery wave to reduce expedite costs amp relieve stress on tesla team',
#  'aiming for steadier deliveries intra quarter',
#  'it s funny reading simultaneous criticism that it s already been done but also it s impossible',
#  '',
#  '',
#  'master plan mé nage à trois is all about tonnage',
#  'thanks we have a great team',
#  'beautiful',
#  'exactly',
#  'https t co hdul etoao',
#  'recording of tesla ai day   https t co  lr x pxa',
#  'join https t co fgkc zt k',
#  'a little',
#  'that and giving it a brain',
#  'and wegovy',
#  'yes',
#  'fasting',
#  'uh oh mine must be tiny',
#  '',
#  'https t co enhvvztxhm',
#  'https t co nlutmraqfa',
#  '',
#  '',
#  'https t co pha kkhfot',
#  'naturally there will be a catgirl version of our optimus robot',
#  'the point of ai day is to show the immense depth amp breadth of tesla in ai compute hardware amp robotics',
#  '',
#  'yup',
#  'should be according to greatest need not race or anything else',
#  '',
#  '',
#  'webcast link https t co trtjkph mk',
#  'tesla ai day   starts at precisely    pm california time',
#  'tesla team is awesome such an honor to work with them',
#  'now',
#  'that is not cgi',
#  'the hands of optimus',
#  'i still love the',
#  'epic plane',
#  'haha',
#  'such an incredible engine',
#  '',
#  'yay',
#  'true',
#  'needs be able to get from starbase to south padre island which requires crossing the channel',
#  'off label use',
#  'cybertruck will be waterproof enough to serve briefly as a boat so it can cross rivers lakes amp even seas that aren t too choppy',
#  'submarines use electric motors under water',
#  'works on land too',
#  'as well as advanced chip amp supercomputer engineers for next gen training amp inference',
#  'note this event is meant for recruiting ai amp robotics engineers so will be highly technical https t co bcxaev qjd',
#  'pretty much',
#  'ai robotics engineers who understand what problems need to be solved will like what they see',
#  'there will be lots of technical detail amp cool hardware demos',
#  'good analysis',
#  'rated for   kph   mph winds https t co qjbdykptt',
#  'starlink maritime system enables high speed internet connectivity even in heavy seas amp hurricane winds https t co  r p ugot',
#  'last coal shipment arrived in hawaii at same time as tesla megapack batteries that will enable     sustainable energy https t co zlqjhlsaqq',
#  'still very tiny potatoes compared to what s needed to make life multiplanetary',
#  'spacex now delivering about twice as much payload to orbit as rest of world combined',
#  'extremely concerning',
#  'how ironic that s what henrik fisker did to tesla in',
#  'karma is a',
#  'they need to add a lot of batteries to the grid to buffer energy',
#  'https t co mebagbcckj',
#  'i guess this joke is a slow burn',
#  'big improvement in high speed cross traffic velocity nn coming next month',
#  'maybe worth talking at some point',
#  'make hair on fire not just a metaphor',
#  'https t co  hbmzueali',
#  'stand out in a crowd',
#  'get noticed as you walk through the airport',
#  'coming soon from the same people that sold you a flamethrower',
#  'burnt hair scent for men by singed',
#  'i m a little preoccupied rn',
#  'batteries ftw',
#  'good point',
#  'my son saxon was amazed that so many paper newspapers are still produced every day',
#  'he said they probably just search the internet amp print it out',
#  'yup with rare exception that is actually what they do haha',
#  'https t co rckpre eim',
#  'falcon   fairing cam captures  nd stage plume booster entry burn amp earth in twilight https t co ga mpzkvk',
#  'even then lenin would ve gotten nowhere without ludendorff s train',
#  'charming',
#  'https t co qeidmu sog',
#  'https t co  wpp f ja',
#  'starlink now over  m user terminals manufactured',
#  'siegel is obviously correct',
#  'activating starlink',
#  'education is the path out of poverty and internet access enables education',
#  'exactly',
#  'starlink connecting schools in the amazon https t co xy d sk n',
#  'it is',
#  'why is this a popmech story',
#  'https t co vfvhab l t https t co pupzznzcpe',
#  'yup sigh',
#  'fully reusable orbital rockets are the fundamental breakthrough needed for humanity to become a multiplanet species',
#  'the terminology is outdated amp inaccurate',
#  'this is a tiny over the air software update',
#  'to the best of our knowledge there have been no injuries',
#  'your car needs a camera upgrade which is free of charge',
#  'there are a few thousand cars in a similar situation',
#  'replacement cameras will be available early next month',
#  'while pheromone',
#  '',
#  'shaded patio',
#  'actually i live in a little house on weems st that cost  k but i ve done a lot with the place',
#  'aka cogency',
#  'looks awesome',
#  'maybe little electric tesla boats with a retro futuristic victorian design',
#  'long term goal is a boardwalk with amenities that goes all the way to downtown austin so you can walk bike or kayak',
#  'area from south giga to river really will be next level great amp open to public',
#  'ecological paradise plans from south portion of giga texas to river look great however we must first get the factory financially on its feet',
#  'i was instrumental in creating openai which made dall e',
#  'although his methods of instruction very strongly favored stick over carrot i did learn a tremendous amount of engineering from him amp appreciation of art he is an extremely talented artist',
#  'boys high was a good school but it was government not private',
#  'brooklyn would be considered a middle income not exclusive neighborhood in america',
#  'for sure',
#  'errol ran out of money in the   s',
#  'my brother amp i financially supported him amp his extended family in south africa since then on condition that he not do bad things',
#  'unfortunately he did do bad things',
#  'this is true',
#  'with some improvements it will achieve   mps',
#  'incorrect',
#  'there was tuition for students from outside the school district which was a small part of the student body incl black students but not for students in district which i was',
#  'also i was there for     years previously attending govt schools for   of   years',
#  'i went to government schools not private except for part of one year in third grade',
#  'probably q  next year with vehicles initially transferred by boat from port of brownsville to the cape',
#  '',
#  'https t co  b msiktf',
#  'that s the plan',
#  'we re taking a little risk there as engine isolation was done as retrofit so not as good as on booster',
#  'late next month maybe but november seems highly likely',
#  'we will have two boosters amp ships ready for orbital flight by then with full stack production at roughly one every two months',
#  'our focus is on reliability upgrades for flight on booster   and completing booster   which has many design changes especially for full engine rud isolation',
#  'exactly',
#  'seems that way',
#  '',
#  'what s going on',
#  'such miracles are impossible',
#  'that s a real picture',
#  'absolutely',
#  'unsurprisingly reich is also a hypocrite',
#  'reich is suicidally boring',
#  '',
#  'you both an idiot and a liar',
#  '',
#  'curiouser and curiouser',
#  'same',
#  'yes',
#  'happy birthday bro love you',
#  'yes all us amp canada cars with safety scores above   should receive an invitation to download fsd beta by tomorrow',
#  'note autopilot ai team is also working on optimus and actually smart summon autopark which have end of month deadlines',
#  'next month',
#  'yes',
#  'ok',
#  'starlink will ask for an exemption to iranian sanctions in this regard',
#  'looking forward to providing starlink service to the people of zambia',
#  'car will move on tighter gaps as we enhance nn velocity predictions for crossing traffic',
#  'next month has some step change improvements',
#  '',
#  'fsd beta         looks good extending to  k owners in us amp canada',
#  'profoundly important concept',
#  'baltasar gracián oráculo manual y arte de prudencia',
#  'great for clearing dust',
#  'booster   now returns to high bay for robustness upgrades amp booster   moves to pad for testing',
#  'next big test is probably full stack wet dress rehearsal then   engine firing in a few weeks',
#  'engine static fire https t co som jx rjq',
#  'chamber pressure looked good on all   engines',
#  'yes seven engine static fire',
#  'there is too much latency in fed decisions',
#  'problematic in a fast changing world',
#  'tunnels ftw',
#  'yes the fundamental error is reasoning by analogy rather than first principles',
#  'starry starry night paint your palette blue and gray https t co ium pzfdgc',
#  'starlink is now active on all continents including antarctica https t co q vvqv g i',
#  'another batch with lasers reaches orbit',
#  'true',
#  'starship will be an incredible enabler for science',
#  'full reusability amp high production rate drive several orders of magnitude improvement in kg to orbit amp beyond',
#  'next gen starlink constellation is primary user of this rocket so science doesn t need to cover fixed cost',
#  'should be alexander the greatest',
#  'after all is there a better alexander',
#  '',
#  'https t co vdcpkjm j',
#  'hyperloop could do that trip in less than half an hour',
#  'looks like they re fighting an actual fire demon',
#  'to help mend the fault in our stars',
#  'it will be later this year when laser links activate on polar constellation',
#  'starlink is meant for peaceful use only',
#  'is it really true that four year olds are receiving hormone treatment',
#  'technically true but earth s economy is extremely far from physical limits',
#  'energy is the foundation of the economy but we re using a very tiny amount of available energy even if we only used pv',
#  'beta expanding to safety scores above   after         goes out',
#  'coming out in a few days with additional polish       comes out shortly after ai day',
#  'or their short shorts https t co ek xby ga',
#  'salted butter is amazing but should be stored at room temperature https t co  rsr jb',
#  'drop',
#  'exactly this is neither subtle nor secret',
#  'layers upon layers of neural nets ever higher',
#  'https t co xmol wdxh',
#  'subtle',
#  '',
#  'note we are working on making the whistle sound much louder',
#  'but u have to pay in doge',
#  'blow the whistle',
#  'https t co rqldti ulz',
#  'true',
#  'could be worse',
#  'fair point',
#  '',
#  'good thread',
#  'https t co qjjdvyoszp',
#  'sounds pretty bad',
#  'please fix',
#  'my tweets are being suppressed',
#  '',
#  'this says it all none of the members of the stripe chat who spoke with me said that they accepted payment or agreed to speak to the firms about zatko and all said they wished to defend his credibility',
#  'anyone know who the secret clients are',
#  'let s out them on twitter rn haha',
#  'https t co g d mqzlrv',
#  'absolutely',
#  'true',
#  'i m testing it today in palo alto',
#  'rome show is underappreciated https t co oqd b o mw',
#  'this was harder than reaching volume production which was insanely hard',
#  '',
#  'there is appetite for an infinite number of interesting tweets',
#  '',
#  'take a moment to https t co r hk u uw',
#  'the residual value of gasoline cars bought today will be much lower than people think',
#  'supercharger centers with solar amp batteries are the long term vision',
#  'won t be long before we view gasoline cars the same way we view steam engines today',
#  'socrates can be a little boring tbh',
#  'yes',
#  'our view of reality is always wrong just a question of how wrong',
#  'i guess we could make joe mode quieter',
#  'still doing same thing but bigger',
#  'looks good to roll out to all tesla owners with        k cars',
#  'that is probably the right order of magnitude',
#  'real world validation amp billions of miles of real world training are what will make fsd superhuman',
#  'yup',
#  'sigh',
#  'fsd beta       rolling out now',
#  'please note that top priority is safety so expect it to be overly cautious especially around pedestrians',
#  'falcon arching to orbit https t co m grug fv',
#  'no obvious limit to rocket reflight so far https t co rbrcyjxjea',
#  'instagram is an envy amplifier',
#  'yes',
#  'team found a bug causing an   delay in detecting pedestrians at gt  m',
#  'that s been fixed so rolling out tonight',
#  '',
#  'that s pretty accurate',
#  'haha',
#  'astronomy too',
#  'internal beta rollout tonight wider tomorrow',
#  'it s coming',
#  'take materials science',
#  'you won t regret it',
#  'a major fed rate hike risks deflation',
#  'please lmk when that happens',
#  'absolutely the tesla fleet in australia is growing rapidly so we do need to ramp up service in general',
#  'tesla north america aiming for gt   same hour service',
#  '',
#  'anubis',
#  'nice',
#  'i m dressing up as a sink amp knocking on random doors',
#  'once they see me they will have no choice but to let that sink in',
#  'one of our most complex missions',
#  'bot block party',
#  'assuming   efficient pv cells at     surface coverage',
#  'exactly',
#  'ecosystem is almost entirely dependent on the sun already',
#  'civilization s energy needs are absurdly tiny compared to what the sun sends us for free   gwh day km',
#  'yup there s a reason we do static fires',
#  'much better to break things on the ground than en route to orbit',
#  'solar panels ground mount amp rooftop paired with stationary batteries will be civilization s primary source of energy as sure as day follows night',
#  'mark these words',
#  'i love the graffiti art at giga berlin',
#  'so much empty land amp only a tiny percentage needed to power entire country',
#  'it s looking good so far',
#  'indeed',
#  'we ve had some promising conversations with apple about starlink connectivity',
#  'iphone team is obv super smart',
#  'for sure closing link from space to phone will work best if phone software amp hardware adapt to space based signals vs starlink purely emulating cell tower',
#  'note i am putting a lot of time personally into advancing tesla service to make it awesome',
#  'hopefully this is starting to be felt by tesla owners',
#  'you re right we should credit tesla owners   if we change appointments with less than   hours notice',
#  'should be reciprocal',
#  '',
#  'lot of people still don t realize tesla makes uninterruptible power supplies for your whole home powerwall',
#  'and remember https t co unsjk cjm',
#  'this thread brings back a lot of memories',
#  'we have since improved it further',
#  'the primary solution to a sustainable energy future is solar wind with batteries for when sun doesn t shine or wind doesn t blow interconnected with conventional high voltage lines',
#  'no unknown technology is needed',
#  'hydro geothermal fission will also be non trivial contributors',
#  'fusion would be expensive energy given difficulty of obtaining and transporting source fuel plus maintaining the reactor',
#  'far better to use the sun thermonuclear reactor with no need to refuel or service',
#  '',
#  'only   squares no fog of war no tech tree only a few different pieces no random spawn',
#  'chess is a simple game',
#  'i prefer polytopia',
#  'interesting',
#  'that s not punny',
#  'more solar batteries needed',
#  'batteries are great at dealing with peak demand',
#  '',
#  'i accept   of cookies but if choc chip',
#  'if twitter put as much effort into bot spam removal as they do into subpoenas we wouldn t have this problem in the first place',
#  '',
#  'we have advised all potential witnesses to provide full cooperation to the court but we do not control their actions',
#  'read the actual ruling',
#  'we had zero to do with david sack s response',
#  'zero',
#  'those who claim any criticism of rings of power means you re racist are outing themselves as closet racists',
#  'peter jackson did excellent work with lord of the rings',
#  'the hobbit was stretched too long for a short book',
#  'for now supply is too low but ordering a powerwall by itself should be possible end of year',
#  'cool',
#  'order a tesla powerwall battery for blackout protection',
#  'https t co tee ldbd',
#  'and   of my comments are bots https t co a rkynjzor',
#  'almost every male character so far is a coward a jerk or both',
#  'only galadriel is brave smart and nice',
#  'release of       probably end of week',
#  'needs a bit more polish',
#  'tolkien is turning in his grave',
#  'has a relatively small number of code changes but their practical effect will be significant',
#  'more starlinks reach orbit',
#  'it will probably help proportionate to the cost of raising children',
#  'important',
#  'south korea is currently tracking to lose about half its population roughly every generation',
#  'long lifespan hides the dire nature of the problem',
#  '',
#  'invited me to open for one of his shows',
#  'thanks chris',
#  'i will try not to flounder too much',
#  'yes also very important',
#  'accurate assessment',
#  'raptor design started out using h  but switched to ch',
#  'latter is best combo of high efficiency amp ease of operation imo',
#  'delta v difference between h  amp ch  is small for most missions because ch  tank is much smaller amp no insulation is needed',
#  'moody s is irrelevant',
#  'https t co l gldge c',
#  'hope connor is ok',
#  '',
#  '',
#  '',
#  'on a bot basis this deal is awesome',
#  'sure sounds higher than',
#  'https t co va txxzoi',
#  'i intend to do so as soon as possible',
#  '',
#  'yeah aiming for up to   flights next year',
#  'now launching every   days https t co kjyg ckpyx',
#  'goes out to  k owners next week',
#  'sjm question',
#  'spent the day walking entire giga berlin production line team is doing excellent work',
#  'is even better',
#  'we reduced latency amp jitter in hardware command loop so time from object detection to brake actuation is   to   better',
#  'kickass internet connection coming royal caribbean ships soon',
#  'https t co  qjriuunah',
#  'it s true',
#  'ancient times',
#  'it will grow by at least   to   meters over time',
#  'first few days just  k owners but going to  k if no major issues',
#  'note       hopefully going out week after this is the wide release beta',
#  'good to ask yourself this often',
#  'agreed we recently made this change amp many others',
#  'an intense effort is underway to achieve robust engine containment in case of rud to protect booster other engines amp launch ring',
#  'this will happen again just a matter of time https t co heyzhzbaih',
#  'godspeed artemis',
#  'https t co  rzsqpambf',
#  'https t co jinhq gc j',
#  'the swoop of the x is meant to represent the rocket s arc to orbit',
#  'hopefully this week',
#  'wise actions',
#  'diet coke is amazing',
#  'please share some things in this thread which are working for you in life amp that others may find helpful',
#  'yeah i lift a little',
#  'over   lbs down from my unhealthy peak weight',
#  'from time to time i will share some things that seem to be working for me in case you find it helpful',
#  'the zero fasting app is quite good',
#  'on advice of a good friend i ve been fasting periodically amp feel healthier',
#  'yes but i ve done a lot with the place',
#  'gnus news snooze',
#  'coming',
#  'ares',
#  'what do you call a great dane eating a small piece of ham in a tiny village',
#  'hamlet eating hamlet in a hamlet',
#  'middle part credit to gam',
#  'squeezing extra performance out of falcon   almost at   metric tons to an actual useful orbit with booster amp fairing reusable',
#  'https t co vghsmasj d',
#  'maybe it s times for new roman',
#  'getting to orbit amp back is harder than it may seem',
#  'the caffeine one is most troubling',
#  'some are indeed sadly anti human',
#  'countries should be increasing nuclear power generation',
#  'it is insane from a national security standpoint amp bad for the environment to shut them down',
#  'lotr hg g',
#  'it is safe to say that our output will not exceed the mass of the known universe',
#  'similarly high cycle life with nickel cathode is possible if optimizing for that',
#  'adding silicon to primarily carbon anode which improves energy density reduces cycle life due to large volumetric changes during charge discharge',
#  'true',
#  'that plus pessimism about the future false overpopulation fears',
#  'yes',
#  'and i do think global warming is a major risk',
#  'yes',
#  'mark these words',
#  'population collapse due to low birth rates is a much bigger risk to civilization than global warming',
#  'good summary',
#  'yes',
#  'yes',
#  'note connectivity will be   to   mbits per cell zone so will work great for texting amp voice calls but not high bandwidth',
#  'starlink v  launching next year will transmit direct to mobile phones eliminating dead zones worldwide',
#  'livestream of big news in about an hour https t co lsmirybxhh',
#  'releases monday night',
#  'about a week or so later this will be the wide beta version',
#  'ron barron is awesome',
#  'crazy',
#  'i would gladly obey their commands but i can t tell what they re saying',
#  'i do not doubt that',
#  'criticism public or private is welcome after we go to wide beta',
#  'early beta has many known issues',
#  'the reason we release it to a limited number of cars is to discover unknown issues',
#  'no',
#  'let me make something clear james contacted me directly to be included in early beta which is only   cars mostly employees',
#  'early beta explicitly has issues or it would be rolled out widely so publicly criticizing something he had asked for is wrong',
#  'this is something special https t co lsmiryt zf',
#  'the course of civilization is not always upward https t co  mr pfwcni',
#  'true',
#  'mechazilla loads starship on launchpad https t co lfkfjpaczj',
#  '',
#  '',
#  'is in limited release for a reason',
#  'please do not ask to be included in early beta releases and then complain',
#  '',
#  '',
#  'so spam prevalence was shared with the board but the board chose not disclose that to the public https t co lxk tfzl',
#  '',
#  'important thread',
#  'in case anyone feels like buying a fine whistle',
#  'yet another verified',
#  '',
#  'https t co kswiazactx',
#  'you re waking up in the morning',
#  '',
#  ...]

# %% [markdown]
# ### Tokenizing the corpus

# %%
wordfreq = {}
for sentence in corpus:
    words = sentence.split()
    #tokens = nltk.word_tokenize(sentence) # To get the words, it can be also done with sentence.split()
    for word in words:
        if ( word not in wordfreq.keys() ): ## first time appearnce in the sentence
            wordfreq[word] = 1 # We initialize the corresponding counter
        else: ## if the world is already existed in the dictionalry 
            wordfreq[word] += 1 # We increase the corresponding counter

# %%
len(list(wordfreq.keys()))
# Out:
# 6025

# %%
wordfreq.keys()
# Out:
# dict_keys(['the', 'bird', 'is', 'freed', 'falcon', 'rockets', 'to', 'orbit', 'as', 'seen', 'from', 'la', 'https', 't', 'co', 'r', 'l', 'sblc', 'p', 'thanks', 'absolutely', 'dear', 'twitter', 'advertisers', 'gmwhminpas', 'meeting', 'a', 'lot', 'of', 'cool', 'people', 'at', 'today', 'entering', 'hq', 'let', 'that', 'sink', 'in', 'd', 'z', 'k', 'wq', 'definitely', 'closer', 'citizen', 'journalism', 'local', 'news', 'orgs', 'are', 'under', 'appreciated', 'amp', 'should', 'get', 'way', 'more', 'prominence', 'on', 'nobody', 'bats', 'beautiful', 'thing', 'about', 'how', 'it', 'empowers', 'able', 'disseminate', 'without', 'an', 'establishment', 'bias', 'i', 'm', 'big', 'fan', 'according', 'unnamed', 'sources', 'close', 'matter', 'who', 'wish', 'remain', 'anonymous', 'new', 'york', 'times', 'has', 'emerged', 'chaotic', 'actor', 'global', 'politics', 'paper', 's', 'interventions', 'some', 'world', 'most', 'combustible', 'conflicts', 'have', 'sometimes', 'been', 'boon', 'but', 'their', 'messaging', 'also', 'caused', 'problems', 'yes', 'concerning', 'works', 'any', 'moving', 'land', 'object', 'xu', 'qkjw', 'fasting', 'rocks', 'had', 'do', 'double', 'take', 'this', 'first', 'non', 'fake', 'vitalik', 'tweet', 've', 'while', 'one', 'man', 'hedge', 'another', 'shrub', 'yup', 'true', 'too', 'much', 'respect', 'for', 'authority', 'inhibits', 'innovation', 'what', 'lesson', 'took', 'you', 'longest', 'unlearn', 'διαλεκτική', 'be', 'broadly', 'inclusive', 'possible', 'serving', 'fair', 'forum', 'lively', 'even', 'if', 'occasionally', 'rancorous', 'debate', 'between', 'widely', 'divergent', 'beliefs', 'necessary', 'important', 'exactly', 'yeah', 'doesn', 'make', 'sense', 'good', 'thread', 'only', 'play', 'crazy', 'plan', 'unless', 'damaged', 'testing', 'really', 'matters', 'ship', 'booster', 'production', 'line', 'spooling', 'up', 'each', 'incremental', 'design', 'improvements', 'back', 'spare', 'bedroom', 'couch', 'surfing', 'friend', 'houses', 'silicon', 'valley', 'which', 'did', 'decade', 'frankly', 'like', 'see', 'my', 'friends', 'love', 'often', 'child', 'found', 'simple', 'useful', 'real', 'life', 'mere', 'by', 'grid', 'no', 'fog', 'war', 'technology', 'tree', 'random', 'map', 'or', 'spawn', 'position', 'players', 'both', 'sides', 'exact', 'same', 'pieces', 'etc', 'polytopia', 'addresses', 'these', 'limitations', 'and', 'don', 'own', 'house', 'alone', 'mansion', 'douche', 'kasparov', 'almost', 'playing', 'chess', 'iphone', 'he', 'otherwise', 'idiot', 'exciting', 'alive', 'time', 'largest', 'animal', 'ever', 'wild', 'blue', 'whales', 'bigger', 'than', 'biggest', 'dinosaur', 're', 'welcome', 'before', 'dod', 'came', 'with', 'answer', 'told', 'spacex', 'would', 'not', 'turn', 'off', 'starlink', 'refused', 'provide', 'funding', 'interesting', 'great', 'game', 'maybe', 'was', 'social', 'media', 'algorithm', 'think', 'might', 'decided', 'current', 'accepting', 'decides', 'question', 'know', 'wapo', 'such', 'hypocrites', 'neuralink', 'show', 'tell', 'now', 'nov', 'done', 'we', 'come', 'long', 'nothing', 'forever', 'point', 'needs', 'change', 'manufacturing', 'awesome', 'will', 'happen', 'hear', 'why', 'perpetuating', 'propaganda', 'concocted', 'oil', 'gas', 'industry', 'distract', 'trillion', 'dollars', 'per', 'year', 'subsidies', 'those', 'companies', 'receive', 'xzxdjape', 'switzerland', 'belgium', 'chocolate', 'eccentric', 'british', 'irish', 'artisanal', 'sweet', 'shops', 'next', 'week', 'actually', 'major', 'release', 'so', 'internal', 'needed', 'going', 'public', 'beta', 'although', 'there', 'could', 'candy', 'tbh', 'feels', 'hasn', 'improvement', 'decades', 'headline', 'misleading', 'can', 'obviously', 'offer', 'far', 'robust', 'positioning', 'gps', 'x', 'satellites', 'over', 'all', 'sight', 'users', 'still', 'gt', 'stronger', 'signal', 'just', 'problem', 'favorite', 'conspiracy', 'theories', 'men', 'un', 'ass', 'ailable', 'logic', 'j', 'zhlazopa', 'right', 'eventually', 'run', 'out', 'gyxk', 'uzliw', 'giga', 'berlin', 'colors', 'paint', 'sho ...

# %%
type(wordfreq)
# Out:
# dict

# %%
#remove words with lenght less than 2, but keeping 'ok'
wordfreq = dict((key,wordfreq[key]) for key in w if len(key)>2 or key== 'ok')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 #remove words with lenght less than 2, but keeping 'ok'
# ----> 2 wordfreq = dict((key,wordfreq[key]) for key in w if len(key)>2 or key== 'ok')
#
# NameError: name 'w' is not defined

# %%
type(wordfreq)
# Out:
# dict

# %%
len(list(wordfreq.keys()))
# Out:
# 5787

# %%
#Reduce the corpus by removung stopwords

from nltk.corpus import stopwords

stop_words = list(stopwords.words('english'))

# %%
#Cleaning stop words (i.e : you vs you're)
for i in range(len(stop_words)):
    stop_words[i] = re.sub(r"\s*'\s*\w*","",stop_words[i])

#stop_words = [word for word in list(np.unique(stop_words)) if len(word) > 1]
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  'she',
#  'her',
#  'hers',
#  'herself',
#  'it',
#  'it',
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  'that',
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  'don',
#  'should',
#  'should',
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  'aren',
#  'couldn',
#  'couldn',
#  'didn',
#  'didn',
#  'doesn',
#  'doesn',
#  'hadn',
#  'hadn',
#  'hasn',
#  'hasn',
#  'haven',
#  'haven',
#  'isn',
#  'isn',
#  'ma',
#  'mightn',
#  'mightn',
#  'mustn',
#  'mustn',
#  'needn',
#  'needn',
#  'shan',
#  'shan',
#  'shouldn',
#  'shouldn',
#  'wasn',
#  'wasn',
#  'weren',
#  'weren',
#  'won',
#  'won',
#  'wouldn',
#  'wouldn']

# %%
#drop stop words from bag
corpus = [(wordfreq[key],key) for key in list(wordfreq.keys()) if key not in stop_words]

# %%
corpus
# Out:
# [(1, 'bird'),
#  (1, 'freed'),
#  (21, 'falcon'),
#  (5, 'rockets'),
#  (32, 'orbit'),
#  (12, 'seen'),
#  (400, 'https'),
#  (1, 'sblc'),
#  (22, 'thanks'),
#  (24, 'absolutely'),
#  (1, 'dear'),
#  (100, 'twitter'),
#  (4, 'advertisers'),
#  (1, 'gmwhminpas'),
#  (3, 'meeting'),
#  (40, 'lot'),
#  (22, 'cool'),
#  (100, 'people'),
#  (16, 'today'),
#  (1, 'entering'),
#  (24, 'let'),
#  (7, 'sink'),
#  (12, 'definitely'),
#  (3, 'closer'),
#  (5, 'citizen'),
#  (6, 'journalism'),
#  (4, 'local'),
#  (17, 'news'),
#  (2, 'orgs'),
#  (5, 'appreciated'),
#  (282, 'amp'),
#  (34, 'get'),
#  (38, 'way'),
#  (1, 'prominence'),
#  (3, 'nobody'),
#  (1, 'bats'),
#  (8, 'beautiful'),
#  (22, 'thing'),
#  (1, 'empowers'),
#  (9, 'able'),
#  (1, 'disseminate'),
#  (14, 'without'),
#  (2, 'establishment'),
#  (4, 'bias'),
#  (30, 'big'),
#  (7, 'fan'),
#  (4, 'according'),
#  (1, 'unnamed'),
#  (3, 'sources'),
#  (11, 'close'),
#  (10, 'matter'),
#  (6, 'wish'),
#  (3, 'remain'),
#  (2, 'anonymous'),
#  (28, 'new'),
#  (1, 'york'),
#  (33, 'times'),
#  (1, 'emerged'),
#  (1, 'chaotic'),
#  (1, 'actor'),
#  (9, 'global'),
#  (3, 'politics'),
#  (4, 'paper'),
#  (2, 'interventions'),
#  (37, 'world'),
#  (1, 'combustible'),
#  (1, 'conflicts'),
#  (7, 'sometimes'),
#  (1, 'boon'),
#  (2, 'messaging'),
#  (61, 'also'),
#  (3, 'caused'),
#  (4, 'problems'),
#  (83, 'yes'),
#  (5, 'concerning'),
#  (5, 'works'),
#  (10, 'moving'),
#  (6, 'land'),
#  (3, 'object'),
#  (1, 'qkjw'),
#  (4, 'fasting'),
#  (5, 'rocks'),
#  (5, 'double'),
#  (19, 'take'),
#  (31, 'first'),
#  (5, 'non'),
#  (15, 'fake'),
#  (1, 'vitalik'),
#  (10, 'tweet'),
#  (76, 'one'),
#  (8, 'man'),
#  (1, 'hedge'),
#  (22, 'another'),
#  (1, 'shrub'),
#  (28, 'yup'),
#  (75, 'true'),
#  (81, 'much'),
#  (6, 'respect'),
#  (1, 'authority'),
#  (1, 'inhibits'),
#  (1, 'innovation'),
#  (2, 'lesson'),
#  (5, 'took'),
#  (1, 'longest'),
#  (1, 'unlearn'),
#  (1, 'διαλεκτική'),
#  (2, 'broadly'),
#  (3, 'inclusive'),
#  (26, 'possible'),
#  (1, 'serving'),
#  (6, 'fair'),
#  (2, 'forum'),
#  (1, 'lively'),
#  (67, 'even'),
#  (2, 'occasionally'),
#  (1, 'rancorous'),
#  (4, 'debate'),
#  (2, 'widely'),
#  (1, 'divergent'),
#  (1, 'beliefs'),
#  (2, 'necessary'),
#  (22, 'important'),
#  (55, 'exactly'),
#  (55, 'yeah'),
#  (52, 'make'),
#  (9, 'sense'),
#  (102, 'good'),
#  (20, 'thread'),
#  (6, 'play'),
#  (10, 'crazy'),
#  (8, 'plan'),
#  (10, 'unless'),
#  (1, 'damaged'),
#  (9, 'testing'),
#  (16, 'really'),
#  (7, 'matters'),
#  (4, 'ship'),
#  (20, 'booster'),
#  (23, 'production'),
#  (6, 'line'),
#  (1, 'spooling'),
#  (4, 'incremental'),
#  (9, 'design'),
#  (9, 'improvements'),
#  (26, 'back'),
#  (1, 'spare'),
#  (1, 'bedroom'),
#  (1, 'couch'),
#  (1, 'surfing'),
#  (8, 'friend'),
#  (1, 'houses'),
#  (2, 'silicon'),
#  (1, 'valley'),
#  (1, 'decade'),
#  (3, 'frankly'),
#  (68, 'like'),
#  (28, 'see'),
#  (7, 'friends'),
#  (25, 'love'),
#  (11, 'often'),
#  (3, 'child'),
#  (3, 'found'),
#  (6, 'simple'),
#  (6, 'useful'),
#  (38, 'real'),
#  (38, 'life'),
#  (1, 'mere'),
#  (3, 'grid'),
#  (3, 'fog'),
#  (25, 'war'),
#  (8, 'technology'),
#  (4, 'tree'),
#  (8, 'random'),
#  (4, 'map'),
#  (2, 'spawn'),
#  (2, 'position'),
#  (1, 'players'),
#  (7, 'sides'),
#  (1, 'exact'),
#  (4, 'pieces'),
#  (3, 'etc'),
#  (3, 'polytopia'),
#  (1, 'addresses'),
#  (1, 'limitations'),
#  (5, 'house'),
#  (3, 'alone'),
#  (1, 'mansion'),
#  (1, 'douche'),
#  (1, 'kasparov'),
#  (30, 'almost'),
#  (3, 'playing'),
#  (4, 'chess'),
#  (2, 'iphone'),
#  (7, 'otherwise'),
#  (2, 'idiot'),
#  (4, 'exciting'),
#  (5, 'alive'),
#  (62, 'time'),
#  (3, 'largest'),
#  (1, 'animal'),
#  (18, 'ever'),
#  (7, 'wild'),
#  (3, 'blue'),
#  (1, 'whales'),
#  (10, 'bigger'),
#  (8, 'biggest'),
#  (1, 'dinosaur'),
#  (8, 'welcome'),
#  (5, 'dod'),
#  (2, 'came'),
#  (4, 'answer'),
#  (7, 'told'),
#  (52, 'spacex'),
#  (103, 'would'),
#  (7, 'turn'),
#  (80, 'starlink'),
#  (4, 'refused'),
#  (8, 'provide'),
#  (5, 'funding'),
#  (27, 'interesting'),
#  (66, 'great'),
#  (11, 'game'),
#  (49, 'maybe'),
#  (11, 'social'),
#  (21, 'media'),
#  (9, 'algorithm'),
#  (51, 'think'),
#  (22, 'might'),
#  (2, 'decided'),
#  (14, 'current'),
#  (1, 'accepting'),
#  (1, 'decides'),
#  (26, 'question'),
#  (30, 'know'),
#  (4, 'wapo'),
#  (1, 'hypocrites'),
#  (5, 'neuralink'),
#  (12, 'show'),
#  (6, 'tell'),
#  (1, 'nov'),
#  (21, 'done'),
#  (8, 'come'),
#  (33, 'long'),
#  (15, 'nothing'),
#  (1, 'forever'),
#  (25, 'point'),
#  (17, 'needs'),
#  (11, 'change'),
#  (1, 'manufacturing'),
#  (18, 'awesome'),
#  (4, 'happen'),
#  (9, 'hear'),
#  (1, 'perpetuating'),
#  (2, 'propaganda'),
#  (1, 'concocted'),
#  (9, 'oil'),
#  (8, 'gas'),
#  (5, 'industry'),
#  (1, 'distract'),
#  (4, 'trillion'),
#  (3, 'dollars'),
#  (13, 'per'),
#  (51, 'year'),
#  (1, 'subsidies'),
#  (19, 'companies'),
#  (5, 'receive'),
#  (1, 'xzxdjape'),
#  (2, 'switzerland'),
#  (1, 'belgium'),
#  (2, 'chocolate'),
#  (1, 'eccentric'),
#  (2, 'british'),
#  (1, 'irish'),
#  (1, 'artisanal'),
#  (2, 'sweet'),
#  (1, 'shops'),
#  (52, 'next'),
#  (26, 'week'),
#  (34, 'actually'),
#  (23, 'major'),
#  (27, 'release'),
#  (5, 'internal'),
#  (26, 'needed'),
#  (19, 'going'),
#  (18, 'public'),
#  (34, 'beta'),
#  (7, 'although'),
#  (26, 'could'),
#  (2, 'candy'),
#  (7, 'tbh'),
#  (7, 'feels'),
#  (7, 'improvement'),
#  (1, 'decades'),
#  (1, 'headline'),
#  (1, 'misleading'),
#  (13, 'obviously'),
#  (8, 'offer'),
#  (43, 'far'),
#  (3, 'robust'),
#  (1, 'positioning'),
#  (6, 'gps'),
#  (15, 'satellites'),
#  (1, 'sight'),
#  (18, 'users'),
#  (50, 'still'),
#  (1, 'stronger'),
#  (12, 'signal'),
#  (16, 'problem'),
#  (4, 'favorite'),
#  (2, 'conspiracy'),
#  (1, 'theories'),
#  (2, 'men'),
#  (2, 'ass'),
#  (1, 'ailable'),
#  (3, 'logic'),
#  (1, 'zhlazopa'),
#  (41, 'right'),
#  (4, 'eventually'),
#  (7, 'run'),
#  (1, 'gyxk'),
#  (1, 'uzliw'),
#  (15, 'giga'),
#  (8, 'berlin'),
#  (1, 'colors'),
#  (4, 'paint'),
#  (3, 'shop'),
#  (1, 'specially'),
#  (7, 'built'),
#  (1, 'apply'),
#  (69, 'many'),
#  (6, 'fine'),
#  (4, 'layers'),
#  (8, 'giving'),
#  (2, 'complexity'),
#  (1, 'htis'),
#  (1, 'lfrzv'),
#  (2, 'varies'),
#  (153, 'tesla'),
#  (1, 'positions'),
#  (2, 'recessions'),
#  (1, 'silver'),
#  (1, 'lining'),
#  (4, 'exist'),
#  (8, 'stop'),
#  (6, 'existing'),
#  (22, 'want'),
#  (2, 'putin'),
#  (1, 'removed'),
#  (1, 'laboring'),
#  (1, 'misapprehension'),
#  (3, 'whoever'),
#  (1, 'replaces'),
#  (1, 'amenable'),
#  (11, 'peace'),
#  (1, 'western'),
#  (4, 'philosophy'),
#  (5, 'unlikely'),
#  (1, 'kremlin'),
#  (14, 'nice'),
#  (4, 'guy'),
#  (2, 'olympics'),
#  (38, 'russia'),
#  (1, 'overrunning'),
#  (35, 'ukraine'),
#  (1, 'destabilize'),
#  (11, 'entire'),
#  (4, 'region'),
#  (9, 'perhaps'),
#  (3, 'faced'),
#  (1, 'calamitous'),
#  (6, 'defeat'),
#  (2, 'conventional'),
#  (1, 'warfare'),
#  (22, 'something'),
#  (1, 'strategically'),
#  (6, 'critical'),
#  (13, 'crimea'),
#  (8, 'probability'),
#  (14, 'using'),
#  (10, 'nuclear'),
#  (4, 'weapons'),
#  (48, 'high'),
#  (1, 'closest'),
#  (23, 'since'),
#  (1, 'cuba'),
#  (1, 'guessing'),
#  (45, 'probably'),
#  (2, 'spring'),
#  (23, 'sure'),
#  (2, 'horrible'),
#  (3, 'event'),
#  (2, 'brutal'),
#  (4, 'common'),
#  (1, 'phrase'),
#  (21, 'months'),
#  (1, 'wqgm'),
#  (1, 'inntp'),
#  (4, 'certainly'),
#  (1, 'warrants'),
#  (1, 'scrutiny'),
#  (7, 'btw'),
#  (1, 'bakhmut'),
#  (27, 'pretty'),
#  (1, 'troll'),
#  (1, 'humour'),
#  (6, 'agree'),
#  (7, 'humor'),
#  (31, 'best'),
#  (1, 'compromise'),
#  (3, 'overwhelmingly'),
#  (4, 'likely'),
#  (7, 'outcome'),
#  (11, 'death'),
#  (4, 'destruction'),
#  (5, 'happens'),
#  (4, 'nature'),
#  (3, 'probable'),
#  (1, 'attrition'),
#  (1, 'destroys'),
#  (2, 'severely'),
#  (3, 'damages'),
#  (8, 'massive'),
#  (5, 'body'),
#  (7, 'count'),
#  (22, 'end'),
#  (9, 'congrats'),
#  (44, 'team'),
#  (17, 'launch'),
#  (1, 'holds'),
#  (4, 'record'),
#  (6, 'launches'),
#  (13, 'single'),
#  (10, 'vehicle'),
#  (1, 'type'),
#  (13, 'active'),
#  (10, 'rest'),
#  (42, 'earth'),
#  (6, 'combined'),
#  (4, 'tracking'),
#  (19, 'soon'),
#  (1, 'reports'),
#  (1, 'fanfare'),
#  (2, 'predictions'),
#  (4, 'late'),
#  (4, 'rarely'),
#  (10, 'early'),
#  (3, 'accelerating'),
#  (13, 'sustainable'),
#  (25, 'energy'),
#  (8, 'primary'),
#  (3, 'mission'),
#  (5, 'require'),
#  (3, 'truly'),
#  (3, 'exceptional'),
#  (2, 'execution'),
#  (4, 'takes'),
#  (18, 'video'),
#  (7, 'call'),
#  (2, 'airplane'),
#  (2, 'aloft'),
#  (18, 'away'),
#  (2, 'worked'),
#  (1, 'perfectly'),
#  (1, 'lag'),
#  (2, 'vox'),
#  (1, 'populi'),
#  (1, 'dei'),
#  (13, 'several'),
#  (3, 'architectural'),
#  (6, 'upgrades'),
#  (1, 'sticking'),
#  (7, 'cause'),
#  (50, 'haha'),
#  (13, 'sounds'),
#  (5, 'kid'),
#  (2, 'naming'),
#  (5, 'ideas'),
#  (7, 'sold'),
#  (17, 'internet'),
#  (1, 'airplanes'),
#  (6, 'feel'),
#  (1, 'accessing'),
#  (10, 'home'),
#  (1, 'mfl'),
#  (1, 'ixynjh'),
#  (3, 'bottles'),
#  (1, 'exquisite'),
#  (7, 'burnt'),
#  (9, 'hair'),
#  (2, 'perfume'),
#  (18, 'already'),
#  (25, 'left'),
#  (3, 'unique'),
#  (7, 'limited'),
#  (1, 'edition'),
#  (1, 'collector'),
#  (1, 'item'),
#  (31, 'working'),
#  (9, 'hope'),
#  (15, 'money'),
#  (7, 'countries'),
#  (2, 'individuals'),
#  (3, 'paying'),
#  (16, 'terminals'),
#  (8, 'losing'),
#  (24, 'month'),
#  (9, 'due'),
#  (1, 'unpaid'),
#  (15, 'service'),
#  (7, 'costs'),
#  (2, 'related'),
#  (1, 'enhanced'),
#  (6, 'security'),
#  (2, 'measures'),
#  (3, 'cyberwar'),
#  (4, 'defense'),
#  (8, 'keep'),
#  (20, 'sigh'),
#  (9, 'smart'),
#  (4, 'dumb'),
#  (6, 'stuff'),
#  (1, 'jxa'),
#  (1, 'stwf'),
#  (1, 'ideally'),
#  (10, 'easy'),
#  (1, 'prediction'),
#  (1, 'drone'),
#  (1, 'ervme'),
#  (1, 'cbbn'),
#  (1, 'ccaypontfg'),
#  (3, 'summon'),
#  (9, 'optimus'),
#  (3, 'precise'),
#  (6, 'sent'),
#  (4, 'present'),
#  (1, 'withdrawn'),
#  (3, 'request'),
#  (11, 'wrong'),
#  (2, 'analogy'),
#  (16, 'america'),
#  (2, 'humiliating'),
#  (1, 'withdrawal'),
#  (1, 'afghanistan'),
#  (2, 'sees'),
#  (6, 'country'),
#  (24, 'part'),
#  (2, 'crucial'),
#  (3, 'hawaii'),
#  (1, 'practice'),
#  (9, 'makes'),
#  (3, 'perfect'),
#  (1, 'punched'),
#  (2, 'nose'),
#  (1, 'forced'),
#  (1, 'retreat'),
#  (7, 'give'),
#  (6, 'choice'),
#  (11, 'total'),
#  (7, 'nukes'),
#  (4, 'disagree'),
#  (25, 'say'),
#  (4, 'utterly'),
#  (2, 'dangerous'),
#  (4, 'fools'),
#  (2, 'hey'),
#  (9, 'look'),
#  (5, 'bright'),
#  (15, 'side'),
#  (14, 'least'),
#  (1, 'scenario'),
#  (1, 'comforted'),
#  (4, 'thought'),
#  (3, 'watching'),
#  (1, 'mushroom'),
#  (2, 'clouds'),
#  (5, 'rise'),
#  (3, 'faces'),
#  (4, 'army'),
#  (2, 'utter'),
#  (2, 'nato'),
#  (24, 'use'),
#  (1, 'respond'),
#  (23, 'civilization'),
#  (5, 'whether'),
#  (2, 'likes'),
#  (2, 'core'),
#  (5, 'national'),
#  (3, 'importance'),
#  (1, 'southern'),
#  (1, 'navy'),
#  (3, 'base'),
#  (3, 'standpoint'),
#  (5, 'usa'),
#  (1, 'pearl'),
#  (1, 'harbor'),
#  (4, 'battlefield'),
#  (2, 'choose'),
#  (6, 'latter'),
#  (1, 'sanctioned'),
#  (1, 'cutoff'),
#  (26, 'every'),
#  (6, 'lose'),
#  (2, 'nuke'),
#  (2, 'exceptionally'),
#  (28, 'well'),
#  (17, 'said'),
#  (1, 'fxg'),
#  (1, 'mef'),
#  (10, 'standard'),
#  (10, 'performance'),
#  (1, 'suspension'),
#  (4, 'improved'),
#  (1, 'comfort'),
#  (2, 'affecting'),
#  (2, 'handling'),
#  (10, 'version'),
#  (11, 'lower'),
#  (6, 'priority'),
#  (4, 'speeds'),
#  (6, 'hours'),
#  (8, 'happening'),
#  (4, 'add'),
#  (4, 'upgrade'),
#  (7, 'satellite'),
#  (10, 'user'),
#  (3, 'density'),
#  (2, 'locations'),
#  (8, 'significant'),
#  (2, 'increases'),
#  (29, 'ok'),
#  (4, 'donate'),
#  (3, 'option'),
#  (2, 'oddly'),
#  (8, 'low'),
#  (1, 'normally'),
#  (10, 'higher'),
#  (14, 'others'),
#  (10, 'starlinks'),
#  (3, 'places'),
#  (30, 'need'),
#  (1, 'asmenmrd'),
#  (7, 'happened'),
#  (2, 'quieter'),
#  (1, 'leaf'),
#  (1, 'blower'),
#  (9, 'harder'),
#  (1, 'deus'),
#  (1, 'machina'),
#  (1, 'proceeding'),
#  (2, 'carefully'),
#  (3, 'rud'),
#  (6, 'pad'),
#  (28, 'starship'),
#  (17, 'progress'),
#  (4, 'set'),
#  (8, 'gets'),
#  (7, 'hit'),
#  (7, 'size'),
#  (1, 'ramen'),
#  (1, 'lambos'),
#  (9, 'used'),
#  (1, 'rocketry'),
#  (1, 'pwmxuvu'),
#  (1, 'millipede'),
#  (1, 'millennia'),
#  (5, 'bring'),
#  (1, 'outfits'),
#  (1, 'fancy'),
#  (6, 'meme'),
#  (1, 'tennis'),
#  (1, 'tqilg'),
#  (7, 'buy'),
#  (23, 'company'),
#  (1, 'digs'),
#  (1, 'holes'),
#  (9, 'read'),
#  (1, 'goth'),
#  (1, 'clowns'),
#  (1, 'lonely'),
#  (1, 'dyslexic'),
#  (1, 'kbg'),
#  (1, 'agent'),
#  (1, 'pot'),
#  (6, 'secret'),
#  (1, 'venn'),
#  (1, 'diagram'),
#  (3, 'intersection'),
#  (13, 'two'),
#  (1, 'audiences'),
#  (16, 'small'),
#  (9, 'guess'),
#  (4, 'popular'),
#  (1, 'hoped'),
#  (1, 'pitching'),
#  (14, 'idea'),
#  (1, 'crossover'),
#  (5, 'das'),
#  (2, 'boot'),
#  (5, 'boss'),
#  (8, 'baby'),
#  (2, 'hijinks'),
#  (5, 'seas'),
#  (1, 'fiermsthp'),
#  (3, 'scratch'),
#  (1, 'buff'),
#  (12, 'mostly'),
#  (21, 'accurate'),
#  (7, 'comments'),
#  (1, 'theorist'),
#  (2, 'wet'),
#  (1, 'dream'),
#  (43, 'years'),
#  (21, 'ago'),
#  (1, 'strangest'),
#  (1, 'meetings'),
#  (2, 'experienced'),
#  (18, 'trying'),
#  (5, 'hardest'),
#  (3, 'escalate'),
#  (5, 'situation'),
#  (2, 'failing'),
#  (3, 'damned'),
#  (4, 'gen'),
#  (4, 'key'),
#  (14, 'risk'),
#  (2, 'lies'),
#  (3, 'ahead'),
#  (10, 'scale'),
#  (1, 'hilarious'),
#  (17, 'goes'),
#  (5, 'fate'),
#  (2, 'loves'),
#  (6, 'irony'),
#  (1, 'deeds'),
#  (2, 'hell'),
#  (7, 'though'),
#  (12, 'getting'),
#  (3, 'billions'),
#  (1, 'taxpayer'),
#  (5, 'govt'),
#  (25, 'free'),
#  (2, 'dude'),
#  (2, 'condition'),
#  (1, 'anonymity'),
#  (1, 'spineless'),
#  (3, 'coward'),
#  (1, 'ignorant'),
#  (1, 'fool'),
#  (10, 'directly'),
#  (1, 'requested'),
#  (15, 'government'),
#  (4, 'required'),
#  (4, 'resources'),
#  (23, 'super'),
#  (1, 'lockdown'),
#  (4, 'mode'),
#  (1, 'slows'),
#  (3, 'development'),
#  (1, 'resist'),
#  (8, 'attacks'),
#  (2, 'sophisticated'),
#  (1, 'adversary'),
#  (2, 'actively'),
#  (4, 'provided'),
#  (13, 'cost'),
#  (1, 'context'),
#  (7, 'course'),
#  (7, 'jamming'),
#  (2, 'systems'),
#  (38, 'better'),
#  (6, 'amount'),
#  (1, 'requesting'),
#  (5, 'advantage'),
#  (23, 'less'),
#  (4, 'ironically'),
#  (43, 'work'),
#  (1, 'battlefields'),
#  (2, 'jam'),
#  (1, 'someday'),
#  (19, 'humanity'),
#  (4, 'stopped'),
#  (1, 'pointing'),
#  (4, 'destroy'),
#  (17, 'given'),
#  (7, 'chance'),
#  (11, 'zero'),
#  (1, 'launched'),
#  (5, 'highest'),
#  (1, 'hsqneyhnx'),
#  (2, 'curses'),
#  (1, 'foiled'),
#  (4, 'ability'),
#  (4, 'europe'),
#  (1, 'missiles'),
#  (1, 'minutes'),
#  (1, 'vice'),
#  (1, 'versa'),
#  (2, 'surprising'),
#  (11, 'number'),
#  (3, 'mad'),
#  (13, 'potential'),
#  (2, 'fiber'),
#  (7, 'phone'),
#  (4, 'lines'),
#  (6, 'cell'),
#  (1, 'towers'),
#  (14, 'space'),
#  (7, 'based'),
#  (4, 'comms'),
#  (6, 'areas'),
#  (2, 'destroyed'),
#  (1, 'cdjbowgziz'),
#  (7, 'thank'),
#  (1, 'clarifying'),
#  (5, 'communications'),
#  (13, 'system'),
#  (2, 'ukrainian'),
#  (2, 'front'),
#  (13, 'anyone'),
#  (7, 'else'),
#  (3, 'wants'),
#  (3, 'job'),
#  (19, 'please'),
#  (1, 'guest'),
#  (11, 'difference'),
#  (2, 'warfront'),
#  (4, 'dead'),
#  (1, 'kill'),
#  (1, 'safeguard'),
#  (1, 'diverted'),
#  (6, 'towards'),
#  (22, 'may'),
#  (13, 'die'),
#  (1, 'xtwjf'),
#  (2, 'citizens'),
#  (1, 'nations'),
#  (2, 'helping'),
#  (9, 'list'),
#  (2, 'surely'),
#  (5, 'reasonable'),
#  (6, 'person'),
#  (3, 'dealing'),
#  (9, 'place'),
#  (1, 'url'),
#  (13, 'never'),
#  (4, 'fear'),
#  (1, 'turbulence'),
#  (4, 'commercial'),
#  (1, 'airliner'),
#  (1, 'wings'),
#  (5, 'handle'),
#  (13, 'insane'),
#  (3, 'amounts'),
#  (1, 'bending'),
#  (12, 'ask'),
#  (3, 'following'),
#  (1, 'recommendation'),
#  (8, 'past'),
#  (1, 'breakeven'),
#  (2, 'fund'),
#  (19, 'mars'),
#  (1, 'addition'),
#  (2, 'create'),
#  (3, 'maintain'),
#  (1, 'replenish'),
#  (7, 'ground'),
#  (4, 'stations'),
#  (9, 'pay'),
#  (1, 'telcos'),
#  (3, 'access'),
#  (4, 'via'),
#  (1, 'gateways'),
#  (2, 'defend'),
#  (1, 'cyberattacks'),
#  (4, 'burn'),
#  (1, 'approaching'),
#  (4, 'insanely'),
#  (6, 'difficult'),
#  (2, 'leo'),
#  (4, 'constellation'),
#  (7, 'avoid'),
#  (3, 'bankruptcy'),
#  (6, 'tried'),
#  (6, 'asked'),
#  (10, 'goal'),
#  (2, 'conference'),
#  (3, 'bankrupt'),
#  (7, 'got'),
#  (1, 'iran'),
#  (9, 'strange'),
#  (1, 'leaked'),
#  (1, 'competitors'),
#  (1, 'lockheed'),
#  (1, 'boeing'),
#  (4, 'surprised'),
#  (11, 'find'),
#  (5, 'particular'),
#  (6, 'individual'),
#  (1, 'retires'),
#  (3, 'corruption'),
#  (2, 'finest'),
#  (2, 'asking'),
#  (1, 'recoup'),
#  (1, 'expenses'),
#  (5, 'cannot'),
#  (1, 'indefinitely'),
#  (7, 'send'),
#  (4, 'thousand'),
#  (9, 'data'),
#  (3, 'usage'),
#  (3, 'greater'),
#  (1, 'typical'),
#  (1, 'households'),
#  (1, 'unreasonable'),
#  (2, 'vital'),
#  (32, 'future'),
#  (9, 'consciousness'),
#  (1, 'srsly'),
#  (2, 'envy'),
#  (4, 'driven'),
#  (2, 'madness'),
#  (5, 'requires'),
#  (3, 'except'),
#  (1, 'watt'),
#  (24, 'power'),
#  (10, 'source'),
#  (18, 'solar'),
#  (6, 'plus'),
#  (5, 'battery'),
#  (3, 'generator'),
#  (5, 'connectivity'),
#  (3, 'anywhere'),
#  (40, 'day'),
#  (2, 'successfully'),
#  (2, 'viasat'),
#  (1, 'xrramqfszy'),
#  (5, 'relentless'),
#  (3, 'success'),
#  (3, 'noted'),
#  (2, 'growth'),
#  (1, 'iwnwkwlr'),
#  (1, 'ewwyqvwkr'),
#  (1, 'wlvh'),
#  (1, 'zbio'),
#  (2, 'opinion'),
#  (2, 'elon'),
#  (14, 'saying'),
#  (1, 'chill'),
#  (4, 'laugh'),
#  (7, 'share'),
#  (8, 'different'),
#  (15, 'name'),
#  (9, 'basically'),
#  (2, 'roaming'),
#  (3, 'capability'),
#  (7, 'terminal'),
#  (1, 'gnh'),
#  (1, 'yppvos'),
#  (4, 'counter'),
#  (3, 'intuitive'),
#  (1, 'gonna'),
#  (1, 'sick'),
#  (12, 'product'),
#  (1, 'cue'),
#  (1, 'ryskrhejfi'),
#  (4, 'glad'),
#  (21, 'support'),
#  (1, 'lit'),
#  (9, 'wait'),
#  (4, 'stories'),
#  (13, 'tomorrow'),
#  (1, 'omnigender'),
#  (1, 'wdthxqgupx'),
#  (4, 'mine'),
#  (2, 'fragrance'),
#  (3, 'business'),
#  (3, 'inevitable'),
#  (5, 'fight'),
#  (6, 'doge'),
#  (1, 'ohjwxnx'),
#  (1, 'lmreobs'),
#  (6, 'trust'),
#  (1, 'bremmer'),
#  (3, 'finally'),
#  (3, 'achieve'),
#  (1, 'jkbu'),
#  (1, 'wjida'),
#  (1, 'typically'),
#  (1, 'ayahuasca'),
#  (1, 'nlxw'),
#  (1, 'rch'),
#  (4, 'subtle'),
#  (1, 'sam'),
#  (1, 'meditating'),
#  (1, 'regularly'),
#  (1, 'scheduled'),
#  (1, 'programming'),
#  (1, 'pointless'),
#  (6, 'currently'),
#  (1, 'overlap'),
#  ...]

# %%
corpus.sort(reverse = True)
corpus
# Out:
# [(400, 'https'),
#  (282, 'amp'),
#  (153, 'tesla'),
#  (103, 'would'),
#  (102, 'good'),
#  (100, 'twitter'),
#  (100, 'people'),
#  (83, 'yes'),
#  (81, 'much'),
#  (80, 'starlink'),
#  (76, 'one'),
#  (75, 'true'),
#  (69, 'many'),
#  (68, 'like'),
#  (67, 'even'),
#  (66, 'great'),
#  (62, 'time'),
#  (61, 'also'),
#  (55, 'yeah'),
#  (55, 'exactly'),
#  (52, 'spacex'),
#  (52, 'next'),
#  (52, 'make'),
#  (51, 'year'),
#  (51, 'think'),
#  (50, 'still'),
#  (50, 'haha'),
#  (49, 'maybe'),
#  (48, 'high'),
#  (45, 'probably'),
#  (44, 'team'),
#  (43, 'years'),
#  (43, 'work'),
#  (43, 'far'),
#  (42, 'earth'),
#  (41, 'right'),
#  (41, 'car'),
#  (40, 'lot'),
#  (40, 'day'),
#  (38, 'way'),
#  (38, 'russia'),
#  (38, 'real'),
#  (38, 'life'),
#  (38, 'better'),
#  (37, 'world'),
#  (35, 'ukraine'),
#  (34, 'get'),
#  (34, 'beta'),
#  (34, 'actually'),
#  (33, 'times'),
#  (33, 'long'),
#  (32, 'orbit'),
#  (32, 'future'),
#  (31, 'working'),
#  (31, 'first'),
#  (31, 'best'),
#  (30, 'need'),
#  (30, 'know'),
#  (30, 'big'),
#  (30, 'almost'),
#  (29, 'ok'),
#  (29, 'hard'),
#  (29, 'fsd'),
#  (28, 'yup'),
#  (28, 'well'),
#  (28, 'starship'),
#  (28, 'see'),
#  (28, 'new'),
#  (27, 'release'),
#  (27, 'pretty'),
#  (27, 'party'),
#  (27, 'made'),
#  (27, 'interesting'),
#  (27, 'cars'),
#  (26, 'week'),
#  (26, 'question'),
#  (26, 'possible'),
#  (26, 'needed'),
#  (26, 'every'),
#  (26, 'could'),
#  (26, 'bad'),
#  (26, 'back'),
#  (25, 'war'),
#  (25, 'say'),
#  (25, 'point'),
#  (25, 'love'),
#  (25, 'left'),
#  (25, 'free'),
#  (25, 'energy'),
#  (24, 'use'),
#  (24, 'power'),
#  (24, 'part'),
#  (24, 'month'),
#  (24, 'let'),
#  (24, 'absolutely'),
#  (23, 'things'),
#  (23, 'sure'),
#  (23, 'super'),
#  (23, 'since'),
#  (23, 'production'),
#  (23, 'major'),
#  (23, 'less'),
#  (23, 'company'),
#  (23, 'civilization'),
#  (22, 'want'),
#  (22, 'thing'),
#  (22, 'thanks'),
#  (22, 'something'),
#  (22, 'might'),
#  (22, 'may'),
#  (22, 'making'),
#  (22, 'important'),
#  (22, 'end'),
#  (22, 'cool'),
#  (22, 'another'),
#  (21, 'support'),
#  (21, 'software'),
#  (21, 'months'),
#  (21, 'media'),
#  (21, 'last'),
#  (21, 'falcon'),
#  (21, 'done'),
#  (21, 'ago'),
#  (21, 'accurate'),
#  (20, 'thread'),
#  (20, 'sigh'),
#  (20, 'rocket'),
#  (20, 'indeed'),
#  (20, 'coming'),
#  (20, 'case'),
#  (20, 'booster'),
#  (19, 'take'),
#  (19, 'soon'),
#  (19, 'rate'),
#  (19, 'please'),
#  (19, 'mars'),
#  (19, 'humanity'),
#  (19, 'going'),
#  (19, 'engines'),
#  (19, 'companies'),
#  (18, 'video'),
#  (18, 'users'),
#  (18, 'trying'),
#  (18, 'solar'),
#  (18, 'public'),
#  (18, 'little'),
#  (18, 'ever'),
#  (18, 'awesome'),
#  (18, 'away'),
#  (18, 'always'),
#  (18, 'already'),
#  (17, 'seems'),
#  (17, 'said'),
#  (17, 'progress'),
#  (17, 'news'),
#  (17, 'needs'),
#  (17, 'launch'),
#  (17, 'internet'),
#  (17, 'human'),
#  (17, 'goes'),
#  (17, 'given'),
#  (17, 'engine'),
#  (17, 'build'),
#  (16, 'today'),
#  (16, 'terminals'),
#  (16, 'speech'),
#  (16, 'small'),
#  (16, 'really'),
#  (16, 'problem'),
#  (16, 'note'),
#  (16, 'mass'),
#  (16, 'everyone'),
#  (16, 'america'),
#  (16, 'actual'),
#  (15, 'yet'),
#  (15, 'vote'),
#  (15, 'try'),
#  (15, 'tiny'),
#  (15, 'spam'),
#  (15, 'side'),
#  (15, 'service'),
#  (15, 'satellites'),
#  (15, 'nothing'),
#  (15, 'name'),
#  (15, 'must'),
#  (15, 'money'),
#  (15, 'kids'),
#  (15, 'government'),
#  (15, 'giga'),
#  (15, 'fake'),
#  (15, 'electric'),
#  (15, 'amazing'),
#  (14, 'worth'),
#  (14, 'without'),
#  (14, 'using'),
#  (14, 'traffic'),
#  (14, 'story'),
#  (14, 'space'),
#  (14, 'someone'),
#  (14, 'saying'),
#  (14, 'risk'),
#  (14, 'others'),
#  (14, 'night'),
#  (14, 'nice'),
#  (14, 'move'),
#  (14, 'least'),
#  (14, 'imo'),
#  (14, 'idea'),
#  (14, 'humans'),
#  (14, 'fast'),
#  (14, 'days'),
#  (14, 'current'),
#  (14, 'batteries'),
#  (13, 'two'),
#  (13, 'tomorrow'),
#  (13, 'system'),
#  (13, 'sustainable'),
#  (13, 'sounds'),
#  (13, 'single'),
#  (13, 'several'),
#  (13, 'quite'),
#  (13, 'potential'),
#  (13, 'population'),
#  (13, 'per'),
#  (13, 'obviously'),
#  (13, 'never'),
#  (13, 'model'),
#  (13, 'later'),
#  (13, 'issues'),
#  (13, 'insane'),
#  (13, 'hopefully'),
#  (13, 'full'),
#  (13, 'extremely'),
#  (13, 'especially'),
#  (13, 'die'),
#  (13, 'crimea'),
#  (13, 'cost'),
#  (13, 'campaign'),
#  (13, 'birth'),
#  (13, 'around'),
#  (13, 'area'),
#  (13, 'anyone'),
#  (13, 'active'),
#  (12, 'signal'),
#  (12, 'show'),
#  (12, 'seen'),
#  (12, 'put'),
#  (12, 'product'),
#  (12, 'mostly'),
#  (12, 'incredible'),
#  (12, 'getting'),
#  (12, 'definitely'),
#  (12, 'china'),
#  (12, 'bot'),
#  (12, 'board'),
#  (12, 'ask'),
#  (11, 'zero'),
#  (11, 'wrong'),
#  (11, 'total'),
#  (11, 'tax'),
#  (11, 'start'),
#  (11, 'social'),
#  (11, 'simply'),
#  (11, 'seem'),
#  (11, 'safety'),
#  (11, 'peace'),
#  (11, 'owners'),
#  (11, 'open'),
#  (11, 'often'),
#  (11, 'number'),
#  (11, 'lower'),
#  (11, 'level'),
#  (11, 'general'),
#  (11, 'game'),
#  (11, 'find'),
#  (11, 'entire'),
#  (11, 'enough'),
#  (11, 'difference'),
#  (11, 'death'),
#  (11, 'credit'),
#  (11, 'code'),
#  (11, 'close'),
#  (11, 'clear'),
#  (11, 'changes'),
#  (11, 'change'),
#  (11, 'anything'),
#  (10, 'wow'),
#  (10, 'version'),
#  (10, 'vehicle'),
#  (10, 'user'),
#  (10, 'unless'),
#  (10, 'tweets'),
#  (10, 'tweet'),
#  (10, 'texas'),
#  (10, 'test'),
#  (10, 'term'),
#  (10, 'sun'),
#  (10, 'starlinks'),
#  (10, 'standard'),
#  (10, 'source'),
#  (10, 'scam'),
#  (10, 'scale'),
#  (10, 'russian'),
#  (10, 'road'),
#  (10, 'ring'),
#  (10, 'rest'),
#  (10, 'price'),
#  (10, 'performance'),
#  (10, 'orbital'),
#  (10, 'old'),
#  (10, 'nuclear'),
#  (10, 'moving'),
#  (10, 'mean'),
#  (10, 'matter'),
#  (10, 'home'),
#  (10, 'higher'),
#  (10, 'heavy'),
#  (10, 'happy'),
#  (10, 'half'),
#  (10, 'goal'),
#  (10, 'fully'),
#  (10, 'forward'),
#  (10, 'engineering'),
#  (10, 'easy'),
#  (10, 'early'),
#  (10, 'driving'),
#  (10, 'directly'),
#  (10, 'crazy'),
#  (10, 'bigger'),
#  (10, 'agreed'),
#  (9, 'wonder'),
#  (9, 'wide'),
#  (9, 'whole'),
#  (9, 'wait'),
#  (9, 'used'),
#  (9, 'update'),
#  (9, 'tons'),
#  (9, 'testing'),
#  (9, 'strange'),
#  (9, 'smart'),
#  (9, 'serve'),
#  (9, 'sense'),
#  (9, 'reason'),
#  (9, 'read'),
#  (9, 'reach'),
#  (9, 'raptor'),
#  (9, 'products'),
#  (9, 'place'),
#  (9, 'perhaps'),
#  (9, 'pay'),
#  (9, 'optimus'),
#  (9, 'oil'),
#  (9, 'movie'),
#  (9, 'mind'),
#  (9, 'makes'),
#  (9, 'machine'),
#  (9, 'look'),
#  (9, 'literally'),
#  (9, 'list'),
#  (9, 'law'),
#  (9, 'improvements'),
#  (9, 'however'),
#  (9, 'hour'),
#  (9, 'hope'),
#  (9, 'help'),
#  (9, 'hear'),
#  (9, 'hate'),
#  (9, 'harder'),
#  (9, 'hair'),
#  (9, 'guess'),
#  (9, 'global'),
#  (9, 'flight'),
#  (9, 'esg'),
#  (9, 'due'),
#  (9, 'design'),
#  (9, 'deal'),
#  (9, 'data'),
#  (9, 'correct'),
#  (9, 'control'),
#  (9, 'consciousness'),
#  (9, 'congrats'),
#  (9, 'canada'),
#  (9, 'california'),
#  (9, 'bots'),
#  (9, 'boring'),
#  (9, 'bay'),
#  (9, 'basically'),
#  (9, 'art'),
#  (9, 'algorithm'),
#  (9, 'able'),
#  (8, 'welcome'),
#  (8, 'voted'),
#  (8, 'universe'),
#  (8, 'top'),
#  (8, 'thrust'),
#  (8, 'technology'),
#  (8, 'stop'),
#  (8, 'significant'),
#  (8, 'self'),
#  (8, 'random'),
#  (8, 'quality'),
#  (8, 'provide'),
#  (8, 'probability'),
#  (8, 'primary'),
#  (8, 'plan'),
#  (8, 'past'),
#  (8, 'paid'),
#  (8, 'offer'),
#  (8, 'negative'),
#  (8, 'multiplanetary'),
#  (8, 'massive'),
#  (8, 'man'),
#  (8, 'low'),
#  (8, 'lost'),
#  (8, 'losing'),
#  (8, 'looks'),
#  (8, 'looking'),
#  (8, 'keep'),
#  (8, 'improve'),
#  (8, 'highly'),
#  (8, 'hardware'),
#  (8, 'happening'),
#  (8, 'giving'),
#  (8, 'gets'),
#  (8, 'gas'),
#  (8, 'games'),
#  (8, 'funny'),
#  (8, 'friend'),
#  (8, 'experience'),
#  (8, 'elden'),
#  (8, 'drive'),
#  (8, 'different'),
#  (8, 'deep'),
#  (8, 'covid'),
#  (8, 'complex'),
#  (8, 'come'),
#  (8, 'city'),
#  (8, 'care'),
#  (8, 'buying'),
#  (8, 'book'),
#  (8, 'biggest'),
#  (8, 'berlin'),
#  (8, 'believe'),
#  (8, 'beautiful'),
#  (8, 'baby'),
#  (8, 'austin'),
#  (8, 'attacks'),
#  (8, 'age'),
#  (8, 'accounts'),
#  (7, 'wrote'),
#  (7, 'writing'),
#  (7, 'words'),
#  (7, 'word'),
#  (7, 'wild'),
#  (7, 'weeks'),
#  (7, 'water'),
#  (7, 'vehicles'),
#  (7, 'understand'),
#  (7, 'turn'),
#  (7, 'truth'),
#  (7, 'trump'),
#  (7, 'tough'),
#  (7, 'told'),
#  (7, 'though'),
#  (7, 'thank'),
#  (7, 'terminal'),
#  (7, 'tbh'),
#  (7, 'talked'),
#  (7, 'talented'),
#  (7, 'strong'),
#  (7, 'starbase'),
#  (7, 'south'),
#  (7, 'sometimes'),
#  (7, 'sold'),
#  (7, 'sock'),
#  (7, 'size'),
#  (7, 'sink'),
#  (7, 'sides'),
#  (7, 'shareholders'),
#  (7, 'share'),
#  (7, 'seriously'),
#  (7, 'send'),
#  (7, 'satellite'),
#  (7, 'run'),
#  (7, 'reusable'),
#  (7, 'republican'),
#  (7, 'releases'),
#  (7, 'ready'),
#  (7, 'rather'),
#  (7, 'rapidly'),
#  (7, 'range'),
#  (7, 'post'),
#  (7, 'political'),
#  (7, 'phone'),
#  (7, 'payload'),
#  (7, 'outcome'),
#  (7, 'otherwise'),
#  (7, 'original'),
#  (7, 'obvious'),
#  (7, 'obv'),
#  (7, 'nukes'),
#  (7, 'means'),
#  (7, 'matters'),
#  (7, 'live'),
#  (7, 'limited'),
#  (7, 'join'),
#  (7, 'jamming'),
#  (7, 'increase'),
#  (7, 'improvement'),
#  (7, 'impossible'),
#  (7, 'humor'),
#  (7, 'hit'),
#  (7, 'history'),
#  (7, 'happened'),
#  (7, 'ground'),
#  (7, 'got'),
#  (7, 'give'),
#  (7, 'gave'),
#  (7, 'fun'),
#  (7, 'friends'),
#  (7, 'feels'),
#  (7, 'faster'),
#  (7, 'fan'),
#  (7, 'false'),
#  (7, 'factory'),
#  (7, 'extreme'),
#  (7, 'everything'),
#  (7, 'else'),
#  (7, 'daily'),
#  (7, 'creating'),
#  (7, 'course'),
#  (7, 'countries'),
#  (7, 'count'),
#  (7, 'costs'),
#  (7, 'comments'),
#  (7, 'collapse'),
#  (7, 'class'),
#  (7, 'chance'),
#  (7, 'cause'),
#  (7, 'call'),
#  (7, 'buy'),
#  (7, 'burnt'),
#  (7, 'built'),
#  (7, 'building'),
#  (7, 'btw'),
#  (7, 'become'),
#  (7, 'based'),
#  (7, 'avoid'),
#  (7, 'available'),
#  (7, 'although'),
#  (7, 'airport'),
#  (7, 'account'),
#  (6, 'worse'),
#  (6, 'wish'),
#  (6, 'wing'),
#  (6, 'win'),
#  (6, 'whereas'),
#  (6, 'wanted'),
#  (6, 'view'),
#  (6, 'useful'),
#  (6, 'upgrades'),
#  (6, 'turns'),
#  (6, 'tunnels'),
#  (6, 'trust'),
#  (6, 'tried'),
#  (6, 'trend'),
#  (6, 'training'),
#  (6, 'towards'),
#  (6, 'tell'),
#  (6, 'talking'),
#  (6, 'talk'),
#  (6, 'stuff'),
#  (6, 'stock'),
#  (6, 'step'),
#  (6, 'starts'),
#  (6, 'started'),
#  (6, 'stack'),
#  (6, 'simple'),
#  (6, 'short'),
#  (6, 'sent'),
#  (6, 'semi'),
#  (6, 'security'),
#  (6, 'secret'),
#  (6, 'says'),
#  (6, 'saw'),
#  (6, 'running'),
#  (6, 'respect'),
#  (6, 'rare'),
#  (6, 'private'),
#  (6, 'priority'),
#  (6, 'plus'),
#  (6, 'play'),
#  (6, 'piece'),
#  (6, 'person'),
#  (6, 'percentage'),
#  (6, 'path'),
#  (6, 'passive'),
#  (6, 'pain'),
#  (6, 'pad'),
#  (6, 'outside'),
#  (6, 'north'),
#  (6, 'moon'),
#  (6, 'mobile'),
#  (6, 'metric'),
#  (6, 'merch'),
#  (6, 'meme'),
#  (6, 'maximum'),
#  (6, 'lose'),
#  (6, 'longer'),
#  (6, 'links'),
#  (6, 'line'),
#  (6, 'launches'),
#  (6, 'latter'),
#  (6, 'land'),
#  (6, 'kinda'),
#  (6, 'journalism'),
#  (6, 'jack'),
#  (6, 'irony'),
#  (6, 'interview'),
#  (6, 'individual'),
#  (6, 'including'),
#  (6, 'hours'),
#  (6, 'honor'),
#  (6, 'hoax'),
#  (6, 'hardcore'),
#  (6, 'growing'),
#  (6, 'grade'),
#  (6, 'gps'),
#  (6, 'gone'),
#  (6, 'generation'),
#  (6, 'funds'),
#  (6, 'fuel'),
#  (6, 'freedom'),
#  (6, 'fixed'),
#  (6, 'fire'),
#  (6, 'fine'),
#  (6, 'feel'),
#  (6, 'fair'),
#  (6, 'expand'),
#  (6, 'existing'),
#  (6, 'excited'),
#  (6, 'enable'),
#  (6, 'dragon'),
#  (6, 'dogecoin'),
#  (6, 'doge'),
#  (6, 'difficult'),
#  (6, 'demand'),
#  (6, 'defeat'),
#  (6, 'currently'),
#  (6, 'critical'),
#  (6, 'country'),
#  (6, 'computer'),
#  (6, 'combined'),
#  (6, 'claims'),
#  (6, 'choice'),
#  (6, 'challenge'),
#  (6, 'cell'),
#  (6, 'cautious'),
#  (6, 'beyond'),
#  (6, 'asked'),
#  (6, 'areas'),
#  (6, 'antenna'),
#  (6, 'amount'),
#  (6, 'american'),
#  (6, 'agree'),
#  (6, 'action'),
#  (5, 'yesterday'),
#  (5, 'wsj'),
#  (5, 'write'),
#  (5, 'works'),
#  (5, 'whether'),
#  (5, 'wall'),
#  (5, 'vision'),
#  (5, 'vegas'),
#  (5, 'usually'),
#  (5, 'uses'),
#  (5, 'usa'),
#  (5, 'upper'),
#  (5, 'unlikely'),
#  (5, 'unfortunately'),
#  (5, 'uaw'),
#  (5, 'twice'),
#  (5, 'trending'),
#  (5, 'tower'),
#  (5, 'took'),
#  (5, 'tonnage'),
#  (5, 'ton'),
#  (5, 'three'),
#  (5, 'teslas'),
#  (5, 'surface'),
#  (5, 'stay'),
#  (5, 'stars'),
#  (5, 'species'),
#  (5, 'sound'),
#  (5, 'solve'),
#  (5, 'situation'),
#  (5, 'similar'),
#  (5, 'sickkk'),
#  (5, 'shrouds'),
#  (5, 'serious'),
#  (5, 'seas'),
#  (5, 'sci'),
#  (5, 'rules'),
#  (5, 'roughly'),
#  (5, 'rolling'),
#  (5, 'rocks'),
#  (5, 'rockets'),
#  (5, 'rise'),
#  (5, 'requires'),
#  (5, 'require'),
#  (5, 'relentless'),
#  (5, 'reduce'),
#  (5, 'recommend'),
#  (5, 'receive'),
#  (5, 'reasons'),
#  (5, 'reasonable'),
#  (5, 'reality'),
#  (5, 'reading'),
#  (5, 'rates'),
#  (5, 'protection'),
#  (5, 'pro'),
#  (5, 'prices'),
#  (5, 'pressure'),
#  (5, 'plane'),
#  (5, 'pick'),
#  (5, 'parties'),
#  (5, 'particular'),
#  (5, 'output'),
#  (5, 'orders'),
#  (5, 'order'),
#  (5, 'odd'),
#  (5, 'non'),
#  (5, 'neuralink'),
#  (5, 'near'),
#  (5, 'navigate'),
#  (5, 'national'),
#  (5, 'millions'),
#  (5, 'middle'),
#  (5, 'meant'),
#  (5, 'lots'),
#  (5, 'lithium'),
#  (5, 'laser'),
#  (5, 'landing'),
#  (5, 'known'),
#  (5, 'kid'),
#  (5, 'iron'),
#  (5, 'investment'),
#  (5, 'internal'),
#  (5, 'insurance'),
#  (5, 'inflation'),
#  (5, 'inference'),
#  (5, 'industry'),
#  (5, 'included'),
#  (5, 'incentives'),
#  (5, 'ideas'),
#  (5, 'house'),
#  (5, 'highest'),
#  (5, 'heard'),
#  (5, 'hardest'),
#  (5, 'happens'),
#  (5, 'handle'),
#  (5, 'hand'),
#  (5, 'govt'),
#  (5, 'giant'),
#  (5, 'generate'),
#  (5, 'gasoline'),
#  (5, 'funding'),
#  (5, 'fremont'),
#  (5, 'followers'),
#  (5, 'flying'),
#  (5, 'fight'),
#  (5, 'fate'),
#  (5, 'fact'),
#  (5, 'excellent'),
#  (5, 'example'),
#  (5, 'engineers'),
#  (5, 'efficiency'),
#  (5, 'eat'),
#  (5, 'dramatically'),
#  (5, 'double'),
#  (5, 'dod'),
#  (5, 'das'),
#  (5, 'cybertruck'),
#  (5, 'criticism'),
#  (5, 'crew'),
#  (5, 'created'),
#  (5, 'convinced'),
#  (5, 'controls'),
#  (5, 'connector'),
#  (5, 'connectivity'),
#  (5, 'congratulations'),
#  (5, 'concerning'),
#  (5, 'compute'),
#  (5, 'compared'),
#  (5, 'communications'),
#  (5, 'clinton'),
#  (5, 'citizen'),
#  (5, 'cheese'),
#  (5, 'ceo'),
#  (5, 'cannot'),
#  (5, 'candidates'),
#  (5, 'candidate'),
#  (5, 'called'),
#  (5, 'bring'),
#  (5, 'bright'),
#  (5, 'boss'),
#  (5, 'body'),
#  (5, 'biden'),
#  (5, 'battery'),
#  (5, 'autopilot'),
#  (5, 'auto'),
#  (5, 'attack'),
#  (5, 'article'),
#  (5, 'appreciated'),
#  (5, 'ancient'),
#  (5, 'alive'),
#  (5, 'air'),
#  (5, 'aiming'),
#  (5, 'advantage'),
#  (5, 'advanced'),
#  (5, 'acquisition'),
#  (4, 'youtube'),
#  (4, 'workers'),
#  (4, 'woke'),
#  (4, 'within'),
#  (4, 'wind'),
#  (4, 'wider'),
#  (4, 'went'),
#  (4, 'weird'),
#  (4, 'weapons'),
#  (4, 'warming'),
#  (4, 'wapo'),
#  (4, 'voting'),
#  (4, 'volume'),
#  (4, 'virus'),
#  (4, 'via'),
#  (4, 'velocity'),
#  (4, 'vast'),
#  (4, 'utterly'),
#  (4, 'upgrade'),
#  (4, 'united'),
#  (4, 'troubling'),
#  (4, 'trillion'),
#  (4, 'trends'),
#  (4, 'tree'),
#  (4, 'tracking'),
#  (4, 'thousand'),
#  (4, 'thought'),
#  (4, 'third'),
#  (4, 'thinking'),
#  (4, 'technically'),
#  (4, 'tech'),
#  (4, 'tap'),
#  (4, 'taking'),
#  (4, 'takes'),
#  (4, 'switch'),
#  (4, 'surprised'),
#  (4, 'supported'),
#  (4, 'supply'),
#  (4, 'summary'),
#  (4, 'suicide'),
#  (4, 'successful'),
#  (4, 'subtle'),
#  (4, 'students'),
#  (4, 'strongly'),
#  (4, 'stories'),
#  (4, 'stopped'),
#  (4, 'stations'),
#  (4, 'station'),
#  (4, 'static'),
#  (4, 'speeds'),
#  (4, 'sjm'),
#  (4, 'simulation'),
#  (4, 'silly'),
#  (4, 'significantly'),
#  (4, 'ship'),
#  (4, 'shift'),
#  (4, 'set'),
#  (4, 'services'),
#  (4, 'seeking'),
#  (4, 'seek'),
#  (4, 'second'),
#  (4, 'score'),
#  (4, 'science'),
#  (4, 'schools'),
#  (4, 'school'),
#  (4, 'saxon'),
#  (4, 'safe'),
#  (4, 'row'),
#  (4, 'resources'),
#  (4, 'required'),
#  (4, 'reliability'),
#  (4, 'region'),
#  (4, 'refused'),
#  (4, 'reduces'),
#  (4, 'red'),
#  (4, 'record'),
#  (4, 'recent'),
#  (4, 'realize'),
#  (4, 'rarely'),
#  (4, 'quarter'),
#  (4, 'provided'),
#  (4, 'protect'),
#  (4, 'prominent'),
#  (4, 'process'),
#  (4, 'problems'),
#  (4, 'president'),
#  (4, 'present'),
#  (4, 'powerwall'),
#  (4, 'powered'),
#  (4, 'popular'),
#  (4, 'policies'),
#  (4, 'planet'),
#  (4, 'pieces'),
#  (4, 'philosophy'),
#  (4, 'participants'),
#  (4, 'paper'),
#  (4, 'paint'),
#  (4, 'pack'),
#  (4, 'operation'),
#  (4, 'office'),
#  (4, 'november'),
#  (4, 'none'),
#  (4, 'neuralinks'),
#  (4, 'nature'),
#  (4, 'mode'),
#  (4, 'mistake'),
#  (4, 'mirrors'),
#  (4, 'mins'),
#  (4, 'mine'),
#  (4, 'miles'),
#  (4, 'mile'),
#  (4, 'mention'),
#  (4, 'memes'),
#  (4, 'meet'),
#  (4, 'market'),
#  (4, 'mark'),
#  (4, 'map'),
#  (4, 'managers'),
#  (4, 'majority'),
#  (4, 'main'),
#  (4, 'magnitude'),
#  (4, 'magic'),
#  (4, 'local'),
#  (4, 'lines'),
#  (4, 'likely'),
#  (4, 'light'),
#  (4, 'legal'),
#  (4, 'layers'),
#  (4, 'laugh'),
#  (4, 'late'),
#  (4, 'large'),
#  (4, 'knows'),
#  (4, 'key'),
#  (4, 'japan'),
#  (4, 'james'),
#  (4, 'issue'),
#  (4, 'ironically'),
#  (4, 'irl'),
#  (4, 'interests'),
#  (4, 'integrity'),
#  (4, 'instagram'),
#  (4, 'insanely'),
#  (4, 'index'),
#  (4, 'incremental'),
#  (4, 'improved'),
#  (4, 'impact'),
#  (4, 'hyperloop'),
#  (4, 'hold'),
#  (4, 'highway'),
#  (4, 'helpful'),
#  (4, 'heat'),
#  (4, 'heart'),
#  (4, 'head'),
#  (4, 'hat'),
#  (4, 'happen'),
#  (4, 'guy'),
#  (4, 'gun'),
#  (4, 'greatly'),
#  (4, 'glad'),
#  (4, 'gen'),
#  (4, 'fundamental'),
#  (4, 'ftw'),
#  (4, 'former'),
#  (4, 'form'),
#  (4, 'fools'),
#  (4, 'flights'),
#  (4, 'fix'),
#  (4, 'firms'),
#  (4, 'fewer'),
#  (4, 'fear'),
#  (4, 'fbi'),
#  (4, 'favorite'),
#  (4, 'fasting'),
#  (4, 'fantasy'),
#  (4, 'expectancy'),
#  (4, 'expanding'),
#  (4, 'exist'),
#  (4, 'exciting'),
#  (4, 'exception'),
#  ...]

# %%
len(corpus)
# Out:
# 5680

# %% [markdown]
# ### Stemming

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('omw-1.4')
lem = WordNetLemmatizer()

corpus = [(lem.lemmatize(word[1]),word[0]) for word in corpus]
corpus
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\javie\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [('http', 400),
#  ('amp', 282),
#  ('tesla', 153),
#  ('would', 103),
#  ('good', 102),
#  ('twitter', 100),
#  ('people', 100),
#  ('yes', 83),
#  ('much', 81),
#  ('starlink', 80),
#  ('one', 76),
#  ('true', 75),
#  ('many', 69),
#  ('like', 68),
#  ('even', 67),
#  ('great', 66),
#  ('time', 62),
#  ('also', 61),
#  ('yeah', 55),
#  ('exactly', 55),
#  ('spacex', 52),
#  ('next', 52),
#  ('make', 52),
#  ('year', 51),
#  ('think', 51),
#  ('still', 50),
#  ('haha', 50),
#  ('maybe', 49),
#  ('high', 48),
#  ('probably', 45),
#  ('team', 44),
#  ('year', 43),
#  ('work', 43),
#  ('far', 43),
#  ('earth', 42),
#  ('right', 41),
#  ('car', 41),
#  ('lot', 40),
#  ('day', 40),
#  ('way', 38),
#  ('russia', 38),
#  ('real', 38),
#  ('life', 38),
#  ('better', 38),
#  ('world', 37),
#  ('ukraine', 35),
#  ('get', 34),
#  ('beta', 34),
#  ('actually', 34),
#  ('time', 33),
#  ('long', 33),
#  ('orbit', 32),
#  ('future', 32),
#  ('working', 31),
#  ('first', 31),
#  ('best', 31),
#  ('need', 30),
#  ('know', 30),
#  ('big', 30),
#  ('almost', 30),
#  ('ok', 29),
#  ('hard', 29),
#  ('fsd', 29),
#  ('yup', 28),
#  ('well', 28),
#  ('starship', 28),
#  ('see', 28),
#  ('new', 28),
#  ('release', 27),
#  ('pretty', 27),
#  ('party', 27),
#  ('made', 27),
#  ('interesting', 27),
#  ('car', 27),
#  ('week', 26),
#  ('question', 26),
#  ('possible', 26),
#  ('needed', 26),
#  ('every', 26),
#  ('could', 26),
#  ('bad', 26),
#  ('back', 26),
#  ('war', 25),
#  ('say', 25),
#  ('point', 25),
#  ('love', 25),
#  ('left', 25),
#  ('free', 25),
#  ('energy', 25),
#  ('use', 24),
#  ('power', 24),
#  ('part', 24),
#  ('month', 24),
#  ('let', 24),
#  ('absolutely', 24),
#  ('thing', 23),
#  ('sure', 23),
#  ('super', 23),
#  ('since', 23),
#  ('production', 23),
#  ('major', 23),
#  ('le', 23),
#  ('company', 23),
#  ('civilization', 23),
#  ('want', 22),
#  ('thing', 22),
#  ('thanks', 22),
#  ('something', 22),
#  ('might', 22),
#  ('may', 22),
#  ('making', 22),
#  ('important', 22),
#  ('end', 22),
#  ('cool', 22),
#  ('another', 22),
#  ('support', 21),
#  ('software', 21),
#  ('month', 21),
#  ('medium', 21),
#  ('last', 21),
#  ('falcon', 21),
#  ('done', 21),
#  ('ago', 21),
#  ('accurate', 21),
#  ('thread', 20),
#  ('sigh', 20),
#  ('rocket', 20),
#  ('indeed', 20),
#  ('coming', 20),
#  ('case', 20),
#  ('booster', 20),
#  ('take', 19),
#  ('soon', 19),
#  ('rate', 19),
#  ('please', 19),
#  ('mar', 19),
#  ('humanity', 19),
#  ('going', 19),
#  ('engine', 19),
#  ('company', 19),
#  ('video', 18),
#  ('user', 18),
#  ('trying', 18),
#  ('solar', 18),
#  ('public', 18),
#  ('little', 18),
#  ('ever', 18),
#  ('awesome', 18),
#  ('away', 18),
#  ('always', 18),
#  ('already', 18),
#  ('seems', 17),
#  ('said', 17),
#  ('progress', 17),
#  ('news', 17),
#  ('need', 17),
#  ('launch', 17),
#  ('internet', 17),
#  ('human', 17),
#  ('go', 17),
#  ('given', 17),
#  ('engine', 17),
#  ('build', 17),
#  ('today', 16),
#  ('terminal', 16),
#  ('speech', 16),
#  ('small', 16),
#  ('really', 16),
#  ('problem', 16),
#  ('note', 16),
#  ('mass', 16),
#  ('everyone', 16),
#  ('america', 16),
#  ('actual', 16),
#  ('yet', 15),
#  ('vote', 15),
#  ('try', 15),
#  ('tiny', 15),
#  ('spam', 15),
#  ('side', 15),
#  ('service', 15),
#  ('satellite', 15),
#  ('nothing', 15),
#  ('name', 15),
#  ('must', 15),
#  ('money', 15),
#  ('kid', 15),
#  ('government', 15),
#  ('giga', 15),
#  ('fake', 15),
#  ('electric', 15),
#  ('amazing', 15),
#  ('worth', 14),
#  ('without', 14),
#  ('using', 14),
#  ('traffic', 14),
#  ('story', 14),
#  ('space', 14),
#  ('someone', 14),
#  ('saying', 14),
#  ('risk', 14),
#  ('others', 14),
#  ('night', 14),
#  ('nice', 14),
#  ('move', 14),
#  ('least', 14),
#  ('imo', 14),
#  ('idea', 14),
#  ('human', 14),
#  ('fast', 14),
#  ('day', 14),
#  ('current', 14),
#  ('battery', 14),
#  ('two', 13),
#  ('tomorrow', 13),
#  ('system', 13),
#  ('sustainable', 13),
#  ('sound', 13),
#  ('single', 13),
#  ('several', 13),
#  ('quite', 13),
#  ('potential', 13),
#  ('population', 13),
#  ('per', 13),
#  ('obviously', 13),
#  ('never', 13),
#  ('model', 13),
#  ('later', 13),
#  ('issue', 13),
#  ('insane', 13),
#  ('hopefully', 13),
#  ('full', 13),
#  ('extremely', 13),
#  ('especially', 13),
#  ('die', 13),
#  ('crimea', 13),
#  ('cost', 13),
#  ('campaign', 13),
#  ('birth', 13),
#  ('around', 13),
#  ('area', 13),
#  ('anyone', 13),
#  ('active', 13),
#  ('signal', 12),
#  ('show', 12),
#  ('seen', 12),
#  ('put', 12),
#  ('product', 12),
#  ('mostly', 12),
#  ('incredible', 12),
#  ('getting', 12),
#  ('definitely', 12),
#  ('china', 12),
#  ('bot', 12),
#  ('board', 12),
#  ('ask', 12),
#  ('zero', 11),
#  ('wrong', 11),
#  ('total', 11),
#  ('tax', 11),
#  ('start', 11),
#  ('social', 11),
#  ('simply', 11),
#  ('seem', 11),
#  ('safety', 11),
#  ('peace', 11),
#  ('owner', 11),
#  ('open', 11),
#  ('often', 11),
#  ('number', 11),
#  ('lower', 11),
#  ('level', 11),
#  ('general', 11),
#  ('game', 11),
#  ('find', 11),
#  ('entire', 11),
#  ('enough', 11),
#  ('difference', 11),
#  ('death', 11),
#  ('credit', 11),
#  ('code', 11),
#  ('close', 11),
#  ('clear', 11),
#  ('change', 11),
#  ('change', 11),
#  ('anything', 11),
#  ('wow', 10),
#  ('version', 10),
#  ('vehicle', 10),
#  ('user', 10),
#  ('unless', 10),
#  ('tweet', 10),
#  ('tweet', 10),
#  ('texas', 10),
#  ('test', 10),
#  ('term', 10),
#  ('sun', 10),
#  ('starlinks', 10),
#  ('standard', 10),
#  ('source', 10),
#  ('scam', 10),
#  ('scale', 10),
#  ('russian', 10),
#  ('road', 10),
#  ('ring', 10),
#  ('rest', 10),
#  ('price', 10),
#  ('performance', 10),
#  ('orbital', 10),
#  ('old', 10),
#  ('nuclear', 10),
#  ('moving', 10),
#  ('mean', 10),
#  ('matter', 10),
#  ('home', 10),
#  ('higher', 10),
#  ('heavy', 10),
#  ('happy', 10),
#  ('half', 10),
#  ('goal', 10),
#  ('fully', 10),
#  ('forward', 10),
#  ('engineering', 10),
#  ('easy', 10),
#  ('early', 10),
#  ('driving', 10),
#  ('directly', 10),
#  ('crazy', 10),
#  ('bigger', 10),
#  ('agreed', 10),
#  ('wonder', 9),
#  ('wide', 9),
#  ('whole', 9),
#  ('wait', 9),
#  ('used', 9),
#  ('update', 9),
#  ('ton', 9),
#  ('testing', 9),
#  ('strange', 9),
#  ('smart', 9),
#  ('serve', 9),
#  ('sense', 9),
#  ('reason', 9),
#  ('read', 9),
#  ('reach', 9),
#  ('raptor', 9),
#  ('product', 9),
#  ('place', 9),
#  ('perhaps', 9),
#  ('pay', 9),
#  ('optimus', 9),
#  ('oil', 9),
#  ('movie', 9),
#  ('mind', 9),
#  ('make', 9),
#  ('machine', 9),
#  ('look', 9),
#  ('literally', 9),
#  ('list', 9),
#  ('law', 9),
#  ('improvement', 9),
#  ('however', 9),
#  ('hour', 9),
#  ('hope', 9),
#  ('help', 9),
#  ('hear', 9),
#  ('hate', 9),
#  ('harder', 9),
#  ('hair', 9),
#  ('guess', 9),
#  ('global', 9),
#  ('flight', 9),
#  ('esg', 9),
#  ('due', 9),
#  ('design', 9),
#  ('deal', 9),
#  ('data', 9),
#  ('correct', 9),
#  ('control', 9),
#  ('consciousness', 9),
#  ('congrats', 9),
#  ('canada', 9),
#  ('california', 9),
#  ('bot', 9),
#  ('boring', 9),
#  ('bay', 9),
#  ('basically', 9),
#  ('art', 9),
#  ('algorithm', 9),
#  ('able', 9),
#  ('welcome', 8),
#  ('voted', 8),
#  ('universe', 8),
#  ('top', 8),
#  ('thrust', 8),
#  ('technology', 8),
#  ('stop', 8),
#  ('significant', 8),
#  ('self', 8),
#  ('random', 8),
#  ('quality', 8),
#  ('provide', 8),
#  ('probability', 8),
#  ('primary', 8),
#  ('plan', 8),
#  ('past', 8),
#  ('paid', 8),
#  ('offer', 8),
#  ('negative', 8),
#  ('multiplanetary', 8),
#  ('massive', 8),
#  ('man', 8),
#  ('low', 8),
#  ('lost', 8),
#  ('losing', 8),
#  ('look', 8),
#  ('looking', 8),
#  ('keep', 8),
#  ('improve', 8),
#  ('highly', 8),
#  ('hardware', 8),
#  ('happening', 8),
#  ('giving', 8),
#  ('get', 8),
#  ('gas', 8),
#  ('game', 8),
#  ('funny', 8),
#  ('friend', 8),
#  ('experience', 8),
#  ('elden', 8),
#  ('drive', 8),
#  ('different', 8),
#  ('deep', 8),
#  ('covid', 8),
#  ('complex', 8),
#  ('come', 8),
#  ('city', 8),
#  ('care', 8),
#  ('buying', 8),
#  ('book', 8),
#  ('biggest', 8),
#  ('berlin', 8),
#  ('believe', 8),
#  ('beautiful', 8),
#  ('baby', 8),
#  ('austin', 8),
#  ('attack', 8),
#  ('age', 8),
#  ('account', 8),
#  ('wrote', 7),
#  ('writing', 7),
#  ('word', 7),
#  ('word', 7),
#  ('wild', 7),
#  ('week', 7),
#  ('water', 7),
#  ('vehicle', 7),
#  ('understand', 7),
#  ('turn', 7),
#  ('truth', 7),
#  ('trump', 7),
#  ('tough', 7),
#  ('told', 7),
#  ('though', 7),
#  ('thank', 7),
#  ('terminal', 7),
#  ('tbh', 7),
#  ('talked', 7),
#  ('talented', 7),
#  ('strong', 7),
#  ('starbase', 7),
#  ('south', 7),
#  ('sometimes', 7),
#  ('sold', 7),
#  ('sock', 7),
#  ('size', 7),
#  ('sink', 7),
#  ('side', 7),
#  ('shareholder', 7),
#  ('share', 7),
#  ('seriously', 7),
#  ('send', 7),
#  ('satellite', 7),
#  ('run', 7),
#  ('reusable', 7),
#  ('republican', 7),
#  ('release', 7),
#  ('ready', 7),
#  ('rather', 7),
#  ('rapidly', 7),
#  ('range', 7),
#  ('post', 7),
#  ('political', 7),
#  ('phone', 7),
#  ('payload', 7),
#  ('outcome', 7),
#  ('otherwise', 7),
#  ('original', 7),
#  ('obvious', 7),
#  ('obv', 7),
#  ('nuke', 7),
#  ('mean', 7),
#  ('matter', 7),
#  ('live', 7),
#  ('limited', 7),
#  ('join', 7),
#  ('jamming', 7),
#  ('increase', 7),
#  ('improvement', 7),
#  ('impossible', 7),
#  ('humor', 7),
#  ('hit', 7),
#  ('history', 7),
#  ('happened', 7),
#  ('ground', 7),
#  ('got', 7),
#  ('give', 7),
#  ('gave', 7),
#  ('fun', 7),
#  ('friend', 7),
#  ('feel', 7),
#  ('faster', 7),
#  ('fan', 7),
#  ('false', 7),
#  ('factory', 7),
#  ('extreme', 7),
#  ('everything', 7),
#  ('else', 7),
#  ('daily', 7),
#  ('creating', 7),
#  ('course', 7),
#  ('country', 7),
#  ('count', 7),
#  ('cost', 7),
#  ('comment', 7),
#  ('collapse', 7),
#  ('class', 7),
#  ('chance', 7),
#  ('cause', 7),
#  ('call', 7),
#  ('buy', 7),
#  ('burnt', 7),
#  ('built', 7),
#  ('building', 7),
#  ('btw', 7),
#  ('become', 7),
#  ('based', 7),
#  ('avoid', 7),
#  ('available', 7),
#  ('although', 7),
#  ('airport', 7),
#  ('account', 7),
#  ('worse', 6),
#  ('wish', 6),
#  ('wing', 6),
#  ('win', 6),
#  ('whereas', 6),
#  ('wanted', 6),
#  ('view', 6),
#  ('useful', 6),
#  ('upgrade', 6),
#  ('turn', 6),
#  ('tunnel', 6),
#  ('trust', 6),
#  ('tried', 6),
#  ('trend', 6),
#  ('training', 6),
#  ('towards', 6),
#  ('tell', 6),
#  ('talking', 6),
#  ('talk', 6),
#  ('stuff', 6),
#  ('stock', 6),
#  ('step', 6),
#  ('start', 6),
#  ('started', 6),
#  ('stack', 6),
#  ('simple', 6),
#  ('short', 6),
#  ('sent', 6),
#  ('semi', 6),
#  ('security', 6),
#  ('secret', 6),
#  ('say', 6),
#  ('saw', 6),
#  ('running', 6),
#  ('respect', 6),
#  ('rare', 6),
#  ('private', 6),
#  ('priority', 6),
#  ('plus', 6),
#  ('play', 6),
#  ('piece', 6),
#  ('person', 6),
#  ('percentage', 6),
#  ('path', 6),
#  ('passive', 6),
#  ('pain', 6),
#  ('pad', 6),
#  ('outside', 6),
#  ('north', 6),
#  ('moon', 6),
#  ('mobile', 6),
#  ('metric', 6),
#  ('merch', 6),
#  ('meme', 6),
#  ('maximum', 6),
#  ('lose', 6),
#  ('longer', 6),
#  ('link', 6),
#  ('line', 6),
#  ('launch', 6),
#  ('latter', 6),
#  ('land', 6),
#  ('kinda', 6),
#  ('journalism', 6),
#  ('jack', 6),
#  ('irony', 6),
#  ('interview', 6),
#  ('individual', 6),
#  ('including', 6),
#  ('hour', 6),
#  ('honor', 6),
#  ('hoax', 6),
#  ('hardcore', 6),
#  ('growing', 6),
#  ('grade', 6),
#  ('gps', 6),
#  ('gone', 6),
#  ('generation', 6),
#  ('fund', 6),
#  ('fuel', 6),
#  ('freedom', 6),
#  ('fixed', 6),
#  ('fire', 6),
#  ('fine', 6),
#  ('feel', 6),
#  ('fair', 6),
#  ('expand', 6),
#  ('existing', 6),
#  ('excited', 6),
#  ('enable', 6),
#  ('dragon', 6),
#  ('dogecoin', 6),
#  ('doge', 6),
#  ('difficult', 6),
#  ('demand', 6),
#  ('defeat', 6),
#  ('currently', 6),
#  ('critical', 6),
#  ('country', 6),
#  ('computer', 6),
#  ('combined', 6),
#  ('claim', 6),
#  ('choice', 6),
#  ('challenge', 6),
#  ('cell', 6),
#  ('cautious', 6),
#  ('beyond', 6),
#  ('asked', 6),
#  ('area', 6),
#  ('antenna', 6),
#  ('amount', 6),
#  ('american', 6),
#  ('agree', 6),
#  ('action', 6),
#  ('yesterday', 5),
#  ('wsj', 5),
#  ('write', 5),
#  ('work', 5),
#  ('whether', 5),
#  ('wall', 5),
#  ('vision', 5),
#  ('vega', 5),
#  ('usually', 5),
#  ('us', 5),
#  ('usa', 5),
#  ('upper', 5),
#  ('unlikely', 5),
#  ('unfortunately', 5),
#  ('uaw', 5),
#  ('twice', 5),
#  ('trending', 5),
#  ('tower', 5),
#  ('took', 5),
#  ('tonnage', 5),
#  ('ton', 5),
#  ('three', 5),
#  ('tesla', 5),
#  ('surface', 5),
#  ('stay', 5),
#  ('star', 5),
#  ('specie', 5),
#  ('sound', 5),
#  ('solve', 5),
#  ('situation', 5),
#  ('similar', 5),
#  ('sickkk', 5),
#  ('shroud', 5),
#  ('serious', 5),
#  ('sea', 5),
#  ('sci', 5),
#  ('rule', 5),
#  ('roughly', 5),
#  ('rolling', 5),
#  ('rock', 5),
#  ('rocket', 5),
#  ('rise', 5),
#  ('requires', 5),
#  ('require', 5),
#  ('relentless', 5),
#  ('reduce', 5),
#  ('recommend', 5),
#  ('receive', 5),
#  ('reason', 5),
#  ('reasonable', 5),
#  ('reality', 5),
#  ('reading', 5),
#  ('rate', 5),
#  ('protection', 5),
#  ('pro', 5),
#  ('price', 5),
#  ('pressure', 5),
#  ('plane', 5),
#  ('pick', 5),
#  ('party', 5),
#  ('particular', 5),
#  ('output', 5),
#  ('order', 5),
#  ('order', 5),
#  ('odd', 5),
#  ('non', 5),
#  ('neuralink', 5),
#  ('near', 5),
#  ('navigate', 5),
#  ('national', 5),
#  ('million', 5),
#  ('middle', 5),
#  ('meant', 5),
#  ('lot', 5),
#  ('lithium', 5),
#  ('laser', 5),
#  ('landing', 5),
#  ('known', 5),
#  ('kid', 5),
#  ('iron', 5),
#  ('investment', 5),
#  ('internal', 5),
#  ('insurance', 5),
#  ('inflation', 5),
#  ('inference', 5),
#  ('industry', 5),
#  ('included', 5),
#  ('incentive', 5),
#  ('idea', 5),
#  ('house', 5),
#  ('highest', 5),
#  ('heard', 5),
#  ('hardest', 5),
#  ('happens', 5),
#  ('handle', 5),
#  ('hand', 5),
#  ('govt', 5),
#  ('giant', 5),
#  ('generate', 5),
#  ('gasoline', 5),
#  ('funding', 5),
#  ('fremont', 5),
#  ('follower', 5),
#  ('flying', 5),
#  ('fight', 5),
#  ('fate', 5),
#  ('fact', 5),
#  ('excellent', 5),
#  ('example', 5),
#  ('engineer', 5),
#  ('efficiency', 5),
#  ('eat', 5),
#  ('dramatically', 5),
#  ('double', 5),
#  ('dod', 5),
#  ('da', 5),
#  ('cybertruck', 5),
#  ('criticism', 5),
#  ('crew', 5),
#  ('created', 5),
#  ('convinced', 5),
#  ('control', 5),
#  ('connector', 5),
#  ('connectivity', 5),
#  ('congratulation', 5),
#  ('concerning', 5),
#  ('compute', 5),
#  ('compared', 5),
#  ('communication', 5),
#  ('clinton', 5),
#  ('citizen', 5),
#  ('cheese', 5),
#  ('ceo', 5),
#  ('cannot', 5),
#  ('candidate', 5),
#  ('candidate', 5),
#  ('called', 5),
#  ('bring', 5),
#  ('bright', 5),
#  ('bos', 5),
#  ('body', 5),
#  ('biden', 5),
#  ('battery', 5),
#  ('autopilot', 5),
#  ('auto', 5),
#  ('attack', 5),
#  ('article', 5),
#  ('appreciated', 5),
#  ('ancient', 5),
#  ('alive', 5),
#  ('air', 5),
#  ('aiming', 5),
#  ('advantage', 5),
#  ('advanced', 5),
#  ('acquisition', 5),
#  ('youtube', 4),
#  ('worker', 4),
#  ('woke', 4),
#  ('within', 4),
#  ('wind', 4),
#  ('wider', 4),
#  ('went', 4),
#  ('weird', 4),
#  ('weapon', 4),
#  ('warming', 4),
#  ('wapo', 4),
#  ('voting', 4),
#  ('volume', 4),
#  ('virus', 4),
#  ('via', 4),
#  ('velocity', 4),
#  ('vast', 4),
#  ('utterly', 4),
#  ('upgrade', 4),
#  ('united', 4),
#  ('troubling', 4),
#  ('trillion', 4),
#  ('trend', 4),
#  ('tree', 4),
#  ('tracking', 4),
#  ('thousand', 4),
#  ('thought', 4),
#  ('third', 4),
#  ('thinking', 4),
#  ('technically', 4),
#  ('tech', 4),
#  ('tap', 4),
#  ('taking', 4),
#  ('take', 4),
#  ('switch', 4),
#  ('surprised', 4),
#  ('supported', 4),
#  ('supply', 4),
#  ('summary', 4),
#  ('suicide', 4),
#  ('successful', 4),
#  ('subtle', 4),
#  ('student', 4),
#  ('strongly', 4),
#  ('story', 4),
#  ('stopped', 4),
#  ('station', 4),
#  ('station', 4),
#  ('static', 4),
#  ('speed', 4),
#  ('sjm', 4),
#  ('simulation', 4),
#  ('silly', 4),
#  ('significantly', 4),
#  ('ship', 4),
#  ('shift', 4),
#  ('set', 4),
#  ('service', 4),
#  ('seeking', 4),
#  ('seek', 4),
#  ('second', 4),
#  ('score', 4),
#  ('science', 4),
#  ('school', 4),
#  ('school', 4),
#  ('saxon', 4),
#  ('safe', 4),
#  ('row', 4),
#  ('resource', 4),
#  ('required', 4),
#  ('reliability', 4),
#  ('region', 4),
#  ('refused', 4),
#  ('reduces', 4),
#  ('red', 4),
#  ('record', 4),
#  ('recent', 4),
#  ('realize', 4),
#  ('rarely', 4),
#  ('quarter', 4),
#  ('provided', 4),
#  ('protect', 4),
#  ('prominent', 4),
#  ('process', 4),
#  ('problem', 4),
#  ('president', 4),
#  ('present', 4),
#  ('powerwall', 4),
#  ('powered', 4),
#  ('popular', 4),
#  ('policy', 4),
#  ('planet', 4),
#  ('piece', 4),
#  ('philosophy', 4),
#  ('participant', 4),
#  ('paper', 4),
#  ('paint', 4),
#  ('pack', 4),
#  ('operation', 4),
#  ('office', 4),
#  ('november', 4),
#  ('none', 4),
#  ('neuralinks', 4),
#  ('nature', 4),
#  ('mode', 4),
#  ('mistake', 4),
#  ('mirror', 4),
#  ('min', 4),
#  ('mine', 4),
#  ('mile', 4),
#  ('mile', 4),
#  ('mention', 4),
#  ('meme', 4),
#  ('meet', 4),
#  ('market', 4),
#  ('mark', 4),
#  ('map', 4),
#  ('manager', 4),
#  ('majority', 4),
#  ('main', 4),
#  ('magnitude', 4),
#  ('magic', 4),
#  ('local', 4),
#  ('line', 4),
#  ('likely', 4),
#  ('light', 4),
#  ('legal', 4),
#  ('layer', 4),
#  ('laugh', 4),
#  ('late', 4),
#  ('large', 4),
#  ('know', 4),
#  ('key', 4),
#  ('japan', 4),
#  ('james', 4),
#  ('issue', 4),
#  ('ironically', 4),
#  ('irl', 4),
#  ('interest', 4),
#  ('integrity', 4),
#  ('instagram', 4),
#  ('insanely', 4),
#  ('index', 4),
#  ('incremental', 4),
#  ('improved', 4),
#  ('impact', 4),
#  ('hyperloop', 4),
#  ('hold', 4),
#  ('highway', 4),
#  ('helpful', 4),
#  ('heat', 4),
#  ('heart', 4),
#  ('head', 4),
#  ('hat', 4),
#  ('happen', 4),
#  ('guy', 4),
#  ('gun', 4),
#  ('greatly', 4),
#  ('glad', 4),
#  ('gen', 4),
#  ('fundamental', 4),
#  ('ftw', 4),
#  ('former', 4),
#  ('form', 4),
#  ('fool', 4),
#  ('flight', 4),
#  ('fix', 4),
#  ('firm', 4),
#  ('fewer', 4),
#  ('fear', 4),
#  ('fbi', 4),
#  ('favorite', 4),
#  ('fasting', 4),
#  ('fantasy', 4),
#  ('expectancy', 4),
#  ('expanding', 4),
#  ('exist', 4),
#  ('exciting', 4),
#  ('exception', 4),
#  ...]

# %%
len(corpus)
# Out:
# 5680

# %%
type(corpus)
# Out:
# list

# %%
corpus[33]
# Out:
# ('far', 43)
